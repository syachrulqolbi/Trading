# %%
# === Imports === #
import MetaTrader5 as mt5
import pandas as pd
import numpy as np
import yaml
import os
from google_sheet_api import GoogleSheetsUploader

# === Setup Paths === #
BASE_DIR = os.getcwd()
CONFIG_PATH = os.path.join(BASE_DIR, "config.yaml")
CREDENTIAL_PATH = os.path.join(BASE_DIR, "credential_google_sheets.json")

# === Load Configuration === #
def load_config(path):
    with open(path, "r") as file:
        return yaml.safe_load(file)

config = load_config(CONFIG_PATH)

# === Initialize MT5 Connection === #
if not mt5.initialize():
    print("MT5 initialization failed.")
    quit()

# === Retrieve Account Information === #
account_info = mt5.account_info()
if account_info is None:
    print("Failed to retrieve account information.")
    mt5.shutdown()
    quit()

balance = account_info.balance
equity = account_info.equity
floating_loss = account_info.profit

print("=== Account Information ===")
print(f"Balance: {balance:.2f} USD")
print(f"Equity: {equity:.2f} USD")
print(f"Floating Loss: {floating_loss:.2f} USD")

# === Load Running Trades from MT5 and Reference Google Sheet === #
fetcher = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")
df = fetcher.get_sheet_as_dataframe("Forex")
positions = mt5.positions_get()
df_positions = pd.DataFrame([pos._asdict() for pos in positions]) if positions else pd.DataFrame()

if df_positions.empty:
    print("No running trades found. Error:", mt5.last_error())
    mt5.shutdown()
    quit()

# === Clean and Rename Trade Columns === #
df_positions = df_positions[["type", "volume", "price_open", "price_current", "sl", "tp", "profit", "symbol"]]
df_positions["type"] = df_positions["type"].replace({0: "Buy", 1: "Sell"})
df_positions.rename(columns={
    "symbol": "Symbol",
    "type": "Action",
    "volume": "Lot",
    "price_open": "Price",
    "price_current": "Price Current",
    "sl": "SL",
    "tp": "TP",
    "profit": "Profit"
}, inplace=True)

# Prepare hedge profit DataFrame early for printing
df_trend = df[[df.columns[0], df.columns[1], df.columns[2], df.columns[19]]].drop_duplicates()
df_trend.columns = ["Symbol", "Type", "Action", "Trend"]

df_temp_profit = df_positions[["Symbol", "Action", "Profit"]]
df_hedge = pd.merge(df_trend, df_temp_profit, on=["Symbol", "Action"], how="left")
hedged_profit = df_hedge.loc[
    (df_hedge["Type"] == "Forex") & (df_hedge["Trend"] == "Sideways"),
    "Profit"
].sum()

print(f"Total hedged amount (Forex, Sideways trend): {hedged_profit} USD")

# === Aggregate Positions by Symbol and Action === #
def aggregate_group(group):
    symbol = group["Symbol"].iloc[0]
    action = group["Action"].iloc[0]
    lot = group["Lot"].sum()
    warnings = []

    df_lot_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[5]].sum()
    if not pd.isna(df_lot_value) and round(df_lot_value, 2) > round(lot, 2):
        warnings.append(f"Lot Mismatch: Expected {round(df_lot_value, 2)}, Found {round(lot, 2)}")

    df_sl_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[7]].sum()
    sl_mode = group["SL"].mode().iloc[0] if not group["SL"].mode().empty else np.nan
    if group["SL"].nunique() > 1 or (df_sl_value != 0 and round(df_sl_value, 2) != round(sl_mode, 2)):
        warnings.append("SL Mismatch")

    df_tp_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[8]].sum()
    tp_mode = group["TP"].mode().iloc[0] if not group["TP"].mode().empty else np.nan
    if group["TP"].nunique() > 1 or round(df_tp_value, 2) != round(tp_mode, 2):
        warnings.append("TP Mismatch")

    warning_message = "; ".join(warnings) if warnings else np.nan

    return pd.Series({
        "Lot": lot,
        "Price": (group["Price"] * group["Lot"]).sum() / group["Lot"].sum(),
        "Price Current": group["Price Current"].mean(),
        "SL": sl_mode,
        "TP": tp_mode,
        "Profit": group["Profit"].sum(),
        "Warning": warning_message
    })

df_positions = (
    df_positions.groupby(["Symbol", "Action"], as_index=False)
    .apply(aggregate_group)
    .reset_index(drop=True)
)

# === Shutdown MT5 === #
mt5.shutdown()

# === Calculations and Merging === #
df_positions["Coeff"] = np.abs(df_positions["Profit"] / (df_positions["Price Current"] - df_positions["Price"])) / (df_positions["Lot"] * 100)
df_positions["Pips"] = np.abs(df_positions["TP"] - df_positions["SL"])

df_type = df[[df.columns[0], df.columns[1]]].drop_duplicates()
df_type.columns = ["Symbol", "Type"]
df_positions = pd.merge(df_positions, df_type, on="Symbol", how="left")
df_positions["Type"].fillna("Unknown", inplace=True)

# === Update Coefficients in Config File === #
df_avg_coeff = df_positions.groupby("Symbol")["Coeff"].mean().reset_index()
differences = {}
for _, row in df_avg_coeff.iterrows():
    symbol = row["Symbol"]
    avg_coeff = round(row["Coeff"], 5)
    if not pd.isna(avg_coeff):
        if symbol in config.get("symbol_coefficients", {}):
            old_coeff = config["symbol_coefficients"].get(symbol, avg_coeff)
            if old_coeff != avg_coeff:
                differences[symbol] = {"Old": old_coeff, "New": avg_coeff}
        config["symbol_coefficients"][symbol] = avg_coeff

with open(CONFIG_PATH, "w") as file:
    yaml.safe_dump(config, file)

print("Changed symbol_coefficients:")
for symbol, change in differences.items():
    print(f"{symbol}: {change['Old']} -> {change['New']}")

# === Add Account Summary === #
df_balance = pd.DataFrame([
    {"Symbol": "Balance", "Price": balance},
    {"Symbol": "Equity", "Price": equity},
    {"Symbol": "Floating Loss", "Price": floating_loss}
])

df_final = pd.concat([df_balance, df_positions], ignore_index=True)

# === Upload to Google Sheets === #
uploader = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")
uploader.upload_dataframe(df_final, "Forex Summary", replace=True)

# === Print Final Output === #
print("Final Merged DataFrame:")
df_final
# Out:
# === Account Information ===
# Balance: 5131.57 USD
# Equity: 4465.91 USD
# Floating Loss: -2078.42 USD
# ✅ Successfully retrieved data from 'Forex' as a DataFrame.
# Total hedged amount (Forex, Sideways trend): -700.7300000000001 USD
# C:\Users\syahr\AppData\Local\Temp\ipykernel_20032\1423313780.py:115: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(aggregate_group)
# C:\Users\syahr\AppData\Local\Temp\ipykernel_20032\1423313780.py:129: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_positions["Type"].fillna("Unknown", inplace=True)
# Changed symbol_coefficients:
# ALGOUSD: 25.03259 -> 25.01616
# APTUSD: 3.00224 -> 2.99653
# ATOMUSD: 2.5 -> 2.5052
# AUDCAD: 723.66191 -> 723.3622
# AUDCHF: 1210.99291 -> 1209.67742
# AUDJPY: 6.97302 -> 6.97405
# AUDNZD: 591.75288 -> 591.79987
# BCHUSD: 0.10037 -> 0.10038
# BNBUSD: 0.09994 -> 0.10025
# CADCHF: 1210.64302 -> 1211.32898
# CADJPY: 6.97095 -> 6.96927
# CBA.ASX: 0.64545 -> 0.6422
# CHFJPY: 6.97274 -> 6.97349
# DOTUSD: 2.50308 -> 2.5
# ETCUSD: 2.50314 -> 2.50313
# EURAUD: 643.83017 -> 643.47149
# EURCAD: 723.32479 -> 723.33503
# EURCHF: 1210.01927 -> 1210.52632
# EURGBP: 1347.17412 -> 1346.59096
# EURJPY: 6.95647 -> 6.97356
# EURMXN: 51.88768 -> 51.87381
# EURNZD: 592.33277 -> 592.38082
# EURZAR: 55.83395 -> 55.83388
# FETUSD: 29.99071 -> 29.99097
# GBPAUD: 643.07841 -> 643.42914
# GBPCAD: 722.99066 -> 723.47003
# GBPCHF: 1210.4942 -> 1210.43165
# GBPJPY: 6.97282 -> 6.97077
# GBPMXN: 51.88465 -> 51.87893
# GBPNZD: 593.35925 -> 592.52023
# GBPZAR: 55.82851 -> 55.83555
# IOTAUSD: 50.06386 -> 50.0
# LRCUSD: 24.9924 -> 24.98491
# MANAUSD: 10.00541 -> 10.0054
# NID.TSE: 0.00698 -> 0.00696
# NZDCAD: 721.97736 -> 723.49174
# NZDJPY: 6.97029 -> 6.97094
# OR.EPA: 1.13148 -> 1.13211
# SUIUSD: 29.99318 -> 29.98652
# TTE.EPA: 1.13093 -> 1.13143
# USDCAD: 723.06518 -> 723.1567
# USDCHF: 1210.60842 -> 1209.87654
# USDJPY: 7.00874 -> 6.81875
# USDMXN: 51.88431 -> 51.88652
# USDZAR: 55.83255 -> 55.82681
# ✅ Cleared all data from sheet: Forex Summary
# ✅ DataFrame successfully uploaded to Google Sheets: Forex Summary!
# Final Merged DataFrame:
#             Symbol     Price Action   Lot  Price Current       SL       TP  \
# 0          Balance  5131.570    NaN   NaN            NaN      NaN      NaN
# 1           Equity  4465.910    NaN   NaN            NaN      NaN      NaN
# 2    Floating Loss -2078.420    NaN   NaN            NaN      NaN      NaN
# 3         AAPL.NAS   213.670    Buy  0.01         201.23   67.160  217.470
# 4          AAVEUSD   266.780    Buy  0.01         258.34    0.010  294.340
# ..             ...       ...    ...   ...            ...      ...      ...
# 184         XNGUSD     3.439   Sell  0.01           3.71    7.433    3.347
# 185       XOM.NYSE   113.935    Buy  0.02         102.82   64.490  115.250
# 186         XTIUSD    63.170    Buy  0.01          60.64    0.010   64.300
# 187         XTIUSD    60.630   Sell  0.01          60.79  123.840   59.550
# 188         ZECUSD    49.570    Buy  0.02          48.92    0.010   51.490
#
#      Profit      Warning  Coeff     Pips    Type
# 0       NaN          NaN    NaN      NaN     NaN
# 1       NaN          NaN    NaN      NaN     NaN
# 2       NaN          NaN    NaN      NaN     NaN
# 3    -12.44  SL Mismatch    1.0  150.310   Stock
# 4     -4.22          NaN    0.5  294.330  Crypto
# ..      ...          ...    ...      ...     ...
# 184  -27.10          NaN  100.0    4.086   Forex
# 185  -22.23  SL Mismatch    1.0   50.760   Stock
# 186  -25.30          NaN   10.0   64.290   Forex
# 187   -1.60          NaN   10.0   64.290   Forex
# 188   -1.30          NaN    1.0   51.480  Crypto
#
# [189 rows x 12 columns]

# %%
import time
import MetaTrader5 as mt5
import pandas as pd
import os
from google_sheet_api import GoogleSheetsUploader

# === Setup Paths === #
BASE_DIR = os.getcwd()
CONFIG_PATH = os.path.join(BASE_DIR, "config.yaml")
CREDENTIAL_PATH = os.path.join(BASE_DIR, "credential_google_sheets.json")

# === Initialize MT5 Connection === #
if not mt5.initialize():
    print("MT5 initialization failed.")
    quit()

fetcher = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")

# Load DataFrame from Google Sheets
df = fetcher.get_sheet_as_dataframe("Forex")
df.columns = df.iloc[6]
df = df.iloc[7:-3].reset_index(drop=True)

# Initialize counters for success and failure
success_count = 0
failure_count = 0

# Fetch unique symbols from running trades in MT5
positions = mt5.positions_get()
if positions is None or len(positions) == 0:
    print("No running trades found. Exiting.")
    mt5.shutdown()
    quit()

# Get unique symbols from MT5 positions
symbol_list = sorted(list(set(pos.symbol for pos in positions)))

# Convert positions to DataFrame for easy filtering
df_positions = pd.DataFrame([pos._asdict() for pos in positions])

# Iterate through each unique symbol from MT5 positions
for symbol in symbol_list:
    print(f"\n=== Checking Symbol: {symbol} ===")
    for action in ["Buy", "Sell"]:
        print(f"  Action: {action}")
        action_type = 0 if action == "Buy" else 1
        filtered_positions = df_positions[(df_positions['symbol'] == symbol) & (df_positions['type'] == action_type)]
        
        if filtered_positions.empty:
            print(f"    ⚠️ No {action} positions running. Skipping.")
            continue

        # Filter rows for the current symbol and action from Google Sheets
        df_filtered = df[(df["Symbol"] == symbol) & (df["Action"] == action)]
        
        if df_filtered.empty:
            print(f"    ⚠️ No matching TP/SL settings in Google Sheets.")
            continue
        
        tp_value = round(float(df_filtered['TP'].values[0]), df_filtered['Decimal'].values[0])
        sl_value = round(float(df_filtered['SL'].values[0]), df_filtered['Decimal'].values[0])

        # Iterate over filtered positions for modification
        for _, pos in filtered_positions.iterrows():
            order_id = pos['ticket']
            current_tp = pos['tp']
            current_sl = pos['sl']

            # Check for differences and print
            print(f"    Position ID: {order_id}")
            print(f"    Current TP: {current_tp}, Current SL: {current_sl}")
            print(f"    Target TP: {tp_value}, Target SL: {sl_value}")

            if current_tp == tp_value and current_sl == sl_value:
                print(f"    ✅ No changes needed for {action} position {order_id}.")
                continue
            else:
                print(f"    ⚠️ TP/SL difference detected. Attempting to update...")

            # Modify TP/SL using position ID
            request = {
                "action": mt5.TRADE_ACTION_SLTP,
                "position": order_id,
                "sl": sl_value,
                "tp": tp_value
            }

            # Send modification request
            result = mt5.order_send(request)

            # Check if result is None (Error)
            if result is None:
                print(f"    ⚠️ Failed to modify {action} position {order_id}. Error: Request returned None.")
                failure_count += 1
                continue

            # Check if the modification was successful
            if result.retcode == mt5.TRADE_RETCODE_DONE:
                print(f"    ✅ {action} position {order_id} modified successfully.")
                print(f"    Before: TP={current_tp}, SL={current_sl}")
                print(f"    After:  TP={tp_value}, SL={sl_value}\n")
                success_count += 1
            else:
                print(f"    ⚠️ Failed to modify {action} position {order_id}. Error: {result.comment}")
                failure_count += 1

# === Shutdown MT5 Connection === #
mt5.shutdown()

# === Summary Report ===
print("\n=== TP/SL Modification Summary ===")
print(f"Total Successful Modifications: {success_count}")
print(f"Total Failed Modifications: {failure_count}")
# Out:
# ✅ Successfully retrieved data from 'Forex' as a DataFrame.
#
# === Checking Symbol: AAPL.NAS ===
#   Action: Buy
#     Position ID: 3297549570
#     Current TP: 217.47, Current SL: 67.16
#     Target TP: 217.47, Target SL: 67.53
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3297549570. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AAVEUSD ===
#   Action: Buy
#     Position ID: 3308412972
#     Current TP: 294.34, Current SL: 0.01
#     Target TP: 294.34, Target SL: 0.01
#     ✅ No changes needed for Buy position 3308412972.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ABBV.NYSE ===
#   Action: Buy
#     Position ID: 3298446412
#     Current TP: 200.55, Current SL: 124.86
#     Target TP: 200.55, Target SL: 125.19
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3298446412. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ABNB.NAS ===
#   Action: Buy
#     Position ID: 3304860529
#     Current TP: 140.01, Current SL: 0.01
#     Target TP: 140.01, Target SL: 0.01
#     ✅ No changes needed for Buy position 3304860529.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ABT.NYSE ===
#   Action: Buy
#     Position ID: 3302221724
#     Current TP: 136.36, Current SL: 77.58
#     Target TP: 136.36, Target SL: 78.22
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3302221724. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ACN.NYSE ===
#   Action: Buy
#     Position ID: 3304837038
#     Current TP: 328.41, Current SL: 205.38
#     Target TP: 328.41, Target SL: 206.59
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304837038. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ADAUSD ===
#   Action: Buy
#     Position ID: 3304100487
#     Current TP: 0.8554, Current SL: 0.0001
#     Target TP: 0.8554, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304100487.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ADS.XE ===
#   Action: Buy
#     Position ID: 3305209594
#     Current TP: 226.507, Current SL: 86.109
#     Target TP: 226.506, Target SL: 86.775
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305209594. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AI.EPA ===
#   Action: Buy
#     Position ID: 3306803616
#     Current TP: 188.77, Current SL: 120.49
#     Target TP: 188.77, Target SL: 119.04
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3306803616. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AIR.EPA ===
#   Action: Buy
#     Position ID: 3305210944
#     Current TP: 164.25, Current SL: 49.56
#     Target TP: 164.24, Target SL: 49.22
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305210944. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ALGOUSD ===
#   Action: Buy
#     Position ID: 3304100698
#     Current TP: 0.263, Current SL: 0.0001
#     Target TP: 0.263, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304100698.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AMD.NAS ===
#   Action: Buy
#     Position ID: 3305638599
#     Current TP: 121.86, Current SL: 0.01
#     Target TP: 121.86, Target SL: 0.01
#     ✅ No changes needed for Buy position 3305638599.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: APTUSD ===
#   Action: Buy
#     Position ID: 3303173396
#     Current TP: 6.4445, Current SL: 0.0001
#     Target TP: 6.4445, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303173396.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ATOMUSD ===
#   Action: Buy
#     Position ID: 3303174194
#     Current TP: 5.571, Current SL: 0.001
#     Target TP: 5.571, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303174194.
#     Position ID: 3304176535
#     Current TP: 5.571, Current SL: 0.001
#     Target TP: 5.571, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304176535.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AUDCAD ===
#   Action: Buy
#     Position ID: 3304834368
#     Current TP: 0.90446, Current SL: 0.74374
#     Target TP: 0.90446, Target SL: 0.74374
#     ✅ No changes needed for Buy position 3304834368.
#   Action: Sell
#     Position ID: 3301252618
#     Current TP: 0.88671, Current SL: 1.09313
#     Target TP: 0.88671, Target SL: 1.04743
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3301252618 modified successfully.
#     Before: TP=0.88671, SL=1.09313
#     After:  TP=0.88671, SL=1.04743
#
#     Position ID: 3304223072
#     Current TP: 0.88671, Current SL: 1.09313
#     Target TP: 0.88671, Target SL: 1.04743
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304223072 modified successfully.
#     Before: TP=0.88671, SL=1.09313
#     After:  TP=0.88671, SL=1.04743
#
#     Position ID: 3304229587
#     Current TP: 0.88671, Current SL: 1.09313
#     Target TP: 0.88671, Target SL: 1.04743
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304229587 modified successfully.
#     Before: TP=0.88671, SL=1.09313
#     After:  TP=0.88671, SL=1.04743
#
#
# === Checking Symbol: AUDCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3296721794
#     Current TP: 0.52338, Current SL: 0.78233
#     Target TP: 0.52338, Target SL: 0.78233
#     ✅ No changes needed for Sell position 3296721794.
#
# === Checking Symbol: AUDJPY ===
#   Action: Buy
#     Position ID: 3304837518
#     Current TP: 95.918, Current SL: 67.134
#     Target TP: 95.918, Target SL: 67.134
#     ✅ No changes needed for Buy position 3304837518.
#   Action: Sell
#     Position ID: 3310048126
#     Current TP: 91.502, Current SL: 133.993
#     Target TP: 91.502, Target SL: 120.286
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3310048126 modified successfully.
#     Before: TP=91.502, SL=133.993
#     After:  TP=91.502, SL=120.286
#
#
# === Checking Symbol: AUDNZD ===
#   Action: Buy
#     Position ID: 3305835701
#     Current TP: 1.09514, Current SL: 0.94945
#     Target TP: 1.09514, Target SL: 0.94945
#     ✅ No changes needed for Buy position 3305835701.
#   Action: Sell
#     Position ID: 3285918930
#     Current TP: 1.08119, Current SL: 1.2869
#     Target TP: 1.08119, Target SL: 1.22688
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3285918930 modified successfully.
#     Before: TP=1.08119, SL=1.2869
#     After:  TP=1.08119, SL=1.22688
#
#     Position ID: 3304223126
#     Current TP: 1.08119, Current SL: 1.2869
#     Target TP: 1.08119, Target SL: 1.22688
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304223126 modified successfully.
#     Before: TP=1.08119, SL=1.2869
#     After:  TP=1.08119, SL=1.22688
#
#
# === Checking Symbol: AUDUSD ===
#   Action: Buy
#     Position ID: 3304888719
#     Current TP: 0.65114, Current SL: 0.45295
#     Target TP: 0.65114, Target SL: 0.45295
#     ✅ No changes needed for Buy position 3304888719.
#   Action: Sell
#     Position ID: 3304180166
#     Current TP: 0.63239, Current SL: 0.8896
#     Target TP: 0.63239, Target SL: 0.83058
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304180166 modified successfully.
#     Before: TP=0.63239, SL=0.8896
#     After:  TP=0.63239, SL=0.83058
#
#     Position ID: 3304223991
#     Current TP: 0.63239, Current SL: 0.8896
#     Target TP: 0.63239, Target SL: 0.83058
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304223991 modified successfully.
#     Before: TP=0.63239, SL=0.8896
#     After:  TP=0.63239, SL=0.83058
#
#
# === Checking Symbol: AVAXUSD ===
#   Action: Buy
#     Position ID: 3303762188
#     Current TP: 26.804, Current SL: 0.001
#     Target TP: 26.804, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303762188.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AVGO.NAS ===
#   Action: Buy
#     Position ID: 3309615573
#     Current TP: 234.98, Current SL: 128.63
#     Target TP: 234.98, Target SL: 128.12
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3309615573. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AXSUSD ===
#   Action: Buy
#     Position ID: 3305014875
#     Current TP: 3.92, Current SL: 0.01
#     Target TP: 3.92, Target SL: 0.01
#     ✅ No changes needed for Buy position 3305014875.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AZN.LSE ===
#   Action: Buy
#     Position ID: 3299847401
#     Current TP: 109.4, Current SL: 69.76
#     Target TP: 109.4, Target SL: 69.62
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3299847401. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BABA.NYSE ===
#   Action: Buy
#     Position ID: 3304102868
#     Current TP: 135.37, Current SL: 0.01
#     Target TP: 135.37, Target SL: 0.01
#     ✅ No changes needed for Buy position 3304102868.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BAC.NYSE ===
#   Action: Buy
#     Position ID: 3304888731
#     Current TP: 45.16, Current SL: 8.95
#     Target TP: 45.16, Target SL: 8.98
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304888731. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BARC.LSE ===
#   Action: Buy
#     Position ID: 3303762395
#     Current TP: 3.2833, Current SL: 0.0001
#     Target TP: 3.2833, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303762395.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BATS.LSE ===
#   Action: Buy
#     Position ID: 3299872790
#     Current TP: 33.67, Current SL: 15.535
#     Target TP: 33.67, Target SL: 15.52
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3299872790. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BAYN.FWB ===
#   Action: Buy
#     Position ID: 3305209875
#     Current TP: 25.05, Current SL: 0.01
#     Target TP: 25.05, Target SL: 0.01
#     ✅ No changes needed for Buy position 3305209875.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BBVA.BM ===
#   Action: Buy
#     Position ID: 3308534286
#     Current TP: 13.9534, Current SL: 3.4971
#     Target TP: 13.9533, Target SL: 3.5194
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3308534286. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BCHUSD ===
#   Action: Buy
#     Position ID: 3310544490
#     Current TP: 470.06, Current SL: 0.01
#     Target TP: 470.06, Target SL: 0.01
#     ✅ No changes needed for Buy position 3310544490.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BEI.XE ===
#   Action: Buy
#     Position ID: 3299405469
#     Current TP: 125.111, Current SL: 82.549
#     Target TP: 125.111, Target SL: 81.386
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3299405469. Error: Market closed
#     Position ID: 3303762634
#     Current TP: 125.111, Current SL: 82.549
#     Target TP: 125.111, Target SL: 81.386
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303762634. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BHP.ASX ===
#   Action: Buy
#     Position ID: 3305001253
#     Current TP: 39.76, Current SL: 17.55
#     Target TP: 39.76, Target SL: 21.28
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305001253. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BMW.XE ===
#   Action: Buy
#     Position ID: 3305210030
#     Current TP: 85.07, Current SL: 33.046
#     Target TP: 85.07, Target SL: 32.971
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305210030. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BMY.NYSE ===
#   Action: Buy
#     Position ID: 3300219853
#     Current TP: 49.03, Current SL: 27.42
#     Target TP: 49.03, Target SL: 27.52
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3300219853. Error: Market closed
#     Position ID: 3304109863
#     Current TP: 49.03, Current SL: 27.42
#     Target TP: 49.03, Target SL: 27.52
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304109863. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BNBUSD ===
#   Action: Buy
#     Position ID: 3303003080
#     Current TP: 693.51, Current SL: 0.01
#     Target TP: 693.51, Target SL: 0.01
#     ✅ No changes needed for Buy position 3303003080.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BNP.EPA ===
#   Action: Buy
#     Position ID: 3305269306
#     Current TP: 80.891, Current SL: 23.637
#     Target TP: 80.892, Target SL: 22.397
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305269306. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BX.NYSE ===
#   Action: Buy
#     Position ID: 3304110024
#     Current TP: 150.74, Current SL: 39.75
#     Target TP: 150.74, Target SL: 39.28
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304110024. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CADCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3295246044
#     Current TP: 0.59027, Current SL: 0.82553
#     Target TP: 0.59027, Target SL: 0.82553
#     ✅ No changes needed for Sell position 3295246044.
#
# === Checking Symbol: CADJPY ===
#   Action: Buy
#     Position ID: 3303757604
#     Current TP: 106.673, Current SL: 80.606
#     Target TP: 106.673, Target SL: 80.606
#     ✅ No changes needed for Buy position 3303757604.
#     Position ID: 3304223147
#     Current TP: 106.673, Current SL: 80.606
#     Target TP: 106.673, Target SL: 80.606
#     ✅ No changes needed for Buy position 3304223147.
#   Action: Sell
#     Position ID: 3309939192
#     Current TP: 102.654, Current SL: 141.273
#     Target TP: 102.654, Target SL: 128.721
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3309939192 modified successfully.
#     Before: TP=102.654, SL=141.273
#     After:  TP=102.654, SL=128.721
#
#
# === Checking Symbol: CBA.ASX ===
#   Action: Buy
#     Position ID: 3308995304
#     Current TP: 176.78, Current SL: 80.66
#     Target TP: 176.78, Target SL: 98.19
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3308995304. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CHFJPY ===
#   Action: Buy
#     Position ID: 3298014085
#     Current TP: 176.525, Current SL: 135.735
#     Target TP: 176.525, Target SL: 135.735
#     ✅ No changes needed for Buy position 3298014085.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CMCSA.NAS ===
#   Action: Buy
#     Position ID: 3307097606
#     Current TP: 36.18, Current SL: 18.32
#     Target TP: 36.19, Target SL: 18.34
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3307097606. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: COP.NYSE ===
#   Action: Buy
#     Position ID: 3280209232
#     Current TP: 96.56, Current SL: 42.74
#     Target TP: 96.56, Target SL: 42.35
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3280209232. Error: Market closed
#     Position ID: 3293935589
#     Current TP: 96.56, Current SL: 42.74
#     Target TP: 96.56, Target SL: 42.35
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293935589. Error: Market closed
#     Position ID: 3293935927
#     Current TP: 96.56, Current SL: 42.74
#     Target TP: 96.56, Target SL: 42.35
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293935927. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CSCO.NAS ===
#   Action: Buy
#     Position ID: 3306357971
#     Current TP: 66.08, Current SL: 18.53
#     Target TP: 66.08, Target SL: 18.5
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3306357971. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CSL.ASX ===
#   Action: Buy
#     Position ID: 3298768130
#     Current TP: 261.57, Current SL: 146.06
#     Target TP: 261.57, Target SL: 148.45
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3298768130. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CVS.NYSE ===
#   Action: Buy
#     Position ID: 3298338209
#     Current TP: 68.74, Current SL: 29.01
#     Target TP: 68.74, Target SL: 29.46
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3298338209. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DAII.TSE ===
#   Action: Buy
#     Position ID: 3309673882
#     Current TP: 3839.21, Current SL: 1856.27
#     Target TP: 3839.21, Target SL: 2781.22
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3309673882. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DASHUSD ===
#   Action: Buy
#     Position ID: 3303173212
#     Current TP: 26.18, Current SL: 0.01
#     Target TP: 26.18, Target SL: 0.01
#     ✅ No changes needed for Buy position 3303173212.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DHR.NYSE ===
#   Action: Buy
#     Position ID: 3304176735
#     Current TP: 202.29, Current SL: 161.18
#     Target TP: 202.29, Target SL: 161.34
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304176735. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DIS.NYSE ===
#   Action: Buy
#     Position ID: 3307217925
#     Current TP: 114.68, Current SL: 44.39
#     Target TP: 114.68, Target SL: 44.47
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3307217925. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DKI.TSE ===
#   Action: Buy
#     Position ID: 3297726752
#     Current TP: 17495.93, Current SL: 7518.22
#     Target TP: 17495.95, Target SL: 9341.51
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3297726752. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DOTUSD ===
#   Action: Buy
#     Position ID: 3303763159
#     Current TP: 5.44, Current SL: 0.001
#     Target TP: 5.44, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303763159.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DTE.FWB ===
#   Action: Buy
#     Position ID: 3310031540
#     Current TP: 34.64, Current SL: 13.0
#     Target TP: 34.64, Target SL: 12.68
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3310031540. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ENEL.MIL ===
#   Action: Buy
#     Position ID: 3307098448
#     Current TP: 8.1278, Current SL: 3.5299
#     Target TP: 8.1278, Target SL: 3.5898
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3307098448. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ENI.MIL ===
#   Action: Buy
#     Position ID: 3303763971
#     Current TP: 13.526, Current SL: 6.667
#     Target TP: 13.526, Target SL: 6.518
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303763971. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ETCUSD ===
#   Action: Buy
#     Position ID: 3303173265
#     Current TP: 21.247, Current SL: 0.001
#     Target TP: 21.247, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303173265.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: EURAUD ===
#   Action: Buy
#     Position ID: 3293418441
#     Current TP: 1.78078, Current SL: 1.37819
#     Target TP: 1.78078, Target SL: 1.37819
#     ✅ No changes needed for Buy position 3293418441.
#   Action: Sell
#     Position ID: 3304856822
#     Current TP: 1.71953, Current SL: 2.29523
#     Target TP: 1.71953, Target SL: 2.12212
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304856822 modified successfully.
#     Before: TP=1.71953, SL=2.29523
#     After:  TP=1.71953, SL=2.12212
#
#
# === Checking Symbol: EURCAD ===
#   Action: Buy
#     Position ID: 3307941066
#     Current TP: 1.57756, Current SL: 1.24118
#     Target TP: 1.57756, Target SL: 1.24118
#     ✅ No changes needed for Buy position 3307941066.
#   Action: Sell
#     Position ID: 3303757395
#     Current TP: 1.54474, Current SL: 1.9977800000000001
#     Target TP: 1.54474, Target SL: 1.88112
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3303757395 modified successfully.
#     Before: TP=1.54474, SL=1.9977800000000001
#     After:  TP=1.54474, SL=1.88112
#
#     Position ID: 3304223178
#     Current TP: 1.54474, Current SL: 1.9977800000000001
#     Target TP: 1.54474, Target SL: 1.88112
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304223178 modified successfully.
#     Before: TP=1.54474, SL=1.9977800000000001
#     After:  TP=1.54474, SL=1.88112
#
#
# === Checking Symbol: EURCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3299527080
#     Current TP: 0.92792, Current SL: 1.1963
#     Target TP: 0.92792, Target SL: 1.1963
#     ✅ No changes needed for Sell position 3299527080.
#
# === Checking Symbol: EURGBP ===
#   Action: Buy
#     Position ID: 3293418914
#     Current TP: 0.85066, Current SL: 0.72728
#     Target TP: 0.85066, Target SL: 0.72728
#     ✅ No changes needed for Buy position 3293418914.
#     Position ID: 3304223185
#     Current TP: 0.85066, Current SL: 0.72728
#     Target TP: 0.85066, Target SL: 0.72728
#     ✅ No changes needed for Buy position 3304223185.
#   Action: Sell
#     Position ID: 3303756772
#     Current TP: 0.8393, Current SL: 0.99071
#     Target TP: 0.8393, Target SL: 0.96268
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3303756772 modified successfully.
#     Before: TP=0.8393, SL=0.99071
#     After:  TP=0.8393, SL=0.96268
#
#     Position ID: 3304223191
#     Current TP: 0.8393, Current SL: 0.99071
#     Target TP: 0.8393, Target SL: 0.96268
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304223191 modified successfully.
#     Before: TP=0.8393, SL=0.99071
#     After:  TP=0.8393, SL=0.96268
#
#
# === Checking Symbol: EURJPY ===
#   Action: Buy
#     Position ID: 3304179775
#     Current TP: 165.483, Current SL: 124.003
#     Target TP: 165.483, Target SL: 124.003
#     ✅ No changes needed for Buy position 3304179775.
#   Action: Sell
#     Position ID: 3293419124
#     Current TP: 161.477, Current SL: 220.882
#     Target TP: 161.477, Target SL: 202.957
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3293419124 modified successfully.
#     Before: TP=161.477, SL=220.882
#     After:  TP=161.477, SL=202.957
#
#
# === Checking Symbol: EURMXN ===
#   Action: Buy
#     Position ID: 3293419757
#     Current TP: 22.3899, Current SL: 17.2993
#     Target TP: 22.3899, Target SL: 17.2993
#     ✅ No changes needed for Buy position 3293419757.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: EURNZD ===
#   Action: Buy
#     Position ID: 3309752276
#     Current TP: 1.92251, Current SL: 1.49187
#     Target TP: 1.92251, Target SL: 1.49187
#     ✅ No changes needed for Buy position 3309752276.
#   Action: Sell
#     Position ID: 3304459498
#     Current TP: 1.87539, Current SL: 2.46265
#     Target TP: 1.87539, Target SL: 2.30603
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304459498 modified successfully.
#     Before: TP=1.87539, SL=2.46265
#     After:  TP=1.87539, SL=2.30603
#
#
# === Checking Symbol: EURUSD ===
#   Action: Buy
#     Position ID: 3297343009
#     Current TP: 1.1371, Current SL: 0.84125
#     Target TP: 1.1371, Target SL: 0.84125
#     ✅ No changes needed for Buy position 3297343009.
#   Action: Sell
#     Position ID: 3303757469
#     Current TP: 1.10566, Current SL: 1.4641
#     Target TP: 1.10566, Target SL: 1.40151
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3303757469 modified successfully.
#     Before: TP=1.10566, SL=1.4641
#     After:  TP=1.10566, SL=1.40151
#
#
# === Checking Symbol: EURZAR ===
#   Action: Buy
#     Position ID: 3297344129
#     Current TP: 21.24951, Current SL: 15.16286
#     Target TP: 21.24951, Target SL: 15.16286
#     ✅ No changes needed for Buy position 3297344129.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: FETUSD ===
#   Action: Buy
#     Position ID: 3310566104
#     Current TP: 0.9984, Current SL: 0.0001
#     Target TP: 0.9984, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3310566104.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: FILUSD ===
#   Action: Buy
#     Position ID: 3302580433
#     Current TP: 3.289, Current SL: 0.001
#     Target TP: 3.289, Target SL: 0.001
#     ✅ No changes needed for Buy position 3302580433.
#     Position ID: 3303239649
#     Current TP: 3.289, Current SL: 0.001
#     Target TP: 3.289, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303239649.
#     Position ID: 3303770477
#     Current TP: 3.289, Current SL: 0.001
#     Target TP: 3.289, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303770477.
#     Position ID: 3304121459
#     Current TP: 3.289, Current SL: 0.001
#     Target TP: 3.289, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304121459.
#     Position ID: 3304219700
#     Current TP: 3.289, Current SL: 0.001
#     Target TP: 3.289, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304219700.
#     Position ID: 3304239787
#     Current TP: 3.289, Current SL: 0.001
#     Target TP: 3.289, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304239787.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: GBPAUD ===
#   Action: Buy
#     Position ID: 3297344455
#     Current TP: 2.09625, Current SL: 1.55679
#     Target TP: 2.09625, Target SL: 1.55679
#     ✅ No changes needed for Buy position 3297344455.
#   Action: Sell
#     Position ID: 3299102816
#     Current TP: 2.03972, Current SL: 2.77994
#     Target TP: 2.03972, Target SL: 2.57918
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3299102816 modified successfully.
#     Before: TP=2.03972, SL=2.77994
#     After:  TP=2.03972, SL=2.57918
#
#
# === Checking Symbol: GBPCAD ===
#   Action: Buy
#     Position ID: 3307940973
#     Current TP: 1.8740299999999999, Current SL: 1.4186
#     Target TP: 1.87403, Target SL: 1.4186
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3307940973. Error: No changes
#   Action: Sell
#     Position ID: 3297345453
#     Current TP: 1.8335, Current SL: 2.45689
#     Target TP: 1.8335, Target SL: 2.28893
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3297345453 modified successfully.
#     Before: TP=1.8335, SL=2.45689
#     After:  TP=1.8335, SL=2.28893
#
#
# === Checking Symbol: GBPCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3298014406
#     Current TP: 1.09067, Current SL: 1.4925899999999999
#     Target TP: 1.09067, Target SL: 1.49259
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Sell position 3298014406. Error: No changes
#
# === Checking Symbol: GBPJPY ===
#   Action: Buy
#     Position ID: 3304869137
#     Current TP: 197.191, Current SL: 124.777
#     Target TP: 197.191, Target SL: 124.777
#     ✅ No changes needed for Buy position 3304869137.
#   Action: Sell
#     Position ID: 3299912193
#     Current TP: 189.588, Current SL: 293.746
#     Target TP: 189.588, Target SL: 262.002
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3299912193 modified successfully.
#     Before: TP=189.588, SL=293.746
#     After:  TP=189.588, SL=262.002
#
#
# === Checking Symbol: GBPMXN ===
#   Action: Buy
#     Position ID: 3285596224
#     Current TP: 26.9704, Current SL: 20.1317
#     Target TP: 26.9704, Target SL: 20.1317
#     ✅ No changes needed for Buy position 3285596224.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: GBPNZD ===
#   Action: Buy
#     Position ID: 3310088345
#     Current TP: 2.2826, Current SL: 1.69253
#     Target TP: 2.2826, Target SL: 1.69253
#     ✅ No changes needed for Buy position 3310088345.
#   Action: Sell
#     Position ID: 3298767397
#     Current TP: 2.22018, Current SL: 2.9865
#     Target TP: 2.22018, Target SL: 2.81025
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3298767397 modified successfully.
#     Before: TP=2.22018, SL=2.9865
#     After:  TP=2.22018, SL=2.81025
#
#
# === Checking Symbol: GBPUSD ===
#   Action: Buy
#     Position ID: 3295254715
#     Current TP: 1.34955, Current SL: 0.95193
#     Target TP: 1.34955, Target SL: 0.95193
#     ✅ No changes needed for Buy position 3295254715.
#   Action: Sell
#     Position ID: 3303757685
#     Current TP: 1.31158, Current SL: 1.84843
#     Target TP: 1.31158, Target SL: 1.7092
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3303757685 modified successfully.
#     Before: TP=1.31158, SL=1.84843
#     After:  TP=1.31158, SL=1.7092
#
#
# === Checking Symbol: GBPZAR ===
#   Action: Buy
#     Position ID: 3297347553
#     Current TP: 25.01683, Current SL: 17.67203
#     Target TP: 25.01683, Target SL: 17.67203
#     ✅ No changes needed for Buy position 3297347553.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: GOOGL.NAS ===
#   Action: Buy
#     Position ID: 3310270852
#     Current TP: 177.99, Current SL: 95.92
#     Target TP: 177.99, Target SL: 95.45
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3310270852. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HEIA.EAS ===
#   Action: Buy
#     Position ID: 3300760802
#     Current TP: 80.275, Current SL: 49.984
#     Target TP: 80.274, Target SL: 49.487
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3300760802. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HIT.TSE ===
#   Action: Buy
#     Position ID: 3303449468
#     Current TP: 3938.39, Current SL: 324.26
#     Target TP: 3938.39, Target SL: 1150.27
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303449468. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HMC.NYSE ===
#   Action: Buy
#     Position ID: 3295995003
#     Current TP: 31.33, Current SL: 0.01
#     Target TP: 31.33, Target SL: 0.01
#     ✅ No changes needed for Buy position 3295995003.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HON.NAS ===
#   Action: Buy
#     Position ID: 3306521821
#     Current TP: 225.33, Current SL: 88.24
#     Target TP: 225.33, Target SL: 88.04
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3306521821. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HSBA.LSE ===
#   Action: Buy
#     Position ID: 3303764157
#     Current TP: 8.97, Current SL: 0.0001
#     Target TP: 8.97, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303764157.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: IBM.NYSE ===
#   Action: Buy
#     Position ID: 3307105900
#     Current TP: 270.33, Current SL: 130.66
#     Target TP: 270.33, Target SL: 132.08
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3307105900. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: INTC.NAS ===
#   Action: Buy
#     Position ID: 3304188828
#     Current TP: 22.89, Current SL: 0.01
#     Target TP: 22.89, Target SL: 0.01
#     ✅ No changes needed for Buy position 3304188828.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: IOTAUSD ===
#   Action: Buy
#     Position ID: 3303174051
#     Current TP: 0.2668, Current SL: 0.0001
#     Target TP: 0.2668, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303174051.
#     Position ID: 3304127077
#     Current TP: 0.2668, Current SL: 0.0001
#     Target TP: 0.2668, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304127077.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ISP.MIL ===
#   Action: Buy
#     Position ID: 3302854899
#     Current TP: 5.0376, Current SL: 1.1011
#     Target TP: 5.0376, Target SL: 1.0664
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3302854899. Error: Market closed
#     Position ID: 3304492379
#     Current TP: 5.0376, Current SL: 1.1011
#     Target TP: 5.0376, Target SL: 1.0664
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304492379. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ITX.BM ===
#   Action: Buy
#     Position ID: 3294683715
#     Current TP: 50.406, Current SL: 29.73
#     Target TP: 50.406, Target SL: 29.742
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3294683715. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: JAR.SGX ===
#   Action: Buy
#     Position ID: 3279704752
#     Current TP: 26.44, Current SL: 0.01
#     Target TP: 26.44, Target SL: 0.01
#     ✅ No changes needed for Buy position 3279704752.
#     Position ID: 3293425477
#     Current TP: 26.44, Current SL: 0.01
#     Target TP: 26.44, Target SL: 0.01
#     ✅ No changes needed for Buy position 3293425477.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: JD.NAS ===
#   Action: Buy
#     Position ID: 3304860748
#     Current TP: 38.37, Current SL: 0.01
#     Target TP: 38.37, Target SL: 0.01
#     ✅ No changes needed for Buy position 3304860748.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: JNJ.NYSE ===
#   Action: Buy
#     Position ID: 3278886088
#     Current TP: 159.07, Current SL: 110.61
#     Target TP: 159.07, Target SL: 110.72
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3278886088. Error: Market closed
#     Position ID: 3293954893
#     Current TP: 159.07, Current SL: 110.61
#     Target TP: 159.07, Target SL: 110.72
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293954893. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: KO.NYSE ===
#   Action: Buy
#     Position ID: 3296715805
#     Current TP: 73.09, Current SL: 42.52
#     Target TP: 73.09, Target SL: 42.81
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3296715805. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LI.NAS ===
#   Action: Buy
#     Position ID: 3309431987
#     Current TP: 30.45, Current SL: 0.01
#     Target TP: 30.45, Target SL: 0.01
#     ✅ No changes needed for Buy position 3309431987.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LINKUSD ===
#   Action: Buy
#     Position ID: 3303764332
#     Current TP: 18.098, Current SL: 0.001
#     Target TP: 18.098, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303764332.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LRCUSD ===
#   Action: Buy
#     Position ID: 3299514904
#     Current TP: 0.1288, Current SL: 0.0001
#     Target TP: 0.1288, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3299514904.
#     Position ID: 3304127358
#     Current TP: 0.1288, Current SL: 0.0001
#     Target TP: 0.1288, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304127358.
#     Position ID: 3306729027
#     Current TP: 0.1288, Current SL: 0.0001
#     Target TP: 0.1288, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3306729027.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LSEG.LSE ===
#   Action: Buy
#     Position ID: 3292134139
#     Current TP: 117.76, Current SL: 46.62
#     Target TP: 117.76, Target SL: 46.65
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3292134139. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LTCUSD ===
#   Action: Buy
#     Position ID: 3303003157
#     Current TP: 108.22, Current SL: 0.01
#     Target TP: 108.22, Target SL: 0.01
#     ✅ No changes needed for Buy position 3303003157.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MANAUSD ===
#   Action: Buy
#     Position ID: 3303174266
#     Current TP: 0.4002, Current SL: 0.0001
#     Target TP: 0.4002, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303174266.
#     Position ID: 3303239684
#     Current TP: 0.4002, Current SL: 0.0001
#     Target TP: 0.4002, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303239684.
#     Position ID: 3304128204
#     Current TP: 0.4002, Current SL: 0.0001
#     Target TP: 0.4002, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304128204.
#     Position ID: 3304176884
#     Current TP: 0.4002, Current SL: 0.0001
#     Target TP: 0.4002, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304176884.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MBG.XE ===
#   Action: Buy
#     Position ID: 3294703468
#     Current TP: 55.75, Current SL: 18.77
#     Target TP: 55.75, Target SL: 18.64
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3294703468. Error: Market closed
#     Position ID: 3299026423
#     Current TP: 55.75, Current SL: 18.77
#     Target TP: 55.75, Target SL: 18.64
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3299026423. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MCD.NYSE ===
#   Action: Buy
#     Position ID: 3308743172
#     Current TP: 324.72, Current SL: 173.21
#     Target TP: 324.72, Target SL: 174.55
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3308743172. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MDLZ.NAS ===
#   Action: Buy
#     Position ID: 3296717234
#     Current TP: 69.22, Current SL: 45.4
#     Target TP: 69.22, Target SL: 45.51
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3296717234. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MMM.NYSE ===
#   Action: Buy
#     Position ID: 3308743325
#     Current TP: 156.02, Current SL: 81.23
#     Target TP: 156.02, Target SL: 82.08
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3308743325. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MRK.NYSE ===
#   Action: Buy
#     Position ID: 3304188852
#     Current TP: 81.77, Current SL: 59.98
#     Target TP: 81.77, Target SL: 59.99
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304188852. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MRK.XE ===
#   Action: Buy
#     Position ID: 3304493136
#     Current TP: 128.3842, Current SL: 84.9535
#     Target TP: 128.3842, Target SL: 84.9884
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304493136. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MS.NYSE ===
#   Action: Buy
#     Position ID: 3306521810
#     Current TP: 135.27, Current SL: 26.94
#     Target TP: 135.27, Target SL: 26.96
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3306521810. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MUR.TSE ===
#   Action: Buy
#     Position ID: 3304239834
#     Current TP: 2185.92, Current SL: 691.73
#     Target TP: 2185.92, Target SL: 1231.85
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304239834. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NAB.ASX ===
#   Action: Buy
#     Position ID: 3309004900
#     Current TP: 38.25, Current SL: 15.04
#     Target TP: 38.25, Target SL: 20.26
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3309004900. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NEARUSD ===
#   Action: Buy
#     Position ID: 3303173156
#     Current TP: 3.536, Current SL: 0.001
#     Target TP: 3.536, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303173156.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NEE.NYSE ===
#   Action: Buy
#     Position ID: 3308746012
#     Current TP: 76.01, Current SL: 47.2
#     Target TP: 76.01, Target SL: 47.44
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3308746012. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NESTE.OMXH ===
#   Action: Buy
#     Position ID: 3308625823
#     Current TP: 10.26, Current SL: 0.01
#     Target TP: 10.26, Target SL: 0.01
#     ✅ No changes needed for Buy position 3308625823.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NID.TSE ===
#   Action: Buy
#     Position ID: 3305794022
#     Current TP: 2919.03, Current SL: 0.01
#     Target TP: 2919.04, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305794022. Error: Market closed
#     Position ID: 3308239278
#     Current TP: 2919.03, Current SL: 0.01
#     Target TP: 2919.04, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3308239278. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NKE.NYSE ===
#   Action: Buy
#     Position ID: 3307107003
#     Current TP: 64.33, Current SL: 0.01
#     Target TP: 64.33, Target SL: 0.01
#     ✅ No changes needed for Buy position 3307107003.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NOKIA.OMXH ===
#   Action: Buy
#     Position ID: 3276134396
#     Current TP: 4.7479, Current SL: 0.0001
#     Target TP: 4.7479, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3276134396.
#     Position ID: 3292135089
#     Current TP: 4.7479, Current SL: 0.0001
#     Target TP: 4.7479, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3292135089.
#     Position ID: 3293980710
#     Current TP: 4.7479, Current SL: 0.0001
#     Target TP: 4.7479, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3293980710.
#     Position ID: 3299027603
#     Current TP: 4.7479, Current SL: 0.0001
#     Target TP: 4.7479, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3299027603.
#     Position ID: 3304492678
#     Current TP: 4.7479, Current SL: 0.0001
#     Target TP: 4.7479, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304492678.
#     Position ID: 3304547359
#     Current TP: 4.7479, Current SL: 0.0001
#     Target TP: 4.7479, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304547359.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NVDA.NAS ===
#   Action: Buy
#     Position ID: 3306521835
#     Current TP: 137.5, Current SL: 7.31
#     Target TP: 137.49, Target SL: 7.34
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3306521835. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NZDCAD ===
#   Action: Buy
#     Position ID: 3304830506
#     Current TP: 0.83148, Current SL: 0.65621
#     Target TP: 0.83148, Target SL: 0.65621
#     ✅ No changes needed for Buy position 3304830506.
#     Position ID: 3304830658
#     Current TP: 0.83148, Current SL: 0.65621
#     Target TP: 0.83148, Target SL: 0.65621
#     ✅ No changes needed for Buy position 3304830658.
#   Action: Sell
#     Position ID: 3296002462
#     Current TP: 0.81533, Current SL: 1.05433
#     Target TP: 0.81533, Target SL: 0.9906
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3296002462 modified successfully.
#     Before: TP=0.81533, SL=1.05433
#     After:  TP=0.81533, SL=0.9906
#
#     Position ID: 3304223209
#     Current TP: 0.81533, Current SL: 1.05433
#     Target TP: 0.81533, Target SL: 0.9906
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304223209 modified successfully.
#     Before: TP=0.81533, SL=1.05433
#     After:  TP=0.81533, SL=0.9906
#
#     Position ID: 3304229647
#     Current TP: 0.81533, Current SL: 1.05433
#     Target TP: 0.81533, Target SL: 0.9906
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304229647 modified successfully.
#     Before: TP=0.81533, SL=1.05433
#     After:  TP=0.81533, SL=0.9906
#
#
# === Checking Symbol: NZDCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3295245784
#     Current TP: 0.4871, Current SL: 0.71381
#     Target TP: 0.4871, Target SL: 0.71381
#     ✅ No changes needed for Sell position 3295245784.
#
# === Checking Symbol: NZDJPY ===
#   Action: Buy
#     Position ID: 3304856177
#     Current TP: 88.259, Current SL: 61.689
#     Target TP: 88.259, Target SL: 61.689
#     ✅ No changes needed for Buy position 3304856177.
#   Action: Sell
#     Position ID: 3306599358
#     Current TP: 84.581, Current SL: 125.652
#     Target TP: 84.581, Target SL: 111.151
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3306599358 modified successfully.
#     Before: TP=84.581, SL=125.652
#     After:  TP=84.581, SL=111.151
#
#
# === Checking Symbol: NZDUSD ===
#   Action: Buy
#     Position ID: 3305270505
#     Current TP: 0.59921, Current SL: 0.41959
#     Target TP: 0.59921, Target SL: 0.41959
#     ✅ No changes needed for Buy position 3305270505.
#   Action: Sell
#     Position ID: 3303841489
# ...
#     ⚠️ Failed to modify Buy position 3309615644. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: RTX.NYSE ===
#   Action: Buy
#     Position ID: 3309432026
#     Current TP: 139.15, Current SL: 60.75
#     Target TP: 139.15, Target SL: 61.2
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3309432026. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SAN.BM ===
#   Action: Buy
#     Position ID: 3308590585
#     Current TP: 7.2215, Current SL: 0.0001
#     Target TP: 7.2215, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3308590585.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SBUX.NAS ===
#   Action: Buy
#     Position ID: 3280209688
#     Current TP: 92.49, Current SL: 41.12
#     Target TP: 92.49, Target SL: 40.76
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3280209688. Error: Market closed
#     Position ID: 3293985232
#     Current TP: 92.49, Current SL: 41.12
#     Target TP: 92.49, Target SL: 40.76
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293985232. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SHEL.LSE ===
#   Action: Buy
#     Position ID: 3303764511
#     Current TP: 25.38, Current SL: 0.01
#     Target TP: 25.38, Target SL: 0.01
#     ✅ No changes needed for Buy position 3303764511.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SHOP.NYSE ===
#   Action: Buy
#     Position ID: 3306359172
#     Current TP: 113.79, Current SL: 0.01
#     Target TP: 113.78, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3306359172. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SONY.NYSE ===
#   Action: Buy
#     Position ID: 3295995076
#     Current TP: 26.09, Current SL: 6.47
#     Target TP: 26.09, Target SL: 6.54
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3295995076. Error: Market closed
#     Position ID: 3299416560
#     Current TP: 26.09, Current SL: 6.47
#     Target TP: 26.09, Target SL: 6.54
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3299416560. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: STLA.MIL ===
#   Action: Buy
#     Position ID: 3304836943
#     Current TP: 9.985, Current SL: 0.001
#     Target TP: 9.985, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304836943.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SUIUSD ===
#   Action: Buy
#     Position ID: 3303764586
#     Current TP: 4.3367, Current SL: 0.0001
#     Target TP: 4.3367, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303764586.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SVN.TSE ===
#   Action: Buy
#     Position ID: 3303526044
#     Current TP: 2365.87, Current SL: 1070.35
#     Target TP: 2365.87, Target SL: 1391.5
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303526044. Error: Market closed
#     Position ID: 3304239917
#     Current TP: 2365.87, Current SL: 1070.35
#     Target TP: 2365.87, Target SL: 1391.5
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304239917. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: T.NYSE ===
#   Action: Buy
#     Position ID: 3301254934
#     Current TP: 28.29, Current SL: 14.37
#     Target TP: 28.29, Target SL: 14.45
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3301254934. Error: Market closed
#     Position ID: 3304132650
#     Current TP: 28.29, Current SL: 14.37
#     Target TP: 28.29, Target SL: 14.45
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304132650. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TCEHY.OTC ===
#   Action: Buy
#     Position ID: 3305638500
#     Current TP: 67.995, Current SL: 24.235
#     Target TP: 67.995, Target SL: 24.432
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305638500. Error: Market closed
#     Position ID: 3306359369
#     Current TP: 67.995, Current SL: 24.235
#     Target TP: 67.995, Target SL: 24.432
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3306359369. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TKY.TSE ===
#   Action: Buy
#     Position ID: 3305001170
#     Current TP: 24822.85, Current SL: 3512.46
#     Target TP: 24822.81, Target SL: 7966.4
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305001170. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TM.TSE ===
#   Action: Buy
#     Position ID: 3304242075
#     Current TP: 2914.98, Current SL: 1101.19
#     Target TP: 2914.98, Target SL: 1472.92
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304242075. Error: Market closed
#     Position ID: 3304380529
#     Current TP: 2914.98, Current SL: 1101.19
#     Target TP: 2914.98, Target SL: 1472.92
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304380529. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TMH.TSE ===
#   Action: Buy
#     Position ID: 3303450840
#     Current TP: 6199.4, Current SL: 0.01
#     Target TP: 6199.41, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303450840. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TMO.NYSE ===
#   Action: Buy
#     Position ID: 3295995689
#     Current TP: 435.52, Current SL: 253.07
#     Target TP: 435.52, Target SL: 254.27
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3295995689. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TTE.EPA ===
#   Action: Buy
#     Position ID: 3278875237
#     Current TP: 53.94, Current SL: 30.91
#     Target TP: 53.94, Target SL: 30.76
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3278875237. Error: Market closed
#     Position ID: 3292135946
#     Current TP: 53.94, Current SL: 30.91
#     Target TP: 53.94, Target SL: 30.76
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3292135946. Error: Market closed
#     Position ID: 3293652739
#     Current TP: 53.94, Current SL: 30.91
#     Target TP: 53.94, Target SL: 30.76
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293652739. Error: Market closed
#     Position ID: 3293653283
#     Current TP: 53.94, Current SL: 30.91
#     Target TP: 53.94, Target SL: 30.76
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293653283. Error: Market closed
#     Position ID: 3293653462
#     Current TP: 53.94, Current SL: 30.91
#     Target TP: 53.94, Target SL: 30.76
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293653462. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TXN.NAS ===
#   Action: Buy
#     Position ID: 3304132717
#     Current TP: 191.76, Current SL: 69.23
#     Target TP: 191.76, Target SL: 69.46
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304132717. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UCG.MIL ===
#   Action: Buy
#     Position ID: 3309225864
#     Current TP: 59.354, Current SL: 0.001
#     Target TP: 59.354, Target SL: 0.001
#     ✅ No changes needed for Buy position 3309225864.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UNH.NYSE ===
#   Action: Buy
#     Position ID: 3295249135
#     Current TP: 426.8, Current SL: 222.17
#     Target TP: 426.8, Target SL: 235.38
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3295249135. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UNIUSD ===
#   Action: Buy
#     Position ID: 3303173729
#     Current TP: 7.68, Current SL: 0.001
#     Target TP: 7.68, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303173729.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UNP.NYSE ===
#   Action: Buy
#     Position ID: 3307217889
#     Current TP: 234.63, Current SL: 122.35
#     Target TP: 234.63, Target SL: 122.36
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3307217889. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UPS.NYSE ===
#   Action: Buy
#     Position ID: 3304133027
#     Current TP: 101.96, Current SL: 78.19
#     Target TP: 101.96, Target SL: 76.74
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304133027. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: USDCAD ===
#   Action: Buy
#     Position ID: 3307143399
#     Current TP: 1.40326, Current SL: 1.1492
#     Target TP: 1.40326, Target SL: 1.1492
#     ✅ No changes needed for Buy position 3307143399.
#   Action: Sell
#     Position ID: 3309425424
#     Current TP: 1.38082, Current SL: 1.7312699999999999
#     Target TP: 1.38082, Target SL: 1.63488
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3309425424 modified successfully.
#     Before: TP=1.38082, SL=1.7312699999999999
#     After:  TP=1.38082, SL=1.63488
#
#
# === Checking Symbol: USDCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3301255979
#     Current TP: 0.81609, Current SL: 1.13291
#     Target TP: 0.81609, Target SL: 1.13291
#     ✅ No changes needed for Sell position 3301255979.
#
# === Checking Symbol: USDJPY ===
#   Action: Buy
#     Position ID: 3303757544
#     Current TP: 148.953, Current SL: 120.535
#     Target TP: 148.953, Target SL: 120.535
#     ✅ No changes needed for Buy position 3303757544.
#     Position ID: 3304223239
#     Current TP: 148.953, Current SL: 120.535
#     Target TP: 148.953, Target SL: 120.535
#     ✅ No changes needed for Buy position 3304223239.
#   Action: Sell
#     Position ID: 3309604729
#     Current TP: 142.776, Current SL: 185.136
#     Target TP: 142.776, Target SL: 171.194
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3309604729 modified successfully.
#     Before: TP=142.776, SL=185.136
#     After:  TP=142.776, SL=171.194
#
#
# === Checking Symbol: USDMXN ===
#   Action: Buy
#     Position ID: 3293437457
#     Current TP: 19.7216, Current SL: 16.7638
#     Target TP: 19.7216, Target SL: 16.7638
#     ✅ No changes needed for Buy position 3293437457.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: USDZAR ===
#   Action: Buy
#     Position ID: 3293437473
#     Current TP: 18.99192, Current SL: 13.57167
#     Target TP: 18.99192, Target SL: 13.57167
#     ✅ No changes needed for Buy position 3293437473.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: VNA.XE ===
#   Action: Buy
#     Position ID: 3301984800
#     Current TP: 30.723, Current SL: 0.001
#     Target TP: 30.723, Target SL: 0.001
#     ✅ No changes needed for Buy position 3301984800.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: VOW3.XE ===
#   Action: Buy
#     Position ID: 3304856583
#     Current TP: 106.474, Current SL: 0.001
#     Target TP: 106.474, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304856583.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: VZ.NYSE ===
#   Action: Buy
#     Position ID: 3308743558
#     Current TP: 45.07, Current SL: 24.63
#     Target TP: 45.07, Target SL: 24.84
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3308743558. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: WES.ASX ===
#   Action: Buy
#     Position ID: 3308250571
#     Current TP: 84.25, Current SL: 35.5
#     Target TP: 84.25, Target SL: 44.6
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3308250571. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: WFC.NYSE ===
#   Action: Buy
#     Position ID: 3304837439
#     Current TP: 77.07, Current SL: 29.37
#     Target TP: 77.07, Target SL: 29.38
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304837439. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: WMT.NYSE ===
#   Action: Buy
#     Position ID: 3298325768
#     Current TP: 99.89, Current SL: 65.21
#     Target TP: 99.89, Target SL: 65.53
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3298325768. Error: Market closed
#     Position ID: 3299419095
#     Current TP: 99.89, Current SL: 65.21
#     Target TP: 99.89, Target SL: 65.53
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3299419095. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: XBRUSD ===
#   Action: Buy
#     Position ID: 3304837349
#     Current TP: 66.81, Current SL: 0.01
#     Target TP: 66.81, Target SL: 0.01
#     ✅ No changes needed for Buy position 3304837349.
#   Action: Sell
#     Position ID: 3306063937
#     Current TP: 62.73, Current SL: 129.53
#     Target TP: 62.73, Target SL: 129.53
#     ✅ No changes needed for Sell position 3306063937.
#
# === Checking Symbol: XNGUSD ===
#   Action: Buy
#     Position ID: 3304493382
#     Current TP: 4.087, Current SL: 0.001
#     Target TP: 4.087, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304493382.
#   Action: Sell
#     Position ID: 3308412938
#     Current TP: 3.347, Current SL: 7.433
#     Target TP: 3.347, Target SL: 7.433
#     ✅ No changes needed for Sell position 3308412938.
#
# === Checking Symbol: XOM.NYSE ===
#   Action: Buy
#     Position ID: 3278885254
#     Current TP: 115.25, Current SL: 64.49
#     Target TP: 115.25, Target SL: 64.41
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3278885254. Error: Market closed
#     Position ID: 3293990121
#     Current TP: 115.25, Current SL: 64.49
#     Target TP: 115.25, Target SL: 64.41
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293990121. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: XTIUSD ===
#   Action: Buy
#     Position ID: 3308946532
#     Current TP: 64.3, Current SL: 0.01
#     Target TP: 64.3, Target SL: 0.01
#     ✅ No changes needed for Buy position 3308946532.
#   Action: Sell
#     Position ID: 3306063871
#     Current TP: 59.55, Current SL: 123.84
#     Target TP: 59.55, Target SL: 123.84
#     ✅ No changes needed for Sell position 3306063871.
#
# === Checking Symbol: ZECUSD ===
#   Action: Buy
#     Position ID: 3310618254
#     Current TP: 51.49, Current SL: 0.01
#     Target TP: 51.49, Target SL: 0.01
#     ✅ No changes needed for Buy position 3310618254.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === TP/SL Modification Summary ===
# Total Successful Modifications: 30
# Total Failed Modifications: 103
