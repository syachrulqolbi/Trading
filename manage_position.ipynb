# %%
# === Imports === #
import MetaTrader5 as mt5
import pandas as pd
import numpy as np
import yaml
import os
from google_sheet_api import GoogleSheetsUploader

# === Setup Paths === #
BASE_DIR = os.getcwd()
CONFIG_PATH = os.path.join(BASE_DIR, "config.yaml")
CREDENTIAL_PATH = os.path.join(BASE_DIR, "credential_google_sheets.json")

# === Load Configuration === #
def load_config(path):
    with open(path, "r") as file:
        return yaml.safe_load(file)

config = load_config(CONFIG_PATH)

# === Initialize MT5 Connection === #
if not mt5.initialize():
    print("MT5 initialization failed.")
    quit()

# === Retrieve Account Information === #
account_info = mt5.account_info()
if account_info is None:
    print("Failed to retrieve account information.")
    mt5.shutdown()
    quit()

balance = account_info.balance
equity = account_info.equity + account_info.credit
floating_loss = account_info.profit

print("=== Account Information ===")
print(f"Balance: {balance:.2f} USD")
print(f"Equity: {equity:.2f} USD")
print(f"Floating Loss: {floating_loss:.2f} USD")

# === Load Running Trades from MT5 and Reference Google Sheet === #
fetcher = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")
df = fetcher.get_sheet_as_dataframe("Forex")
positions = mt5.positions_get()
df_positions = pd.DataFrame([pos._asdict() for pos in positions]) if positions else pd.DataFrame()

if df_positions.empty:
    print("No running trades found. Error:", mt5.last_error())
    mt5.shutdown()
    quit()

# === Clean and Rename Trade Columns === #
df_positions = df_positions[["type", "volume", "price_open", "price_current", "sl", "tp", "profit", "symbol"]]
df_positions["type"] = df_positions["type"].replace({0: "Buy", 1: "Sell"})
df_positions.rename(columns={
    "symbol": "Symbol",
    "type": "Action",
    "volume": "Lot",
    "price_open": "Price",
    "price_current": "Price Current",
    "sl": "SL",
    "tp": "TP",
    "profit": "Profit"
}, inplace=True)

# Prepare hedge profit DataFrame early for printing
df_trend = df[[df.columns[0], df.columns[1], df.columns[2], df.columns[19]]].drop_duplicates()
df_trend.columns = ["Symbol", "Type", "Action", "Trend"]

df_temp_profit = df_positions[["Symbol", "Action", "Profit"]]
df_hedge = pd.merge(df_trend, df_temp_profit, on=["Symbol", "Action"], how="left")
hedged_profit = df_hedge.loc[
    (df_hedge["Type"] == "Forex") & (df_hedge["Trend"] == "Sideways"),
    "Profit"
].sum()

print(f"Total hedged amount (Forex, Sideways trend): {hedged_profit} USD")

# === Aggregate Positions by Symbol and Action === #
def aggregate_group(group):
    symbol = group["Symbol"].iloc[0]
    action = group["Action"].iloc[0]
    lot = group["Lot"].sum()
    warnings = []

    df_lot_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[5]].sum()
    if not pd.isna(df_lot_value) and round(df_lot_value, 2) > round(lot, 2):
        warnings.append(f"Lot Mismatch: Expected {round(df_lot_value, 2)}, Found {round(lot, 2)}")

    df_sl_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[7]].sum()
    sl_mode = group["SL"].mode().iloc[0] if not group["SL"].mode().empty else np.nan
    if group["SL"].nunique() > 1 or (df_sl_value != 0 and round(df_sl_value, 2) != round(sl_mode, 2)):
        warnings.append("SL Mismatch")

    df_tp_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[8]].sum()
    tp_mode = group["TP"].mode().iloc[0] if not group["TP"].mode().empty else np.nan
    if group["TP"].nunique() > 1 or round(df_tp_value, 2) != round(tp_mode, 2):
        warnings.append("TP Mismatch")

    warning_message = "; ".join(warnings) if warnings else np.nan

    return pd.Series({
        "Lot": lot,
        "Price": (group["Price"] * group["Lot"]).sum() / group["Lot"].sum(),
        "Price Current": group["Price Current"].mean(),
        "SL": sl_mode,
        "TP": tp_mode,
        "Profit": group["Profit"].sum(),
        "Warning": warning_message
    })

df_positions = (
    df_positions.groupby(["Symbol", "Action"], as_index=False)
    .apply(aggregate_group)
    .reset_index(drop=True)
)

# === Shutdown MT5 === #
mt5.shutdown()

# === Calculations and Merging === #
df_positions["Coeff"] = np.abs(df_positions["Profit"] / (df_positions["Price Current"] - df_positions["Price"])) / (df_positions["Lot"] * 100)
df_positions["Pips"] = np.abs(df_positions["TP"] - df_positions["SL"])

df_type = df[[df.columns[0], df.columns[1]]].drop_duplicates()
df_type.columns = ["Symbol", "Type"]
df_positions = pd.merge(df_positions, df_type, on="Symbol", how="left")
df_positions["Type"].fillna("Unknown", inplace=True)

# === Update Coefficients in Config File === #
df_avg_coeff = df_positions.groupby("Symbol")["Coeff"].mean().reset_index()
differences = {}
for _, row in df_avg_coeff.iterrows():
    symbol = row["Symbol"]
    avg_coeff = round(row["Coeff"], 5)
    if not pd.isna(avg_coeff):
        if symbol in config.get("symbol_coefficients", {}):
            old_coeff = config["symbol_coefficients"].get(symbol, avg_coeff)
            if old_coeff != avg_coeff:
                differences[symbol] = {"Old": old_coeff, "New": avg_coeff}
        config["symbol_coefficients"][symbol] = avg_coeff

with open(CONFIG_PATH, "w") as file:
    yaml.safe_dump(config, file)

print("Changed symbol_coefficients:")
for symbol, change in differences.items():
    print(f"{symbol}: {change['Old']} -> {change['New']}")

# === Add Account Summary === #
df_balance = pd.DataFrame([
    {"Symbol": "Balance", "Price": balance},
    {"Symbol": "Equity", "Price": equity},
    {"Symbol": "Floating Loss", "Price": floating_loss}
])

df_final = pd.concat([df_balance, df_positions], ignore_index=True)

# === Upload to Google Sheets === #
uploader = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")
uploader.upload_dataframe(df_final, "Forex Summary", replace=True)

# === Print Final Output === #
print("Final Merged DataFrame:")
df_final
# Out:
# === Account Information ===
# Balance: 5594.85 USD
# Equity: 6407.23 USD
# Floating Loss: -2284.62 USD
# ✅ Successfully retrieved data from 'Forex' as a DataFrame.
# Total hedged amount (Forex, Sideways trend): -830.3199999999999 USD
# C:\Users\syahr\AppData\Local\Temp\ipykernel_5580\3000152237.py:115: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(aggregate_group)
# C:\Users\syahr\AppData\Local\Temp\ipykernel_5580\3000152237.py:129: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_positions["Type"].fillna("Unknown", inplace=True)
# Changed symbol_coefficients:
# AAVEUSD: 0.50028 -> 0.5
# ADS.XE: 1.00018 -> 1.00019
# AI.EPA: 1.13466 -> 1.13365
# AIR.EPA: 1.1342 -> 1.13208
# ALGOUSD: 25.00704 -> 25.00726
# APTUSD: 2.99984 -> 3.00025
# ATOMUSD: 2.50089 -> 2.50091
# AUDCAD: 724.48482 -> 724.30564
# AUDCHF: 1215.90909 -> 1213.83648
# AUDJPY: 6.94571 -> 6.95012
# AUDNZD: 596.02273 -> 596.16477
# AXSUSD: 0.5 -> 0.50009
# AZN.LSE: 1.3477 -> 1.34936
# BATS.LSE: 1.32812 -> 1.25
# BBVA.BM: 1.1354 -> 1.13346
# BCHUSD: 0.09996 -> 0.09998
# BEI.XE: 1.00192 -> 1.00164
# BHP.ASX: 0.64137 -> 0.64286
# BMW.XE: 1.00077 -> 1.00075
# BNBUSD: 0.10018 -> 0.09995
# BNP.EPA: 1.13442 -> 1.13328
# CADCHF: 1213.59223 -> 1212.2905
# CADJPY: 6.94687 -> 6.95083
# CHFJPY: 6.94382 -> 6.94977
# CSL.ASX: 0.64079 -> 0.6426
# DOTUSD: 2.5 -> 2.50078
# ENEL.MIL: 1.14206 -> 1.13839
# ENI.MIL: 1.13462 -> 1.13402
# EURAUD: 642.34984 -> 642.24703
# EURCAD: 723.7157 -> 724.05194
# EURCHF: 1213.2964 -> 1212.46459
# EURGBP: 1349.00578 -> 1348.48051
# EURJPY: 6.94816 -> 6.94819
# EURMXN: 51.81869 -> 51.84813
# EURNZD: 595.84954 -> 596.13117
# EURZAR: 56.00538 -> 55.98059
# FETUSD: 29.99757 -> 29.99755
# FILUSD: 1.00055 -> 1.00056
# GBPAUD: 642.68127 -> 641.78527
# GBPCAD: 723.73983 -> 723.58377
# GBPCHF: 1214.81481 -> 1213.68625
# GBPJPY: 6.94771 -> 6.94927
# GBPMXN: 51.81347 -> 51.85591
# GBPNZD: 595.78117 -> 596.10034
# GBPZAR: 56.00845 -> 55.99119
# HEIA.EAS: 1.1377 -> 1.13489
# HSBA.LSE: 1.35338 -> 1.34636
# IOTAUSD: 50.02378 -> 50.02338
# ISP.MIL: 1.13107 -> 1.13221
# ITX.BM: 1.13413 -> 1.1324
# LRCUSD: 24.99752 -> 24.99745
# LSEG.LSE: 1.34729 -> 1.34848
# MANAUSD: 10.00229 -> 9.99772
# NEARUSD: 2.50062 -> 2.50063
# NESTE.OMXH: 1.13346 -> 1.1337
# NOKIA.OMXH: 1.13596 -> 1.14213
# NZDCAD: 723.6255 -> 724.02485
# NZDCHF: 1213.48315 -> 1212.76596
# NZDJPY: 6.94552 -> 6.94751
# OR.EPA: 1.1343 -> 1.13307
# SAN.BM: 1.13451 -> 1.12754
# SHEL.LSE: 1.34746 -> 1.34906
# STLA.MIL: 1.1344 -> 1.13204
# SUIUSD: 29.99576 -> 29.99433
# TTE.EPA: 1.13415 -> 1.13277
# UCG.MIL: 1.13716 -> 1.13377
# USDCAD: 724.03557 -> 723.85822
# USDCHF: 1215.84699 -> 1212.81465
# USDJPY: 6.94777 -> 6.94909
# USDMXN: 51.81413 -> 51.8686
# USDZAR: 56.00681 -> 55.98105
# VNA.XE: 0.9992 -> 0.99932
# VOW3.XE: 1.00024 -> 0.99954
# WES.ASX: 0.64012 -> 0.64307
# ✅ Cleared all data from sheet: Forex Summary
# ✅ DataFrame successfully uploaded to Google Sheets: Forex Summary!
# Final Merged DataFrame:
#             Symbol     Price Action   Lot  Price Current       SL       TP  \
# 0          Balance  5594.850    NaN   NaN            NaN      NaN      NaN
# 1           Equity  6407.230    NaN   NaN            NaN      NaN      NaN
# 2    Floating Loss -2284.620    NaN   NaN            NaN      NaN      NaN
# 3         AAPL.NAS   213.670    Buy  0.01        199.830   67.530  217.470
# 4          AAVEUSD   266.780    Buy  0.01        249.580    0.010  294.340
# ..             ...       ...    ...   ...            ...      ...      ...
# 185         XNGUSD     3.439   Sell  0.01          3.601    7.433    3.347
# 186       XOM.NYSE   113.935    Buy  0.02        102.630   64.410  115.250
# 187         XTIUSD    63.170    Buy  0.01         60.990    0.010   64.300
# 188         XTIUSD    60.630   Sell  0.01         61.120  123.840   59.550
# 189         ZECUSD    55.110    Buy  0.01         50.970    0.010   57.250
#
#      Profit      Warning  Coeff     Pips    Type
# 0       NaN          NaN    NaN      NaN     NaN
# 1       NaN          NaN    NaN      NaN     NaN
# 2       NaN          NaN    NaN      NaN     NaN
# 3    -13.84  SL Mismatch    1.0  149.940   Stock
# 4     -8.60  TP Mismatch    0.5  294.330  Crypto
# ..      ...          ...    ...      ...     ...
# 185  -16.20          NaN  100.0    4.086   Forex
# 186  -22.61  SL Mismatch    1.0   50.840   Stock
# 187  -21.80          NaN   10.0   64.290   Forex
# 188   -4.90          NaN   10.0   64.290   Forex
# 189   -4.14          NaN    1.0   57.240  Crypto
#
# [190 rows x 12 columns]

# %%
import time
import MetaTrader5 as mt5
import pandas as pd
import os
from google_sheet_api import GoogleSheetsUploader

# === Setup Paths === #
BASE_DIR = os.getcwd()
CONFIG_PATH = os.path.join(BASE_DIR, "config.yaml")
CREDENTIAL_PATH = os.path.join(BASE_DIR, "credential_google_sheets.json")

# === Initialize MT5 Connection === #
if not mt5.initialize():
    print("MT5 initialization failed.")
    quit()

fetcher = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")

# Load DataFrame from Google Sheets
df = fetcher.get_sheet_as_dataframe("Forex")
df.columns = df.iloc[6]
df = df.iloc[7:-3].reset_index(drop=True)

# Initialize counters for success and failure
success_count = 0
failure_count = 0

# Fetch unique symbols from running trades in MT5
positions = mt5.positions_get()
if positions is None or len(positions) == 0:
    print("No running trades found. Exiting.")
    mt5.shutdown()
    quit()

# Get unique symbols from MT5 positions
symbol_list = sorted(list(set(pos.symbol for pos in positions)))

# Convert positions to DataFrame for easy filtering
df_positions = pd.DataFrame([pos._asdict() for pos in positions])

# Iterate through each unique symbol from MT5 positions
for symbol in symbol_list:
    print(f"\n=== Checking Symbol: {symbol} ===")
    for action in ["Buy", "Sell"]:
        print(f"  Action: {action}")
        action_type = 0 if action == "Buy" else 1
        filtered_positions = df_positions[(df_positions['symbol'] == symbol) & (df_positions['type'] == action_type)]
        
        if filtered_positions.empty:
            print(f"    ⚠️ No {action} positions running. Skipping.")
            continue

        # Filter rows for the current symbol and action from Google Sheets
        df_filtered = df[(df["Symbol"] == symbol) & (df["Action"] == action)]
        
        if df_filtered.empty:
            print(f"    ⚠️ No matching TP/SL settings in Google Sheets.")
            continue
        
        tp_value = round(float(df_filtered['TP'].values[0]), df_filtered['Decimal'].values[0])
        sl_value = round(float(df_filtered['SL'].values[0]), df_filtered['Decimal'].values[0])

        # Iterate over filtered positions for modification
        for _, pos in filtered_positions.iterrows():
            order_id = pos['ticket']
            current_tp = pos['tp']
            current_sl = pos['sl']

            # Check for differences and print
            print(f"    Position ID: {order_id}")
            print(f"    Current TP: {current_tp}, Current SL: {current_sl}")
            print(f"    Target TP: {tp_value}, Target SL: {sl_value}")

            if current_tp == tp_value and current_sl == sl_value:
                print(f"    ✅ No changes needed for {action} position {order_id}.")
                continue
            else:
                print(f"    ⚠️ TP/SL difference detected. Attempting to update...")

            # Modify TP/SL using position ID
            request = {
                "action": mt5.TRADE_ACTION_SLTP,
                "position": order_id,
                "sl": sl_value,
                "tp": tp_value
            }

            # Send modification request
            result = mt5.order_send(request)

            # Check if result is None (Error)
            if result is None:
                print(f"    ⚠️ Failed to modify {action} position {order_id}. Error: Request returned None.")
                failure_count += 1
                continue

            # Check if the modification was successful
            if result.retcode == mt5.TRADE_RETCODE_DONE:
                print(f"    ✅ {action} position {order_id} modified successfully.")
                print(f"    Before: TP={current_tp}, SL={current_sl}")
                print(f"    After:  TP={tp_value}, SL={sl_value}\n")
                success_count += 1
            else:
                print(f"    ⚠️ Failed to modify {action} position {order_id}. Error: {result.comment}")
                failure_count += 1

# === Shutdown MT5 Connection === #
mt5.shutdown()

# === Summary Report ===
print("\n=== TP/SL Modification Summary ===")
print(f"Total Successful Modifications: {success_count}")
print(f"Total Failed Modifications: {failure_count}")
# Out:
# ✅ Successfully retrieved data from 'Forex' as a DataFrame.
#
# === Checking Symbol: AAPL.NAS ===
#   Action: Buy
#     Position ID: 3297549570
#     Current TP: 217.47, Current SL: 67.53
#     Target TP: 217.47, Target SL: 67.66
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3297549570. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AAVEUSD ===
#   Action: Buy
#     Position ID: 3308412972
#     Current TP: 294.34, Current SL: 0.01
#     Target TP: 294.23, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3308412972 modified successfully.
#     Before: TP=294.34, SL=0.01
#     After:  TP=294.23, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ABBV.NYSE ===
#   Action: Buy
#     Position ID: 3298446412
#     Current TP: 200.55, Current SL: 125.19
#     Target TP: 200.55, Target SL: 125.21
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3298446412. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ABNB.NAS ===
#   Action: Buy
#     Position ID: 3304860529
#     Current TP: 140.01, Current SL: 0.01
#     Target TP: 140.0, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304860529. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ABT.NYSE ===
#   Action: Buy
#     Position ID: 3302221724
#     Current TP: 136.36, Current SL: 78.22
#     Target TP: 136.36, Target SL: 78.54
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3302221724. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ACN.NYSE ===
#   Action: Buy
#     Position ID: 3304837038
#     Current TP: 328.41, Current SL: 206.59
#     Target TP: 328.41, Target SL: 206.74
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304837038. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ADAUSD ===
#   Action: Buy
#     Position ID: 3304100487
#     Current TP: 0.8554, Current SL: 0.0001
#     Target TP: 0.8553, Target SL: 0.0001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304100487 modified successfully.
#     Before: TP=0.8554, SL=0.0001
#     After:  TP=0.8553, SL=0.0001
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ADS.XE ===
#   Action: Buy
#     Position ID: 3313817895
#     Current TP: 229.648, Current SL: 86.775
#     Target TP: 229.648, Target SL: 85.941
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3313817895 modified successfully.
#     Before: TP=229.648, SL=86.775
#     After:  TP=229.648, SL=85.941
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AI.EPA ===
#   Action: Buy
#     Position ID: 3306803616
#     Current TP: 188.77, Current SL: 119.04
#     Target TP: 188.77, Target SL: 119.2
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3306803616 modified successfully.
#     Before: TP=188.77, SL=119.04
#     After:  TP=188.77, SL=119.2
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AIR.EPA ===
#   Action: Buy
#     Position ID: 3313091214
#     Current TP: 168.02, Current SL: 49.22
#     Target TP: 168.02, Target SL: 49.57
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3313091214 modified successfully.
#     Before: TP=168.02, SL=49.22
#     After:  TP=168.02, SL=49.57
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ALGOUSD ===
#   Action: Buy
#     Position ID: 3304100698
#     Current TP: 0.263, Current SL: 0.0001
#     Target TP: 0.263, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304100698.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AMD.NAS ===
#   Action: Buy
#     Position ID: 3305638599
#     Current TP: 121.86, Current SL: 0.01
#     Target TP: 121.86, Target SL: 0.01
#     ✅ No changes needed for Buy position 3305638599.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: APTUSD ===
#   Action: Buy
#     Position ID: 3303173396
#     Current TP: 6.4445, Current SL: 0.0001
#     Target TP: 6.4434, Target SL: 0.0001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303173396 modified successfully.
#     Before: TP=6.4445, SL=0.0001
#     After:  TP=6.4434, SL=0.0001
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ATOMUSD ===
#   Action: Buy
#     Position ID: 3303174194
#     Current TP: 5.571, Current SL: 0.001
#     Target TP: 5.57, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303174194 modified successfully.
#     Before: TP=5.571, SL=0.001
#     After:  TP=5.57, SL=0.001
#
#     Position ID: 3304176535
#     Current TP: 5.571, Current SL: 0.001
#     Target TP: 5.57, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304176535 modified successfully.
#     Before: TP=5.571, SL=0.001
#     After:  TP=5.57, SL=0.001
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AUDCAD ===
#   Action: Buy
#     Position ID: 3304834368
#     Current TP: 0.90446, Current SL: 0.74374
#     Target TP: 0.90446, Target SL: 0.74567
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304834368 modified successfully.
#     Before: TP=0.90446, SL=0.74374
#     After:  TP=0.90446, SL=0.74567
#
#   Action: Sell
#     Position ID: 3312739870
#     Current TP: 0.88295, Current SL: 1.04367
#     Target TP: 0.88295, Target SL: 1.04367
#     ✅ No changes needed for Sell position 3312739870.
#
# === Checking Symbol: AUDCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3296721794
#     Current TP: 0.52338, Current SL: 0.78233
#     Target TP: 0.52338, Target SL: 0.78187
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3296721794 modified successfully.
#     Before: TP=0.52338, SL=0.78233
#     After:  TP=0.52338, SL=0.78187
#
#
# === Checking Symbol: AUDJPY ===
#   Action: Buy
#     Position ID: 3304837518
#     Current TP: 95.918, Current SL: 67.134
#     Target TP: 95.918, Target SL: 67.118
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304837518 modified successfully.
#     Before: TP=95.918, SL=67.134
#     After:  TP=95.918, SL=67.118
#
#   Action: Sell
#     Position ID: 3310048126
#     Current TP: 91.502, Current SL: 120.286
#     Target TP: 91.501, Target SL: 120.285
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3310048126 modified successfully.
#     Before: TP=91.502, SL=120.286
#     After:  TP=91.501, SL=120.285
#
#
# === Checking Symbol: AUDNZD ===
#   Action: Buy
#     Position ID: 3305835701
#     Current TP: 1.09514, Current SL: 0.94945
#     Target TP: 1.09514, Target SL: 0.94868
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3305835701 modified successfully.
#     Before: TP=1.09514, SL=0.94945
#     After:  TP=1.09514, SL=0.94868
#
#   Action: Sell
#     Position ID: 3313504868
#     Current TP: 1.07431, Current SL: 1.22
#     Target TP: 1.07431, Target SL: 1.22
#     ✅ No changes needed for Sell position 3313504868.
#
# === Checking Symbol: AUDUSD ===
#   Action: Buy
#     Position ID: 3311586902
#     Current TP: 0.65556, Current SL: 0.45295
#     Target TP: 0.65556, Target SL: 0.45389
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3311586902 modified successfully.
#     Before: TP=0.65556, SL=0.45295
#     After:  TP=0.65556, SL=0.45389
#
#   Action: Sell
#     Position ID: 3304180166
#     Current TP: 0.63239, Current SL: 0.835
#     Target TP: 0.63239, Target SL: 0.835
#     ✅ No changes needed for Sell position 3304180166.
#     Position ID: 3304223991
#     Current TP: 0.63239, Current SL: 0.835
#     Target TP: 0.63239, Target SL: 0.835
#     ✅ No changes needed for Sell position 3304223991.
#
# === Checking Symbol: AVAXUSD ===
#   Action: Buy
#     Position ID: 3303762188
#     Current TP: 26.804, Current SL: 0.001
#     Target TP: 26.802, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303762188 modified successfully.
#     Before: TP=26.804, SL=0.001
#     After:  TP=26.802, SL=0.001
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AVGO.NAS ===
#   Action: Buy
#     Position ID: 3314090060
#     Current TP: 245.01, Current SL: 128.12
#     Target TP: 245.01, Target SL: 128.42
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3314090060. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AXSUSD ===
#   Action: Buy
#     Position ID: 3305014875
#     Current TP: 3.92, Current SL: 0.01
#     Target TP: 3.92, Target SL: 0.01
#     ✅ No changes needed for Buy position 3305014875.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AZN.LSE ===
#   Action: Buy
#     Position ID: 3299847401
#     Current TP: 109.4, Current SL: 69.62
#     Target TP: 109.4, Target SL: 69.48
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3299847401 modified successfully.
#     Before: TP=109.4, SL=69.62
#     After:  TP=109.4, SL=69.48
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BABA.NYSE ===
#   Action: Buy
#     Position ID: 3304102868
#     Current TP: 135.37, Current SL: 0.01
#     Target TP: 135.37, Target SL: 0.01
#     ✅ No changes needed for Buy position 3304102868.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BAC.NYSE ===
#   Action: Buy
#     Position ID: 3304888731
#     Current TP: 45.16, Current SL: 8.98
#     Target TP: 45.16, Target SL: 9.0
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304888731. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BARC.LSE ===
#   Action: Buy
#     Position ID: 3303762395
#     Current TP: 3.2833, Current SL: 0.0001
#     Target TP: 3.2833, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303762395.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BATS.LSE ===
#   Action: Buy
#     Position ID: 3299872790
#     Current TP: 33.67, Current SL: 15.52
#     Target TP: 33.67, Target SL: 15.54
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3299872790 modified successfully.
#     Before: TP=33.67, SL=15.52
#     After:  TP=33.67, SL=15.54
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BAYN.FWB ===
#   Action: Buy
#     Position ID: 3313817913
#     Current TP: 25.67, Current SL: 0.01
#     Target TP: 25.67, Target SL: 0.01
#     ✅ No changes needed for Buy position 3313817913.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BBVA.BM ===
#   Action: Buy
#     Position ID: 3308534286
#     Current TP: 13.9533, Current SL: 3.5194
#     Target TP: 13.9533, Target SL: 3.5693
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3308534286 modified successfully.
#     Before: TP=13.9533, SL=3.5194
#     After:  TP=13.9533, SL=3.5693
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BCHUSD ===
#   Action: Buy
#     Position ID: 3310544490
#     Current TP: 470.06, Current SL: 0.01
#     Target TP: 470.03, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3310544490 modified successfully.
#     Before: TP=470.06, SL=0.01
#     After:  TP=470.03, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BEI.XE ===
#   Action: Buy
#     Position ID: 3299405469
#     Current TP: 125.111, Current SL: 81.386
#     Target TP: 125.111, Target SL: 79.229
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3299405469 modified successfully.
#     Before: TP=125.111, SL=81.386
#     After:  TP=125.111, SL=79.229
#
#     Position ID: 3303762634
#     Current TP: 125.111, Current SL: 81.386
#     Target TP: 125.111, Target SL: 79.229
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303762634 modified successfully.
#     Before: TP=125.111, SL=81.386
#     After:  TP=125.111, SL=79.229
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BHP.ASX ===
#   Action: Buy
#     Position ID: 3305001253
#     Current TP: 39.76, Current SL: 21.28
#     Target TP: 39.76, Target SL: 21.61
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305001253. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BMW.XE ===
#   Action: Buy
#     Position ID: 3305210030
#     Current TP: 85.07, Current SL: 32.971
#     Target TP: 85.071, Target SL: 32.518
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3305210030 modified successfully.
#     Before: TP=85.07, SL=32.971
#     After:  TP=85.071, SL=32.518
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BMY.NYSE ===
#   Action: Buy
#     Position ID: 3300219853
#     Current TP: 49.03, Current SL: 27.52
#     Target TP: 49.03, Target SL: 27.53
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3300219853. Error: Market closed
#     Position ID: 3304109863
#     Current TP: 49.03, Current SL: 27.52
#     Target TP: 49.03, Target SL: 27.53
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304109863. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BNBUSD ===
#   Action: Buy
#     Position ID: 3312740016
#     Current TP: 712.89, Current SL: 0.01
#     Target TP: 712.85, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3312740016 modified successfully.
#     Before: TP=712.89, SL=0.01
#     After:  TP=712.85, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BNP.EPA ===
#   Action: Buy
#     Position ID: 3305269306
#     Current TP: 80.892, Current SL: 22.397
#     Target TP: 80.892, Target SL: 22.705
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3305269306 modified successfully.
#     Before: TP=80.892, SL=22.397
#     After:  TP=80.892, SL=22.705
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BX.NYSE ===
#   Action: Buy
#     Position ID: 3304110024
#     Current TP: 150.74, Current SL: 39.28
#     Target TP: 150.74, Target SL: 39.41
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304110024. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CADCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3295246044
#     Current TP: 0.59027, Current SL: 0.82553
#     Target TP: 0.59027, Target SL: 0.82317
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3295246044 modified successfully.
#     Before: TP=0.59027, SL=0.82553
#     After:  TP=0.59027, SL=0.82317
#
#
# === Checking Symbol: CADJPY ===
#   Action: Buy
#     Position ID: 3303757604
#     Current TP: 106.673, Current SL: 80.606
#     Target TP: 106.673, Target SL: 80.342
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303757604 modified successfully.
#     Before: TP=106.673, SL=80.606
#     After:  TP=106.673, SL=80.342
#
#     Position ID: 3304223147
#     Current TP: 106.673, Current SL: 80.606
#     Target TP: 106.673, Target SL: 80.342
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304223147 modified successfully.
#     Before: TP=106.673, SL=80.606
#     After:  TP=106.673, SL=80.342
#
#   Action: Sell
#     Position ID: 3309939192
#     Current TP: 102.654, Current SL: 128.721
#     Target TP: 102.654, Target SL: 128.721
#     ✅ No changes needed for Sell position 3309939192.
#
# === Checking Symbol: CBA.ASX ===
#   Action: Buy
#     Position ID: 3308995304
#     Current TP: 176.94, Current SL: 98.19
#     Target TP: 176.94, Target SL: 98.13
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3308995304. Error: Market closed
#     Position ID: 3312934709
#     Current TP: 176.94, Current SL: 98.19
#     Target TP: 176.94, Target SL: 98.13
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3312934709. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CHFJPY ===
#   Action: Buy
#     Position ID: 3298014085
#     Current TP: 176.525, Current SL: 135.735
#     Target TP: 176.525, Target SL: 135.572
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3298014085 modified successfully.
#     Before: TP=176.525, SL=135.735
#     After:  TP=176.525, SL=135.572
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CMCSA.NAS ===
#   Action: Buy
#     Position ID: 3307097606
#     Current TP: 36.19, Current SL: 18.34
#     Target TP: 36.18, Target SL: 18.36
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3307097606. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: COP.NYSE ===
#   Action: Buy
#     Position ID: 3280209232
#     Current TP: 96.56, Current SL: 42.35
#     Target TP: 96.56, Target SL: 42.19
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3280209232. Error: Market closed
#     Position ID: 3293935589
#     Current TP: 96.56, Current SL: 42.35
#     Target TP: 96.56, Target SL: 42.19
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293935589. Error: Market closed
#     Position ID: 3293935927
#     Current TP: 96.56, Current SL: 42.35
#     Target TP: 96.56, Target SL: 42.19
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293935927. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CSCO.NAS ===
#   Action: Buy
#     Position ID: 3306357971
#     Current TP: 66.08, Current SL: 18.5
#     Target TP: 66.08, Target SL: 18.75
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3306357971. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CSL.ASX ===
#   Action: Buy
#     Position ID: 3298768130
#     Current TP: 261.57, Current SL: 148.45
#     Target TP: 261.57, Target SL: 148.63
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3298768130. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CVS.NYSE ===
#   Action: Buy
#     Position ID: 3298338209
#     Current TP: 68.74, Current SL: 29.46
#     Target TP: 68.74, Target SL: 29.49
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3298338209. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DAII.TSE ===
#   Action: Buy
#     Position ID: 3312869392
#     Current TP: 3935.56, Current SL: 2781.22
#     Target TP: 3935.55, Target SL: 2775.91
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3312869392. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DASHUSD ===
#   Action: Buy
#     Position ID: 3303173212
#     Current TP: 26.18, Current SL: 0.01
#     Target TP: 26.18, Target SL: 0.01
#     ✅ No changes needed for Buy position 3303173212.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DHR.NYSE ===
#   Action: Buy
#     Position ID: 3304176735
#     Current TP: 202.29, Current SL: 161.34
#     Target TP: 202.29, Target SL: 161.27
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304176735. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DIS.NYSE ===
#   Action: Buy
#     Position ID: 3307217925
#     Current TP: 114.68, Current SL: 44.47
#     Target TP: 114.69, Target SL: 44.49
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3307217925. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DKI.TSE ===
#   Action: Buy
#     Position ID: 3297726752
#     Current TP: 17495.95, Current SL: 9341.51
#     Target TP: 17495.85, Target SL: 9228.31
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3297726752. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DOTUSD ===
#   Action: Buy
#     Position ID: 3303763159
#     Current TP: 5.44, Current SL: 0.001
#     Target TP: 5.44, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303763159.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DTE.FWB ===
#   Action: Buy
#     Position ID: 3310031540
#     Current TP: 34.64, Current SL: 12.68
#     Target TP: 34.64, Target SL: 13.02
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3310031540 modified successfully.
#     Before: TP=34.64, SL=12.68
#     After:  TP=34.64, SL=13.02
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ENEL.MIL ===
#   Action: Buy
#     Position ID: 3307098448
#     Current TP: 8.1406, Current SL: 3.5898
#     Target TP: 8.1405, Target SL: 3.5873
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3307098448. Error: Invalid stops
#     Position ID: 3311774405
#     Current TP: 8.1406, Current SL: 3.5898
#     Target TP: 8.1405, Target SL: 3.5873
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3311774405. Error: Invalid stops
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ENI.MIL ===
#   Action: Buy
#     Position ID: 3303763971
#     Current TP: 13.526, Current SL: 6.518
#     Target TP: 13.525, Target SL: 6.464
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303763971 modified successfully.
#     Before: TP=13.526, SL=6.518
#     After:  TP=13.525, SL=6.464
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ETCUSD ===
#   Action: Buy
#     Position ID: 3303173265
#     Current TP: 21.247, Current SL: 0.001
#     Target TP: 21.246, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303173265 modified successfully.
#     Before: TP=21.247, SL=0.001
#     After:  TP=21.246, SL=0.001
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: EURAUD ===
#   Action: Buy
#     Position ID: 3293418441
#     Current TP: 1.78078, Current SL: 1.37819
#     Target TP: 1.78078, Target SL: 1.38236
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3293418441 modified successfully.
#     Before: TP=1.78078, SL=1.37819
#     After:  TP=1.78078, SL=1.38236
#
#   Action: Sell
#     Position ID: 3304856822
#     Current TP: 1.71953, Current SL: 2.12212
#     Target TP: 1.71952, Target SL: 2.12211
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304856822 modified successfully.
#     Before: TP=1.71953, SL=2.12212
#     After:  TP=1.71952, SL=2.12211
#
#
# === Checking Symbol: EURCAD ===
#   Action: Buy
#     Position ID: 3307941066
#     Current TP: 1.57756, Current SL: 1.24118
#     Target TP: 1.57756, Target SL: 1.24222
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3307941066 modified successfully.
#     Before: TP=1.57756, SL=1.24118
#     After:  TP=1.57756, SL=1.24222
#
#   Action: Sell
#     Position ID: 3303757395
#     Current TP: 1.54474, Current SL: 1.8811200000000001
#     Target TP: 1.54474, Target SL: 1.88112
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Sell position 3303757395. Error: No changes
#     Position ID: 3304223178
#     Current TP: 1.54474, Current SL: 1.8811200000000001
#     Target TP: 1.54474, Target SL: 1.88112
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Sell position 3304223178. Error: No changes
#
# === Checking Symbol: EURCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3299527080
#     Current TP: 0.92792, Current SL: 1.1963
#     Target TP: 0.92792, Target SL: 1.19339
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3299527080 modified successfully.
#     Before: TP=0.92792, SL=1.1963
#     After:  TP=0.92792, SL=1.19339
#
#
# === Checking Symbol: EURGBP ===
#   Action: Buy
#     Position ID: 3293418914
#     Current TP: 0.85066, Current SL: 0.72728
#     Target TP: 0.85066, Target SL: 0.72673
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3293418914 modified successfully.
#     Before: TP=0.85066, SL=0.72728
#     After:  TP=0.85066, SL=0.72673
#
#     Position ID: 3304223185
#     Current TP: 0.85066, Current SL: 0.72728
#     Target TP: 0.85066, Target SL: 0.72673
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304223185 modified successfully.
#     Before: TP=0.85066, SL=0.72728
#     After:  TP=0.85066, SL=0.72673
#
#   Action: Sell
#     Position ID: 3310842489
#     Current TP: 0.83562, Current SL: 0.959
#     Target TP: 0.83562, Target SL: 0.959
#     ✅ No changes needed for Sell position 3310842489.
#     Position ID: 3310842707
#     Current TP: 0.83562, Current SL: 0.959
#     Target TP: 0.83562, Target SL: 0.959
#     ✅ No changes needed for Sell position 3310842707.
#
# === Checking Symbol: EURJPY ===
#   Action: Buy
#     Position ID: 3304179775
#     Current TP: 165.483, Current SL: 124.003
#     Target TP: 165.482, Target SL: 123.65
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304179775 modified successfully.
#     Before: TP=165.483, SL=124.003
#     After:  TP=165.482, SL=123.65
#
#   Action: Sell
#     Position ID: 3310842266
#     Current TP: 160.376, Current SL: 201.856
#     Target TP: 160.376, Target SL: 201.856
#     ✅ No changes needed for Sell position 3310842266.
#
# === Checking Symbol: EURMXN ===
#   Action: Buy
#     Position ID: 3293419757
#     Current TP: 22.3899, Current SL: 17.2993
#     Target TP: 22.3899, Target SL: 17.311
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3293419757 modified successfully.
#     Before: TP=22.3899, SL=17.2993
#     After:  TP=22.3899, SL=17.311
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: EURNZD ===
#   Action: Buy
#     Position ID: 3309752276
#     Current TP: 1.92251, Current SL: 1.49187
#     Target TP: 1.92252, Target SL: 1.48808
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3309752276 modified successfully.
#     Before: TP=1.92251, SL=1.49187
#     After:  TP=1.92252, SL=1.48808
#
#   Action: Sell
#     Position ID: 3304459498
#     Current TP: 1.87539, Current SL: 2.30603
#     Target TP: 1.87539, Target SL: 2.30603
#     ✅ No changes needed for Sell position 3304459498.
#
# === Checking Symbol: EURUSD ===
#   Action: Buy
#     Position ID: 3311627457
#     Current TP: 1.14661, Current SL: 0.84125
#     Target TP: 1.14661, Target SL: 0.84491
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3311627457 modified successfully.
#     Before: TP=1.14661, SL=0.84125
#     After:  TP=1.14661, SL=0.84491
#
#   Action: Sell
#     Position ID: 3303757469
#     Current TP: 1.10566, Current SL: 1.41102
#     Target TP: 1.10565, Target SL: 1.41101
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3303757469 modified successfully.
#     Before: TP=1.10566, SL=1.41102
#     After:  TP=1.10565, SL=1.41101
#
#
# === Checking Symbol: EURZAR ===
#   Action: Buy
#     Position ID: 3297344129
#     Current TP: 21.24951, Current SL: 15.16286
#     Target TP: 21.24944, Target SL: 15.14943
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3297344129 modified successfully.
#     Before: TP=21.24951, SL=15.16286
#     After:  TP=21.24944, SL=15.14943
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: FETUSD ===
#   Action: Buy
#     Position ID: 3310566104
#     Current TP: 0.9984, Current SL: 0.0001
#     Target TP: 0.9983, Target SL: 0.0001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3310566104 modified successfully.
#     Before: TP=0.9984, SL=0.0001
#     After:  TP=0.9983, SL=0.0001
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: FILUSD ===
#   Action: Buy
#     Position ID: 3302580433
#     Current TP: 3.289, Current SL: 0.001
#     Target TP: 3.288, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3302580433 modified successfully.
#     Before: TP=3.289, SL=0.001
#     After:  TP=3.288, SL=0.001
#
#     Position ID: 3303239649
#     Current TP: 3.289, Current SL: 0.001
#     Target TP: 3.288, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303239649 modified successfully.
#     Before: TP=3.289, SL=0.001
#     After:  TP=3.288, SL=0.001
#
#     Position ID: 3303770477
#     Current TP: 3.289, Current SL: 0.001
#     Target TP: 3.288, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303770477 modified successfully.
#     Before: TP=3.289, SL=0.001
#     After:  TP=3.288, SL=0.001
#
#     Position ID: 3304121459
#     Current TP: 3.289, Current SL: 0.001
#     Target TP: 3.288, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304121459 modified successfully.
#     Before: TP=3.289, SL=0.001
#     After:  TP=3.288, SL=0.001
#
#     Position ID: 3304219700
#     Current TP: 3.289, Current SL: 0.001
#     Target TP: 3.288, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304219700 modified successfully.
#     Before: TP=3.289, SL=0.001
#     After:  TP=3.288, SL=0.001
#
#     Position ID: 3304239787
#     Current TP: 3.289, Current SL: 0.001
#     Target TP: 3.288, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304239787 modified successfully.
#     Before: TP=3.289, SL=0.001
#     After:  TP=3.288, SL=0.001
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: GBPAUD ===
#   Action: Buy
#     Position ID: 3310891810
#     Current TP: 2.10398, Current SL: 1.55679
#     Target TP: 2.10398, Target SL: 1.55828
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3310891810 modified successfully.
#     Before: TP=2.10398, SL=1.55679
#     After:  TP=2.10398, SL=1.55828
#
#   Action: Sell
#     Position ID: 3299102816
#     Current TP: 2.03972, Current SL: 2.58691
#     Target TP: 2.03972, Target SL: 2.58691
#     ✅ No changes needed for Sell position 3299102816.
#
# === Checking Symbol: GBPCAD ===
#   Action: Buy
#     Position ID: 3307940973
#     Current TP: 1.8740299999999999, Current SL: 1.4186
#     Target TP: 1.87403, Target SL: 1.42106
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3307940973 modified successfully.
#     Before: TP=1.8740299999999999, SL=1.4186
#     After:  TP=1.87403, SL=1.42106
#
#   Action: Sell
#     Position ID: 3297345453
#     Current TP: 1.8335, Current SL: 2.28893
#     Target TP: 1.8335, Target SL: 2.28893
#     ✅ No changes needed for Sell position 3297345453.
#
# === Checking Symbol: GBPCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3298014406
#     Current TP: 1.09067, Current SL: 1.4925899999999999
#     Target TP: 1.09067, Target SL: 1.48982
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3298014406 modified successfully.
#     Before: TP=1.09067, SL=1.4925899999999999
#     After:  TP=1.09067, SL=1.48982
#
#
# === Checking Symbol: GBPJPY ===
#   Action: Buy
#     Position ID: 3304869137
#     Current TP: 197.191, Current SL: 124.777
#     Target TP: 197.191, Target SL: 124.558
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304869137 modified successfully.
#     Before: TP=197.191, SL=124.777
#     After:  TP=197.191, SL=124.558
#
#   Action: Sell
#     Position ID: 3299912193
#     Current TP: 189.588, Current SL: 262.002
#     Target TP: 189.588, Target SL: 262.002
#     ✅ No changes needed for Sell position 3299912193.
#
# === Checking Symbol: GBPMXN ===
#   Action: Buy
#     Position ID: 3285596224
#     Current TP: 26.9704, Current SL: 20.1317
#     Target TP: 26.9703, Target SL: 20.1314
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3285596224 modified successfully.
#     Before: TP=26.9704, SL=20.1317
#     After:  TP=26.9703, SL=20.1314
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: GBPNZD ===
#   Action: Buy
#     Position ID: 3310088345
#     Current TP: 2.2826, Current SL: 1.69253
#     Target TP: 2.2826, Target SL: 1.69153
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3310088345 modified successfully.
#     Before: TP=2.2826, SL=1.69253
#     After:  TP=2.2826, SL=1.69153
#
#   Action: Sell
#     Position ID: 3298767397
#     Current TP: 2.22018, Current SL: 2.81025
#     Target TP: 2.22018, Target SL: 2.81025
#     ✅ No changes needed for Sell position 3298767397.
#
# === Checking Symbol: GBPUSD ===
#   Action: Buy
#     Position ID: 3311580954
#     Current TP: 1.36147, Current SL: 0.95193
#     Target TP: 1.36147, Target SL: 0.95275
#     ⚠️ TP/SL difference detected. Attempting to update...
