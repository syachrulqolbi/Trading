# %%
# === Imports === #
import MetaTrader5 as mt5
import pandas as pd
import numpy as np
import yaml
import os
from google_sheet_api import GoogleSheetsUploader

# === Setup Paths === #
BASE_DIR = os.getcwd()
CONFIG_PATH = os.path.join(BASE_DIR, "config.yaml")
CREDENTIAL_PATH = os.path.join(BASE_DIR, "credential_google_sheets.json")

# === Load Configuration === #
def load_config(path):
    """Load configuration from YAML file."""
    with open(path, "r") as file:
        return yaml.safe_load(file)

config = load_config(CONFIG_PATH)

# === Initialize MT5 Connection === #
if not mt5.initialize():
    print("MT5 initialization failed.")
    quit()

# === Retrieve Account Information === #
account_info = mt5.account_info()
if account_info is None:
    print("Failed to retrieve account information.")
    mt5.shutdown()
    quit()

# === Extract Balance, Equity, and Floating Loss === #
balance = account_info.balance
equity = account_info.equity
floating_loss = account_info.profit

# === Display Results === #
print("=== Account Information ===")
print(f"Balance: {balance:.2f} USD")
print(f"Equity: {equity:.2f} USD")
print(f"Floating Loss: {floating_loss:.2f} USD")

# === Fetch and Process Running Trades === #
fetcher = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")
df = fetcher.get_sheet_as_dataframe("Forex")
positions = mt5.positions_get()
df_positions = pd.DataFrame([pos._asdict() for pos in positions]) if positions else pd.DataFrame()

if df_positions.empty:
    print("No running trades found. Error:", mt5.last_error())
else:
    # Filter and rename columns
    df_positions = df_positions[["type", "volume", "price_open", "price_current", "sl", "tp", "profit", "symbol"]]
    df_positions["type"] = df_positions["type"].replace({0: "Buy", 1: "Sell"})
    df_positions.rename(columns={
        "symbol": "Symbol",
        "type": "Action",
        "volume": "Lot",
        "price_open": "Price",
        "price_current": "Price Current",
        "sl": "SL",
        "tp": "TP",
        "profit": "Profit"
    }, inplace=True)

    # Aggregate by Symbol and Action
    def aggregate_group(group):
        symbol = group["Symbol"].iloc[0]
        action = group["Action"].iloc[0]
        lot = group["Lot"].sum()
        warnings = []

        # === Lot mismatch check === #
        df_lot_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[5]].sum()
        if not pd.isna(df_lot_value) and round(df_lot_value, 2) > round(lot, 2):
            warnings.append(f"Lot Mismatch: Expected {round(df_lot_value, 2)}, Found {round(lot, 2)}")

        # === SL/TP mismatch check === #
        df_sl_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[7]].sum()
        sl_mode = group["SL"].mode().iloc[0] if not group["SL"].mode().empty else np.nan
        if group["SL"].nunique() > 1 or (df_sl_value != 0 and round(df_sl_value, 2) != round(sl_mode, 2)):
            warnings.append("SL Mismatch")

        df_tp_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[8]].sum()
        tp_mode = group["TP"].mode().iloc[0] if not group["TP"].mode().empty else np.nan
        if group["TP"].nunique() > 1 or round(df_tp_value, 2) != round(tp_mode, 2):
            warnings.append("TP Mismatch")

        # Combine warnings
        warning_message = "; ".join(warnings) if warnings else np.nan

        return pd.Series({
            "Lot": lot,
            "Price": (group["Price"] * group["Lot"]).sum() / group["Lot"].sum(),
            "Price Current": group["Price Current"].mean(),
            "SL": group["SL"].mode().iloc[0] if not group["SL"].empty else np.nan,
            "TP": group["TP"].mode().iloc[0] if not group["TP"].empty else np.nan,
            "Profit": group["Profit"].sum(),
            "Warning": warning_message
        })

    df_positions = (
        df_positions.groupby(["Symbol", "Action"], as_index=False)
        .apply(lambda group: aggregate_group(group))
        .reset_index(drop=True)
    )

# === Shutdown MT5 Connection === #
mt5.shutdown()

# === Calculate Coefficients === #
df_positions["Coeff"] = np.abs(df_positions["Profit"] / (df_positions["Price Current"] - df_positions["Price"])) / (df_positions["Lot"] * 100)
df_positions["Pips"] = np.abs(df_positions["TP"] - df_positions["SL"])

# Merging the Type column based on Symbol
df_type = df[[df.columns[0], df.columns[1]]].drop_duplicates()
df_type.columns = ["Symbol", "Type"]
df_positions = pd.merge(df_positions, df_type, on="Symbol", how="left")

# Handling missing types (optional)
df_positions['Type'].fillna("Unknown", inplace=True)

df_positions

# === Update Coefficients in Config (Exclude NaN) === #
df_avg_coeff = df_positions.groupby("Symbol")["Coeff"].mean().reset_index()
differences = {}

for _, row in df_avg_coeff.iterrows():
    symbol = row["Symbol"]
    avg_coeff = round(row["Coeff"], 5)
    
    # Only update if coefficient is not NaN
    if not pd.isna(avg_coeff):
        if symbol in config.get("symbol_coefficients", {}):
            old_coeff = config["symbol_coefficients"].get(symbol, avg_coeff)
            if old_coeff != avg_coeff:
                differences[symbol] = {"Old": old_coeff, "New": avg_coeff}
        
        # Add or update the coefficient
        config["symbol_coefficients"][symbol] = avg_coeff

# === Save Updated Configuration === #
with open(CONFIG_PATH, "w") as file:
    yaml.safe_dump(config, file)

# === Display Changed Coefficients === #
print("Changed symbol_coefficients:")
for symbol, change in differences.items():
    print(f"{symbol}: {change['Old']} -> {change['New']}")

# Creating new rows for Balance, Equity, and Floating Loss
df_balance = pd.DataFrame([
    {"Symbol": "Balance", "Price": balance},
    {"Symbol": "Equity", "Price": equity},
    {"Symbol": "Floating Loss", "Price": floating_loss}
])

# Inserting the new rows at the top of the DataFrame
df_final = pd.concat([df_balance, df_positions], ignore_index=True)

# === Uploade Updated Dataframe === #
uploader = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")
uploader.upload_dataframe(df_final, "Forex Summary", replace=True)

# === Display Final Merged DataFrame === #
print("Final Merged DataFrame:")
df_final
# Out:
# === Account Information ===
# Balance: 4534.15 USD
# Equity: 4064.68 USD
# Floating Loss: -1718.35 USD
# ✅ Successfully retrieved data from 'Forex' as a DataFrame.
# C:\Users\syahr\AppData\Local\Temp\ipykernel_2552\2936804534.py:106: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda group: aggregate_group(group))
# C:\Users\syahr\AppData\Local\Temp\ipykernel_2552\2936804534.py:123: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_positions['Type'].fillna("Unknown", inplace=True)
# Changed symbol_coefficients:
# AAVEUSD: 0.5003 -> 0.50029
# AIR.EPA: 1.12322 -> 1.1193
# ALGOUSD: 25.00731 -> 24.99296
# APTUSD: 2.99977 -> 3.0009
# AUDCAD: 716.92606 -> 716.97234
# AUDCHF: 1198.95833 -> 1198.55222
# AUDJPY: 6.89162 -> 6.89053
# AUDNZD: 590.65689 -> 590.98565
# AVAXUSD: 1.00036 -> 1.00034
# AZN.LSE: 1.33284 -> 1.33333
# BATS.LSE: 1.33189 -> 1.33164
# BBVA.BM: 1.12341 -> 1.12545
# BCHUSD: 0.10017 -> 0.09993
# BEI.XE: 1.00084 -> 1.00137
# BMW.XE: 1.00063 -> 1.00067
# BNBUSD: 0.10027 -> 0.1
# BNP.EPA: 1.08108 -> 1.14458
# CADCHF: 1199.17012 -> 1198.38057
# CADJPY: 6.88828 -> 6.8958
# CHFJPY: 6.88738 -> 6.89158
# DKI.TSE: 0.00689 -> 0.0069
# ENI.MIL: 1.12025 -> 1.12121
# EURAUD: 642.60043 -> 642.41239
# EURCAD: 716.94473 -> 716.8608
# EURCHF: 1199.57537 -> 1199.57983
# EURGBP: 1332.92782 -> 1332.34955
# EURJPY: 6.89365 -> 6.89416
# EURMXN: 51.23714 -> 51.25267
# EURNZD: 590.87681 -> 591.08139
# EURZAR: 55.42763 -> 55.46321
# FETUSD: 29.99593 -> 29.99607
# FILUSD: 0.99983 -> 0.99984
# GBPAUD: 642.62766 -> 642.30161
# GBPCAD: 716.36946 -> 717.00526
# GBPCHF: 1199.37107 -> 1199.12881
# GBPJPY: 6.88917 -> 6.89096
# GBPMXN: 51.22864 -> 51.24664
# GBPNZD: 590.31141 -> 590.71887
# GBPZAR: 55.42448 -> 55.46027
# HEIA.EAS: 1.12297 -> 1.12654
# ITX.BM: 1.12142 -> 1.12011
# JAR.SGX: 0.7672 -> 0.7732
# LRCUSD: 24.98654 -> 24.98689
# MANAUSD: 10.00597 -> 10.0057
# MRK.XE: 1.00006 -> 1.00007
# MUR.TSE: 0.00689 -> 0.0069
# NEARUSD: 2.50101 -> 2.50099
# NESTE.OMXH: 1.1201 -> 1.12245
# NOKIA.OMXH: 1.1248 -> 1.1337
# NZDCAD: 717.54347 -> 716.59816
# NZDCHF: 1199.3007 -> 1197.36842
# NZDJPY: 6.89081 -> 6.89071
# OR.EPA: 1.12155 -> 1.12101
# SAN.BM: 1.13103 -> 1.12057
# SHEL.LSE: 1.33696 -> 1.34
# STLA.MIL: 1.12434 -> 1.12211
# SUIUSD: 29.98523 -> 30.00686
# SVN.TSE: 0.00689 -> 0.0069
# TM.TSE: 0.00689 -> 0.0069
# TTE.EPA: 1.12268 -> 1.12177
# UCG.MIL: 1.11413 -> 1.12245
# USDCAD: 716.8358 -> 717.59764
# USDCHF: 1199.71469 -> 1199.02575
# USDJPY: 6.88811 -> 6.88935
# USDMXN: 51.23457 -> 51.2054
# USDZAR: 55.43107 -> 55.46646
# VNA.XE: 0.99946 -> 0.99941
# VOW3.XE: 0.99696 -> 1.00299

# %%
import time
import MetaTrader5 as mt5
import pandas as pd
import os
from google_sheet_api import GoogleSheetsUploader

# === Setup Paths === #
BASE_DIR = os.getcwd()
CONFIG_PATH = os.path.join(BASE_DIR, "config.yaml")
CREDENTIAL_PATH = os.path.join(BASE_DIR, "credential_google_sheets.json")

# === Initialize MT5 Connection === #
if not mt5.initialize():
    print("MT5 initialization failed.")
    quit()

fetcher = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")

# Load DataFrame from Google Sheets
df = fetcher.get_sheet_as_dataframe("Forex")
df.columns = df.iloc[6]
df = df.iloc[7:-3].reset_index(drop=True)

# Initialize counters for success and failure
success_count = 0
failure_count = 0

# Fetch unique symbols from running trades in MT5
positions = mt5.positions_get()
if positions is None or len(positions) == 0:
    print("No running trades found. Exiting.")
    mt5.shutdown()
    quit()

# Get unique symbols from MT5 positions
symbol_list = sorted(list(set(pos.symbol for pos in positions)))

# Convert positions to DataFrame for easy filtering
df_positions = pd.DataFrame([pos._asdict() for pos in positions])

# Iterate through each unique symbol from MT5 positions
for symbol in symbol_list:
    print(f"\n=== Checking Symbol: {symbol} ===")
    for action in ["Buy", "Sell"]:
        print(f"  Action: {action}")
        action_type = 0 if action == "Buy" else 1
        filtered_positions = df_positions[(df_positions['symbol'] == symbol) & (df_positions['type'] == action_type)]
        
        if filtered_positions.empty:
            print(f"    ⚠️ No {action} positions running. Skipping.")
            continue

        # Filter rows for the current symbol and action from Google Sheets
        df_filtered = df[(df["Symbol"] == symbol) & (df["Action"] == action)]
        
        if df_filtered.empty:
            print(f"    ⚠️ No matching TP/SL settings in Google Sheets.")
            continue
        
        tp_value = round(df_filtered['TP'].values[0], 5)
        sl_value = round(df_filtered['SL'].values[0], 5)

        # Iterate over filtered positions for modification
        for _, pos in filtered_positions.iterrows():
            order_id = pos['ticket']
            current_tp = pos['tp']
            current_sl = pos['sl']

            # Check for differences and print
            print(f"    Position ID: {order_id}")
            print(f"    Current TP: {current_tp}, Current SL: {current_sl}")
            print(f"    Target TP: {tp_value}, Target SL: {sl_value}")

            if current_tp == tp_value and current_sl == sl_value:
                print(f"    ✅ No changes needed for {action} position {order_id}.")
                continue
            else:
                print(f"    ⚠️ TP/SL difference detected. Attempting to update...")

            # Modify TP/SL using position ID
            request = {
                "action": mt5.TRADE_ACTION_SLTP,
                "position": order_id,
                "sl": sl_value,
                "tp": tp_value
            }

            # Send modification request
            result = mt5.order_send(request)

            # Check if result is None (Error)
            if result is None:
                print(f"    ⚠️ Failed to modify {action} position {order_id}. Error: Request returned None.")
                failure_count += 1
                continue

            # Check if the modification was successful
            if result.retcode == mt5.TRADE_RETCODE_DONE:
                print(f"    ✅ {action} position {order_id} modified successfully.")
                print(f"    Before: TP={current_tp}, SL={current_sl}")
                print(f"    After:  TP={tp_value}, SL={sl_value}\n")
                success_count += 1
            else:
                print(f"    ⚠️ Failed to modify {action} position {order_id}. Error: {result.comment}")
                failure_count += 1

# === Shutdown MT5 Connection === #
mt5.shutdown()

# === Summary Report ===
print("\n=== TP/SL Modification Summary ===")
print(f"Total Successful Modifications: {success_count}")
print(f"Total Failed Modifications: {failure_count}")
# Out:
# ✅ Successfully retrieved data from 'Forex' as a DataFrame.
#
# === Checking Symbol: AAPL.NAS ===
#   Action: Buy
#     Position ID: 3297549570
#     Current TP: 217.47, Current SL: 67.34
#     Target TP: 217.94, Target SL: 67.35
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3297549570. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AAVEUSD ===
#   Action: Buy
#     Position ID: 3302602638
#     Current TP: 239.76, Current SL: 0.01
#     Target TP: 239, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3302602638. Error: Request returned None.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ABBV.NYSE ===
#   Action: Buy
#     Position ID: 3298446412
#     Current TP: 200.55, Current SL: 125.12
#     Target TP: 200.25, Target SL: 125.24
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3298446412. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ABNB.NAS ===
#   Action: Buy
#     Position ID: 3304860529
#     Current TP: 140.02, Current SL: 0.01
#     Target TP: 139.67, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304860529. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ABT.NYSE ===
#   Action: Buy
#     Position ID: 3302221724
#     Current TP: 136.36, Current SL: 77.77
#     Target TP: 136.23, Target SL: 77.88
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3302221724. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ACN.NYSE ===
#   Action: Buy
#     Position ID: 3304837038
#     Current TP: 328.41, Current SL: 206.52
#     Target TP: 327.59, Target SL: 206.585
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304837038. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ADAUSD ===
#   Action: Buy
#     Position ID: 3304100487
#     Current TP: 0.8554, Current SL: 0.01
#     Target TP: 0.8556, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304100487 modified successfully.
#     Before: TP=0.8554, SL=0.01
#     After:  TP=0.8556, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ADS.XE ===
#   Action: Buy
#     Position ID: 3305209594
#     Current TP: 226.507, Current SL: 86.94
#     Target TP: 225.654, Target SL: 87.02
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305209594. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AI.EPA ===
#   Action: Buy
#     Position ID: 3297913700
#     Current TP: 186.37, Current SL: 120.24
#     Target TP: 186.26, Target SL: 120.59
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3297913700. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AIR.EPA ===
#   Action: Buy
#     Position ID: 3305210944
#     Current TP: 164.25, Current SL: 49.44
#     Target TP: 164.85, Target SL: 49.6818
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305210944. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ALGOUSD ===
#   Action: Buy
#     Position ID: 3304100698
#     Current TP: 0.263, Current SL: 0.01
#     Target TP: 0.2625, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304100698 modified successfully.
#     Before: TP=0.263, SL=0.01
#     After:  TP=0.2625, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AMD.NAS ===
#   Action: Buy
#     Position ID: 3305638599
#     Current TP: 121.86, Current SL: 0.01
#     Target TP: 122.22, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305638599. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: APTUSD ===
#   Action: Buy
#     Position ID: 3303173396
#     Current TP: 6.4446, Current SL: 0.001
#     Target TP: 6.4591, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303173396 modified successfully.
#     Before: TP=6.4446, SL=0.001
#     After:  TP=6.4591, SL=0.001
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ATOMUSD ===
#   Action: Buy
#     Position ID: 3303174194
#     Current TP: 5.571, Current SL: 0.0
#     Target TP: 5.563, Target SL: 1e-05
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303174194 modified successfully.
#     Before: TP=5.571, SL=0.0
#     After:  TP=5.563, SL=1e-05
#
#     Position ID: 3304176535
#     Current TP: 5.571, Current SL: 0.0
#     Target TP: 5.563, Target SL: 1e-05
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304176535 modified successfully.
#     Before: TP=5.571, SL=0.0
#     After:  TP=5.563, SL=1e-05
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AUDCAD ===
#   Action: Buy
#     Position ID: 3304834368
#     Current TP: 0.90446, Current SL: 0.74395
#     Target TP: 0.90072, Target SL: 0.74346
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304834368 modified successfully.
#     Before: TP=0.90446, SL=0.74395
#     After:  TP=0.90072, SL=0.74346
#
#   Action: Sell
#     Position ID: 3301252618
#     Current TP: 0.88671, Current SL: 1.04722
#     Target TP: 0.89042, Target SL: 1.05093
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3301252618 modified successfully.
#     Before: TP=0.88671, SL=1.04722
#     After:  TP=0.89042, SL=1.05093
#
#     Position ID: 3304223072
#     Current TP: 0.88671, Current SL: 1.04722
#     Target TP: 0.89042, Target SL: 1.05093
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304223072 modified successfully.
#     Before: TP=0.88671, SL=1.04722
#     After:  TP=0.89042, SL=1.05093
#
#     Position ID: 3304229587
#     Current TP: 0.88671, Current SL: 1.04722
#     Target TP: 0.89042, Target SL: 1.05093
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304229587 modified successfully.
#     Before: TP=0.88671, SL=1.04722
#     After:  TP=0.89042, SL=1.05093
#
#
# === Checking Symbol: AUDCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3296721794
#     Current TP: 0.52338, Current SL: 0.73721
#     Target TP: 0.52091, Target SL: 0.522
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Sell position 3296721794. Error: Invalid stops
#
# === Checking Symbol: AUDJPY ===
#   Action: Buy
#     Position ID: 3304837518
#     Current TP: 95.918, Current SL: 67.106
#     Target TP: 96.271, Target SL: 67.075
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304837518 modified successfully.
#     Before: TP=95.918, SL=67.106
#     After:  TP=96.271, SL=67.075
#
#   Action: Sell
#     Position ID: 3295995295
#     Current TP: 92.105, Current SL: 120.917
#     Target TP: 91.762, Target SL: 120.574
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3295995295 modified successfully.
#     Before: TP=92.105, SL=120.917
#     After:  TP=91.762, SL=120.574
#
#     Position ID: 3304223099
#     Current TP: 92.105, Current SL: 120.917
#     Target TP: 91.762, Target SL: 120.574
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304223099 modified successfully.
#     Before: TP=92.105, SL=120.917
#     After:  TP=91.762, SL=120.574
#
#
# === Checking Symbol: AUDNZD ===
#   Action: Buy
#     Position ID: 3305835701
#     Current TP: 1.09514, Current SL: 0.94957
#     Target TP: 1.09164, Target SL: 0.94918
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3305835701 modified successfully.
#     Before: TP=1.09514, SL=0.94957
#     After:  TP=1.09164, SL=0.94918
#
#   Action: Sell
#     Position ID: 3285918930
#     Current TP: 1.08119, Current SL: 1.22676
#     Target TP: 1.08467, Target SL: 1.23024
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3285918930 modified successfully.
#     Before: TP=1.08119, SL=1.22676
#     After:  TP=1.08467, SL=1.23024
#
#     Position ID: 3304223126
#     Current TP: 1.08119, Current SL: 1.22676
#     Target TP: 1.08467, Target SL: 1.23024
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304223126 modified successfully.
#     Before: TP=1.08119, SL=1.22676
#     After:  TP=1.08467, SL=1.23024
#
#
# === Checking Symbol: AUDUSD ===
#   Action: Buy
#     Position ID: 3304888719
#     Current TP: 0.65114, Current SL: 0.5
#     Target TP: 0.65332, Target SL: 0.5
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304888719 modified successfully.
#     Before: TP=0.65114, SL=0.5
#     After:  TP=0.65332, SL=0.5
#
#   Action: Sell
#     Position ID: 3304180166
#     Current TP: 0.63238, Current SL: 0.78352
#     Target TP: 0.63024, Target SL: 0.78138
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304180166 modified successfully.
#     Before: TP=0.63238, SL=0.78352
#     After:  TP=0.63024, SL=0.78138
#
#     Position ID: 3304223991
#     Current TP: 0.63238, Current SL: 0.78352
#     Target TP: 0.63024, Target SL: 0.78138
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304223991 modified successfully.
#     Before: TP=0.63238, SL=0.78352
#     After:  TP=0.63024, SL=0.78138
#
#
# === Checking Symbol: AVAXUSD ===
#   Action: Buy
#     Position ID: 3303762188
#     Current TP: 26.805, Current SL: 0.01
#     Target TP: 26.705, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303762188 modified successfully.
#     Before: TP=26.805, SL=0.01
#     After:  TP=26.705, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AVGO.NAS ===
#   Action: Buy
#     Position ID: 3304947624
#     Current TP: 236.18, Current SL: 126.58
#     Target TP: 236.99, Target SL: 127.78
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304947624. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AXSUSD ===
#   Action: Buy
#     Position ID: 3305014875
#     Current TP: 3.92, Current SL: 0.01
#     Target TP: 3.93, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3305014875 modified successfully.
#     Before: TP=3.92, SL=0.01
#     After:  TP=3.93, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AZN.LSE ===
#   Action: Buy
#     Position ID: 3299847401
#     Current TP: 109.4, Current SL: 69.83
#     Target TP: 109.24, Target SL: 69.84
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3299847401. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BABA.NYSE ===
#   Action: Buy
#     Position ID: 3304102868
#     Current TP: 135.37, Current SL: 0.01
#     Target TP: 135.6, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304102868. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BAC.NYSE ===
#   Action: Buy
#     Position ID: 3304888731
#     Current TP: 45.16, Current SL: 8.98
#     Target TP: 45.34, Target SL: 8.9916
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304888731. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BARC.LSE ===
#   Action: Buy
#     Position ID: 3303762395
#     Current TP: 3.2833, Current SL: 0.0001
#     Target TP: 3.2934, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303762395. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BATS.LSE ===
#   Action: Buy
#     Position ID: 3299872790
#     Current TP: 33.67, Current SL: 15.482
#     Target TP: 33.622, Target SL: 15.42
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3299872790. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BAYN.FWB ===
#   Action: Buy
#     Position ID: 3305209875
#     Current TP: 25.05, Current SL: 0.01
#     Target TP: 24.96, Target SL: 0.0001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305209875. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BBVA.BM ===
#   Action: Buy
#     Position ID: 3304865845
#     Current TP: 13.5373, Current SL: 3.4817
#     Target TP: 13.471, Target SL: 3.49
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304865845. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BCHUSD ===
#   Action: Buy
#     Position ID: 3301497543
#     Current TP: 435.23, Current SL: 0.0
#     Target TP: 436.34, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3301497543 modified successfully.
#     Before: TP=435.23, SL=0.0
#     After:  TP=436.34, SL=0.001
#
#     Position ID: 3303230992
#     Current TP: 435.23, Current SL: 0.0
#     Target TP: 436.34, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303230992 modified successfully.
#     Before: TP=435.23, SL=0.0
#     After:  TP=436.34, SL=0.001
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BEI.XE ===
#   Action: Buy
#     Position ID: 3299405469
#     Current TP: 125.112, Current SL: 83.505
#     Target TP: 124.93, Target SL: 82.56
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3299405469. Error: Market closed
#     Position ID: 3303762634
#     Current TP: 125.112, Current SL: 83.505
#     Target TP: 124.93, Target SL: 82.56
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303762634. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BHP.ASX ===
#   Action: Buy
#     Position ID: 3305001253
#     Current TP: 39.76, Current SL: 22.25
#     Target TP: 39.67, Target SL: 21.87
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305001253. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BMW.XE ===
#   Action: Buy
#     Position ID: 3305210030
#     Current TP: 85.07, Current SL: 33.316
#     Target TP: 84.671, Target SL: 31.52
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305210030. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BMY.NYSE ===
#   Action: Buy
#     Position ID: 3300219853
#     Current TP: 49.03, Current SL: 27.52
#     Target TP: 48.93, Target SL: 27.52
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3300219853. Error: Market closed
#     Position ID: 3304109863
#     Current TP: 49.03, Current SL: 27.52
#     Target TP: 48.93, Target SL: 27.52
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304109863. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BNBUSD ===
#   Action: Buy
#     Position ID: 3303003080
#     Current TP: 693.54, Current SL: 0.0
#     Target TP: 692.32, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303003080 modified successfully.
#     Before: TP=693.54, SL=0.0
#     After:  TP=692.32, SL=0.001
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BNP.EPA ===
#   Action: Buy
#     Position ID: 3305269306
#     Current TP: 80.891, Current SL: 23.202
#     Target TP: 81.236, Target SL: 23.52
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305269306. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BX.NYSE ===
#   Action: Buy
#     Position ID: 3304110024
#     Current TP: 150.74, Current SL: 39.62
#     Target TP: 150.99, Target SL: 38.3498
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304110024. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CADCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3295246044
#     Current TP: 0.59027, Current SL: 0.79516
#     Target TP: 0.59306, Target SL: 0.594
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Sell position 3295246044. Error: Invalid stops
#
# === Checking Symbol: CADJPY ===
#   Action: Buy
#     Position ID: 3303757604
#     Current TP: 106.674, Current SL: 80.532
#     Target TP: 107.123, Target SL: 80.548
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303757604 modified successfully.
#     Before: TP=106.674, SL=80.532
#     After:  TP=107.123, SL=80.548
#
#     Position ID: 3304223147
#     Current TP: 106.674, Current SL: 80.532
#     Target TP: 107.123, Target SL: 80.548
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304223147 modified successfully.
#     Before: TP=106.674, SL=80.532
#     After:  TP=107.123, SL=80.548
#
#   Action: Sell
#     Position ID: 3291088065
#     Current TP: 103.23, Current SL: 129.37
#     Target TP: 102.79, Target SL: 128.93
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3291088065 modified successfully.
#     Before: TP=103.23, SL=129.37
#     After:  TP=102.79, SL=128.93
#
#     Position ID: 3304223149
#     Current TP: 103.23, Current SL: 129.37
#     Target TP: 102.79, Target SL: 128.93
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304223149 modified successfully.
#     Before: TP=103.23, SL=129.37
#     After:  TP=102.79, SL=128.93
#
#
# === Checking Symbol: CBA.ASX ===
#   Action: Buy
#     Position ID: 3303445304
#     Current TP: 169.95, Current SL: 96.08
#     Target TP: 170.19, Target SL: 95.713
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303445304. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CHFJPY ===
#   Action: Buy
#     Position ID: 3298014085
#     Current TP: 176.525, Current SL: 135.57
#     Target TP: 175.711, Target SL: 135.58
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3298014085 modified successfully.
#     Before: TP=176.525, SL=135.57
#     After:  TP=175.711, SL=135.58
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CMCSA.NAS ===
#   Action: Buy
#     Position ID: 3304114376
#     Current TP: 35.42, Current SL: 18.33
#     Target TP: 35.27, Target SL: 18.34
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304114376. Error: Invalid stops
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: COP.NYSE ===
#   Action: Buy
#     Position ID: 3280209232
#     Current TP: 96.56, Current SL: 42.87
#     Target TP: 96.16, Target SL: 42.83
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3280209232. Error: Market closed
#     Position ID: 3293935589
#     Current TP: 96.56, Current SL: 42.87
#     Target TP: 96.16, Target SL: 42.83
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293935589. Error: Market closed
#     Position ID: 3293935927
#     Current TP: 96.56, Current SL: 42.87
#     Target TP: 96.16, Target SL: 42.83
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293935927. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CSCO.NAS ===
#   Action: Buy
#     Position ID: 3306357971
#     Current TP: 66.08, Current SL: 18.38
#     Target TP: 66.36, Target SL: 18.43
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3306357971. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CSL.ASX ===
#   Action: Buy
#     Position ID: 3298768130
#     Current TP: 261.34, Current SL: 185.62
#     Target TP: 261.34, Target SL: 146.57
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3298768130. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CVS.NYSE ===
#   Action: Buy
#     Position ID: 3298338209
#     Current TP: 68.74, Current SL: 29.48
#     Target TP: 68.54, Target SL: 29.48
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3298338209. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DAII.TSE ===
#   Action: Buy
#     Position ID: 3300540962
#     Current TP: 3570.03, Current SL: 2769.87
#     Target TP: 3555.3, Target SL: 2780.29
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3300540962. Error: Market closed
#     Position ID: 3303520468
#     Current TP: 3570.03, Current SL: 2769.87
#     Target TP: 3555.3, Target SL: 2780.29
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303520468. Error: Market closed
#     Position ID: 3303520689
#     Current TP: 3570.03, Current SL: 2769.87
#     Target TP: 3555.3, Target SL: 2780.29
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303520689. Error: Market closed
#     Position ID: 3304239778
#     Current TP: 3570.03, Current SL: 2769.87
#     Target TP: 3555.3, Target SL: 2780.29
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304239778. Error: Market closed
#     Position ID: 3304268865
#     Current TP: 3570.03, Current SL: 2769.87
#     Target TP: 3555.3, Target SL: 2780.29
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304268865. Error: Market closed
#     Position ID: 3304269062
#     Current TP: 3570.03, Current SL: 2769.87
#     Target TP: 3555.3, Target SL: 2780.29
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304269062. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DASHUSD ===
#   Action: Buy
#     Position ID: 3303173212
#     Current TP: 26.18, Current SL: 0.01
#     Target TP: 26.28, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303173212 modified successfully.
#     Before: TP=26.18, SL=0.01
#     After:  TP=26.28, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DHR.NYSE ===
#   Action: Buy
#     Position ID: 3304176735
#     Current TP: 202.29, Current SL: 161.61
#     Target TP: 201.95, Target SL: 161.52
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304176735. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DIS.NYSE ===
#   Action: Buy
#     Position ID: 3304837280
#     Current TP: 113.49, Current SL: 44.45
#     Target TP: 113.14, Target SL: 44.46
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304837280. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DKI.TSE ===
#   Action: Buy
#     Position ID: 3297726752
#     Current TP: 17496.11, Current SL: 9421.82
#     Target TP: 17563.79, Target SL: 9427.71118
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3297726752. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DOTUSD ===
#   Action: Buy
#     Position ID: 3303763159
#     Current TP: 5.441, Current SL: 0.01
#     Target TP: 5.454, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303763159 modified successfully.
#     Before: TP=5.441, SL=0.01
#     After:  TP=5.454, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ENI.MIL ===
#   Action: Buy
#     Position ID: 3303763971
#     Current TP: 13.526, Current SL: 6.6690000000000005
#     Target TP: 13.499, Target SL: 6.7
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303763971. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ETCUSD ===
#   Action: Buy
#     Position ID: 3303173265
#     Current TP: 21.248, Current SL: 0.01
#     Target TP: 21.317, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303173265 modified successfully.
#     Before: TP=21.248, SL=0.01
#     After:  TP=21.317, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: EURAUD ===
#   Action: Buy
#     Position ID: 3293418441
#     Current TP: 1.78078, Current SL: 1.37276
#     Target TP: 1.77279, Target SL: 1.3737
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3293418441 modified successfully.
#     Before: TP=1.78078, SL=1.37276
#     After:  TP=1.77279, SL=1.3737
#
#   Action: Sell
#     Position ID: 3304856822
#     Current TP: 1.71953, Current SL: 2.12755
#     Target TP: 1.72731, Target SL: 2.13533
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304856822 modified successfully.
#     Before: TP=1.71953, SL=2.12755
#     After:  TP=1.72731, SL=2.13533
#
#
# === Checking Symbol: EURCAD ===
#   Action: Buy
#     Position ID: 3306063736
#     Current TP: 1.57347, Current SL: 1.24019
#     Target TP: 1.56699, Target SL: 1.24018
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3306063736 modified successfully.
#     Before: TP=1.57347, SL=1.24019
#     After:  TP=1.56699, SL=1.24018
#
#   Action: Sell
#     Position ID: 3303757395
#     Current TP: 1.54474, Current SL: 1.87802
#     Target TP: 1.55115, Target SL: 1.88443
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3303757395 modified successfully.
#     Before: TP=1.54474, SL=1.87802
#     After:  TP=1.55115, SL=1.88443
#
#     Position ID: 3304223178
#     Current TP: 1.54474, Current SL: 1.87802
#     Target TP: 1.55115, Target SL: 1.88443
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304223178 modified successfully.
#     Before: TP=1.54474, SL=1.87802
#     After:  TP=1.55115, SL=1.88443
#
#
# === Checking Symbol: EURCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3299527080
#     Current TP: 0.92792, Current SL: 1.06895
#     Target TP: 0.93027, Target SL: 0.93028
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Sell position 3299527080. Error: Invalid stops
#
# === Checking Symbol: EURGBP ===
#   Action: Buy
#     Position ID: 3293418914
#     Current TP: 0.85066, Current SL: 0.7278
#     Target TP: 0.84753, Target SL: 0.72805
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3293418914 modified successfully.
#     Before: TP=0.85066, SL=0.7278
#     After:  TP=0.84753, SL=0.72805
#
#     Position ID: 3304223185
#     Current TP: 0.85066, Current SL: 0.7278
#     Target TP: 0.84753, Target SL: 0.72805
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304223185 modified successfully.
#     Before: TP=0.85066, SL=0.7278
#     After:  TP=0.84753, SL=0.72805
#
#   Action: Sell
#     Position ID: 3303756772
#     Current TP: 0.8393, Current SL: 0.962
#     Target TP: 0.84242, Target SL: 0.965
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Sell position 3303756772. Error: Invalid stops
#     Position ID: 3304223191
#     Current TP: 0.8393, Current SL: 0.962
#     Target TP: 0.84242, Target SL: 0.965
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Sell position 3304223191. Error: Invalid stops
#
# === Checking Symbol: EURJPY ===
#   Action: Buy
#     Position ID: 3304179775
#     Current TP: 165.483, Current SL: 123.877
#     Target TP: 164.662, Target SL: 123.883
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304179775 modified successfully.
#     Before: TP=165.483, SL=123.877
#     After:  TP=164.662, SL=123.883
#
#   Action: Sell
#     Position ID: 3293419124
#     Current TP: 161.477, Current SL: 203.083
#     Target TP: 162.286, Target SL: 203.892
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3293419124 modified successfully.
#     Before: TP=161.477, SL=203.083
#     After:  TP=162.286, SL=203.892
#
#
# === Checking Symbol: EURMXN ===
#   Action: Buy
#     Position ID: 3293419757
#     Current TP: 22.39, Current SL: 17.2962
#     Target TP: 22.4725, Target SL: 17.31314
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3293419757 modified successfully.
#     Before: TP=22.39, SL=17.2962
#     After:  TP=22.4725, SL=17.31314
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: EURNZD ===
#   Action: Buy
#     Position ID: 3295753416
#     Current TP: 1.9140899999999998, Current SL: 1.49011
#     Target TP: 1.90506, Target SL: 1.49061
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3295753416 modified successfully.
#     Before: TP=1.9140899999999998, SL=1.49011
#     After:  TP=1.90506, SL=1.49061
#
#     Position ID: 3304243214
#     Current TP: 1.9140899999999998, Current SL: 1.49011
#     Target TP: 1.90506, Target SL: 1.49061
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304243214 modified successfully.
#     Before: TP=1.9140899999999998, SL=1.49011
#     After:  TP=1.90506, SL=1.49061
#
#   Action: Sell
#     Position ID: 3304459498
#     Current TP: 1.87539, Current SL: 2.29937
#     Target TP: 1.88433, Target SL: 2.30831
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304459498 modified successfully.
#     Before: TP=1.87539, SL=2.29937
#     After:  TP=1.88433, SL=2.30831
#
#
# === Checking Symbol: EURUSD ===
#   Action: Buy
#     Position ID: 3297343009
#     Current TP: 1.1371, Current SL: 0.84005
#     Target TP: 1.13213, Target SL: 0.84001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3297343009 modified successfully.
#     Before: TP=1.1371, SL=0.84005
#     After:  TP=1.13213, SL=0.84001
#
#   Action: Sell
#     Position ID: 3303757469
#     Current TP: 1.10566, Current SL: 1.40271
#     Target TP: 1.11053, Target SL: 1.40758
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3303757469 modified successfully.
#     Before: TP=1.10566, SL=1.40271
#     After:  TP=1.11053, SL=1.40758
#
#
# === Checking Symbol: EURZAR ===
#   Action: Buy
#     Position ID: 3297344129
#     Current TP: 21.24955, Current SL: 15.1
#     Target TP: 21.30856, Target SL: 15.2
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3297344129 modified successfully.
#     Before: TP=21.24955, SL=15.1
#     After:  TP=21.30856, SL=15.2
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: FETUSD ===
#   Action: Buy
#     Position ID: 3303216662
#     Current TP: 0.9163, Current SL: 0.001
#     Target TP: 0.9146, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303216662 modified successfully.
#     Before: TP=0.9163, SL=0.001
#     After:  TP=0.9146, SL=0.001
#
#     Position ID: 3303226695
#     Current TP: 0.9163, Current SL: 0.001
#     Target TP: 0.9146, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303226695 modified successfully.
#     Before: TP=0.9163, SL=0.001
#     After:  TP=0.9146, SL=0.001
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: FILUSD ===
#   Action: Buy
#     Position ID: 3302580433
#     Current TP: 3.289, Current SL: 0.1
#     Target TP: 3.282, Target SL: 0.1
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3302580433 modified successfully.
#     Before: TP=3.289, SL=0.1
#     After:  TP=3.282, SL=0.1
#
#     Position ID: 3303239649
#     Current TP: 3.289, Current SL: 0.1
#     Target TP: 3.282, Target SL: 0.1
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303239649 modified successfully.
#     Before: TP=3.289, SL=0.1
#     After:  TP=3.282, SL=0.1
#
#     Position ID: 3303770477
#     Current TP: 3.289, Current SL: 0.1
#     Target TP: 3.282, Target SL: 0.1
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303770477 modified successfully.
#     Before: TP=3.289, SL=0.1
#     After:  TP=3.282, SL=0.1
#
#     Position ID: 3304121459
#     Current TP: 3.289, Current SL: 0.1
#     Target TP: 3.282, Target SL: 0.1
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304121459 modified successfully.
#     Before: TP=3.289, SL=0.1
#     After:  TP=3.282, SL=0.1
#
#     Position ID: 3304219700
#     Current TP: 3.289, Current SL: 0.1
#     Target TP: 3.282, Target SL: 0.1
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304219700 modified successfully.
#     Before: TP=3.289, SL=0.1
#     After:  TP=3.282, SL=0.1
#
#     Position ID: 3304239787
#     Current TP: 3.289, Current SL: 0.1
#     Target TP: 3.282, Target SL: 0.1
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304239787 modified successfully.
#     Before: TP=3.289, SL=0.1
#     After:  TP=3.282, SL=0.1
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: GBPAUD ===
#   Action: Buy
#     Position ID: 3297344455
#     Current TP: 2.09625, Current SL: 1.55257
#     Target TP: 2.08656, Target SL: 1.55321
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3297344455 modified successfully.
#     Before: TP=2.09625, SL=1.55257
#     After:  TP=2.08656, SL=1.55321
#
#   Action: Sell
#     Position ID: 3299102816
#     Current TP: 2.03971, Current SL: 2.58339
#     Target TP: 2.04923, Target SL: 2.59291
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3299102816 modified successfully.
#     Before: TP=2.03971, SL=2.58339
#     After:  TP=2.04923, SL=2.59291
#
#
# === Checking Symbol: GBPCAD ===
#   Action: Buy
#     Position ID: 3306357661
#     Current TP: 1.8683100000000001, Current SL: 1.4161000000000001
#     Target TP: 1.8604, Target SL: 1.41561
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3306357661 modified successfully.
#     Before: TP=1.8683100000000001, SL=1.4161000000000001
#     After:  TP=1.8604, SL=1.41561
#
#   Action: Sell
#     Position ID: 3297345453
#     Current TP: 1.8334899999999998, Current SL: 2.2857
#     Target TP: 1.84132, Target SL: 2.29353
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3297345453 modified successfully.
#     Before: TP=1.8334899999999998, SL=2.2857
#     After:  TP=1.84132, SL=2.29353
#
#
# === Checking Symbol: GBPCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3298014406
#     Current TP: 1.09067, Current SL: 1.31762
#     Target TP: 1.09526, Target SL: 1.096
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Sell position 3298014406. Error: Invalid stops
#
# === Checking Symbol: GBPJPY ===
#   Action: Buy
#     Position ID: 3304869137
#     Current TP: 197.192, Current SL: 124.726
#     Target TP: 198.105, Target SL: 124.6912
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304869137 modified successfully.
#     Before: TP=197.192, SL=124.726
#     After:  TP=198.105, SL=124.6912
#
#   Action: Sell
#     Position ID: 3299912193
#     Current TP: 189.588, Current SL: 262.054
#     Target TP: 188.7, Target SL: 261.166
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3299912193 modified successfully.
#     Before: TP=189.588, SL=262.054
#     After:  TP=188.7, SL=261.166
#
#
# === Checking Symbol: GBPMXN ===
#   Action: Buy
#     Position ID: 3285596224
#     Current TP: 26.9705, Current SL: 20.1394
#     Target TP: 27.0844, Target SL: 20.15083
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3285596224 modified successfully.
#     Before: TP=26.9705, SL=20.1394
#     After:  TP=27.0844, SL=20.15083
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: GBPNZD ===
#   Action: Buy
#     Position ID: 3306196637
#     Current TP: 2.27157, Current SL: 1.69034
#     Target TP: 2.2605, Target SL: 1.69025
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3306196637 modified successfully.
#     Before: TP=2.27157, SL=1.69034
#     After:  TP=2.2605, SL=1.69025
#
#   Action: Sell
#     Position ID: 3298767397
#     Current TP: 2.22017, Current SL: 2.8014
#     Target TP: 2.2311, Target SL: 2.81233
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3298767397 modified successfully.
#     Before: TP=2.22017, SL=2.8014
#     After:  TP=2.2311, SL=2.81233
#
#
# === Checking Symbol: GBPUSD ===
#   Action: Buy
#     Position ID: 3295254715
#     Current TP: 1.34955, Current SL: 0.951
#     Target TP: 1.3438, Target SL: 0.95071
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3295254715 modified successfully.
#     Before: TP=1.34955, SL=0.951
#     After:  TP=1.3438, SL=0.95071
#
#   Action: Sell
#     Position ID: 3303757685
#     Current TP: 1.3115700000000001, Current SL: 1.7101199999999999
#     Target TP: 1.31721, Target SL: 1.71576
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3303757685 modified successfully.
#     Before: TP=1.3115700000000001, SL=1.7101199999999999
#     After:  TP=1.31721, SL=1.71576
#
#
# === Checking Symbol: GBPZAR ===
#   Action: Buy
#     Position ID: 3297347553
#     Current TP: 25.0169, Current SL: 17.68
#     Target TP: 25.08803, Target SL: 17.69
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3297347553 modified successfully.
#     Before: TP=25.0169, SL=17.68
#     After:  TP=25.08803, SL=17.69
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: GOOGL.NAS ===
#   Action: Buy
#     Position ID: 3305701654
#     Current TP: 168.52, Current SL: 95.4
#     Target TP: 167.99, Target SL: 95.44
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305701654. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HEIA.EAS ===
#   Action: Buy
#     Position ID: 3300760802
#     Current TP: 80.275, Current SL: 50.445
#     Target TP: 80.233, Target SL: 50.05
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3300760802. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HIT.TSE ===
#   Action: Buy
#     Position ID: 3303449468
#     Current TP: 3938.4, Current SL: 1156.75
#     Target TP: 3955.97, Target SL: 1150.41
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303449468. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HMC.NYSE ===
#   Action: Buy
#     Position ID: 3295995003
#     Current TP: 31.33, Current SL: 0.01
#     Target TP: 31.23, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3295995003. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HON.NAS ===
#   Action: Buy
#     Position ID: 3306521821
#     Current TP: 225.33, Current SL: 88.46
#     Target TP: 224.74, Target SL: 88.4363
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3306521821. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HSBA.LSE ===
#   Action: Buy
#     Position ID: 3303764157
#     Current TP: 8.97, Current SL: 0.0001
#     Target TP: 8.9534, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303764157. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: IBM.NYSE ===
#   Action: Buy
#     Position ID: 3306359013
#     Current TP: 0.0, Current SL: 0.0
#     Target TP: 265.28, Target SL: 131.32
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3306359013. Error: Invalid stops
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: INTC.NAS ===
#   Action: Buy
#     Position ID: 3304188828
#     Current TP: 22.89, Current SL: 0.01
#     Target TP: 22.96, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304188828. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: IOTAUSD ===
#   Action: Buy
#     Position ID: 3303174051
#     Current TP: 0.2668, Current SL: 0.0001
#     Target TP: 0.2672, Target SL: 0.0001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303174051 modified successfully.
#     Before: TP=0.2668, SL=0.0001
#     After:  TP=0.2672, SL=0.0001
#
#     Position ID: 3304127077
#     Current TP: 0.2668, Current SL: 0.0001
#     Target TP: 0.2672, Target SL: 0.0001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304127077 modified successfully.
#     Before: TP=0.2668, SL=0.0001
#     After:  TP=0.2672, SL=0.0001
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ISP.MIL ===
#   Action: Buy
#     Position ID: 3302854899
#     Current TP: 5.0376, Current SL: 1.0951
#     Target TP: 5.0531, Target SL: 1.1
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3302854899. Error: Market closed
#     Position ID: 3304492379
#     Current TP: 5.0376, Current SL: 1.0951
#     Target TP: 5.0531, Target SL: 1.1
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304492379. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ITX.BM ===
#   Action: Buy
#     Position ID: 3294683715
#     Current TP: 50.406, Current SL: 29.787
#     Target TP: 50.291, Target SL: 29.68
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3294683715. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: JAR.SGX ===
#   Action: Buy
#     Position ID: 3279704752
#     Current TP: 26.44, Current SL: 0.01
#     Target TP: 26.32, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3279704752 modified successfully.
#     Before: TP=26.44, SL=0.01
#     After:  TP=26.32, SL=0.01
#
#     Position ID: 3293425477
#     Current TP: 26.44, Current SL: 0.01
#     Target TP: 26.32, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3293425477 modified successfully.
#     Before: TP=26.44, SL=0.01
#     After:  TP=26.32, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: JD.NAS ===
#   Action: Buy
#     Position ID: 3304860748
#     Current TP: 38.37, Current SL: 0.01
#     Target TP: 38.3, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304860748. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: JNJ.NYSE ===
#   Action: Buy
#     Position ID: 3278886088
#     Current TP: 159.07, Current SL: 110.73
#     Target TP: 159.26, Target SL: 110.74
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3278886088. Error: Market closed
#     Position ID: 3293954893
#     Current TP: 159.07, Current SL: 110.73
#     Target TP: 159.26, Target SL: 110.74
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293954893. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: KO.NYSE ===
#   Action: Buy
#     Position ID: 3296715805
#     Current TP: 73.09, Current SL: 42.56
#     Target TP: 73.14, Target SL: 42.69
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3296715805. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LI.NAS ===
#   Action: Buy
#     Position ID: 3304127280
#     Current TP: 29.05, Current SL: 0.01
#     Target TP: 28.98, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304127280. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LINKUSD ===
#   Action: Buy
#     Position ID: 3303764332
#     Current TP: 18.099, Current SL: 0.01
#     Target TP: 18.018, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303764332 modified successfully.
#     Before: TP=18.099, SL=0.01
#     After:  TP=18.018, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LRCUSD ===
#   Action: Buy
#     Position ID: 3299514904
#     Current TP: 0.1288, Current SL: 0.01
#     Target TP: 0.129, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3299514904 modified successfully.
#     Before: TP=0.1288, SL=0.01
#     After:  TP=0.129, SL=0.01
#
#     Position ID: 3304127358
#     Current TP: 0.1288, Current SL: 0.01
#     Target TP: 0.129, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304127358 modified successfully.
#     Before: TP=0.1288, SL=0.01
#     After:  TP=0.129, SL=0.01
#
#     Position ID: 3306729027
#     Current TP: 0.1288, Current SL: 0.01
#     Target TP: 0.129, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3306729027 modified successfully.
#     Before: TP=0.1288, SL=0.01
#     After:  TP=0.129, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LSEG.LSE ===
#   Action: Buy
#     Position ID: 3292134139
#     Current TP: 117.76, Current SL: 46.75
#     Target TP: 117.39, Target SL: 46.59
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3292134139. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LTCUSD ===
#   Action: Buy
#     Position ID: 3303003157
#     Current TP: 108.22, Current SL: 0.01
#     Target TP: 107.87, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303003157 modified successfully.
#     Before: TP=108.22, SL=0.01
#     After:  TP=107.87, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MANAUSD ===
#   Action: Buy
#     Position ID: 3303174266
#     Current TP: 0.4002, Current SL: 0.01
#     Target TP: 0.4016, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303174266 modified successfully.
#     Before: TP=0.4002, SL=0.01
#     After:  TP=0.4016, SL=0.01
#
#     Position ID: 3303239684
#     Current TP: 0.4002, Current SL: 0.01
#     Target TP: 0.4016, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
# ...
#     Position ID: 3304239917
#     Current TP: 2365.88, Current SL: 1388.19
#     Target TP: 2361.57, Target SL: 1393.76
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304239917. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: T.NYSE ===
#   Action: Buy
#     Position ID: 3301254934
#     Current TP: 28.29, Current SL: 14.33
#     Target TP: 28.25, Target SL: 14.346
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3301254934. Error: Market closed
#     Position ID: 3304132650
#     Current TP: 28.29, Current SL: 14.33
#     Target TP: 28.25, Target SL: 14.346
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304132650. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TCEHY.OTC ===
#   Action: Buy
#     Position ID: 3305638500
#     Current TP: 67.995, Current SL: 24.101
#     Target TP: 68.187, Target SL: 24.19
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305638500. Error: Market closed
#     Position ID: 3306359369
#     Current TP: 67.995, Current SL: 24.101
#     Target TP: 68.187, Target SL: 24.19
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3306359369. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TKY.TSE ===
#   Action: Buy
#     Position ID: 3305001170
#     Current TP: 24822.96, Current SL: 7864.22
#     Target TP: 24834.45, Target SL: 7832.51
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305001170. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TM.TSE ===
#   Action: Buy
#     Position ID: 3304242075
#     Current TP: 2914.99, Current SL: 1485.32
#     Target TP: 2906.12, Target SL: 1480.54
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304242075. Error: Market closed
#     Position ID: 3304380529
#     Current TP: 2914.99, Current SL: 1485.32
#     Target TP: 2906.12, Target SL: 1480.54
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304380529. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TMH.TSE ===
#   Action: Buy
#     Position ID: 3303450840
#     Current TP: 6199.57, Current SL: 0.01
#     Target TP: 6213.27, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303450840. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TMO.NYSE ===
#   Action: Buy
#     Position ID: 3295995689
#     Current TP: 435.52, Current SL: 254.71
#     Target TP: 434.23, Target SL: 254.46
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3295995689. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TTE.EPA ===
#   Action: Buy
#     Position ID: 3278875237
#     Current TP: 53.94, Current SL: 31.07
#     Target TP: 53.84, Target SL: 30.87
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3278875237. Error: Market closed
#     Position ID: 3292135946
#     Current TP: 53.94, Current SL: 31.07
#     Target TP: 53.84, Target SL: 30.87
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3292135946. Error: Market closed
#     Position ID: 3293652739
#     Current TP: 53.94, Current SL: 31.07
#     Target TP: 53.84, Target SL: 30.87
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293652739. Error: Market closed
#     Position ID: 3293653283
#     Current TP: 53.94, Current SL: 31.07
#     Target TP: 53.84, Target SL: 30.87
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293653283. Error: Market closed
#     Position ID: 3293653462
#     Current TP: 53.94, Current SL: 31.07
#     Target TP: 53.84, Target SL: 30.87
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293653462. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TXN.NAS ===
#   Action: Buy
#     Position ID: 3304132717
#     Current TP: 191.76, Current SL: 69.47
#     Target TP: 192.22, Target SL: 69.504
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304132717. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UCG.MIL ===
#   Action: Buy
#     Position ID: 3303764669
#     Current TP: 56.675, Current SL: 0.001
#     Target TP: 56.735, Target SL: 0.1
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303764669. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UNH.NYSE ===
#   Action: Buy
#     Position ID: 3295249135
#     Current TP: 426.79, Current SL: 236.12
#     Target TP: 425.14, Target SL: 235.938
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3295249135. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UNIUSD ===
#   Action: Buy
#     Position ID: 3303173729
#     Current TP: 7.68, Current SL: 0.01
#     Target TP: 7.657, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303173729 modified successfully.
#     Before: TP=7.68, SL=0.01
#     After:  TP=7.657, SL=0.01
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UNP.NYSE ===
#   Action: Buy
#     Position ID: 3304132846
#     Current TP: 232.11, Current SL: 122.35
#     Target TP: 231.57, Target SL: 122.3
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304132846. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UPS.NYSE ===
#   Action: Buy
#     Position ID: 3304133027
#     Current TP: 101.96, Current SL: 78.43
#     Target TP: 101.94, Target SL: 78.3
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304133027. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: USDCAD ===
#   Action: Buy
#     Position ID: 3303844515
#     Current TP: 1.4032200000000001, Current SL: 1.14902
#     Target TP: 1.39772, Target SL: 1.14905
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303844515 modified successfully.
#     Before: TP=1.4032200000000001, SL=1.14902
#     After:  TP=1.39772, SL=1.14905
#
#     Position ID: 3304223227
#     Current TP: 1.4032200000000001, Current SL: 1.14902
#     Target TP: 1.39772, Target SL: 1.14905
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304223227 modified successfully.
#     Before: TP=1.4032200000000001, SL=1.14902
#     After:  TP=1.39772, SL=1.14905
#
#   Action: Sell
#     Position ID: 3293436465
#     Current TP: 1.3866399999999999, Current SL: 1.6408399999999999
#     Target TP: 1.39213, Target SL: 1.64633
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3293436465 modified successfully.
#     Before: TP=1.3866399999999999, SL=1.6408399999999999
#     After:  TP=1.39213, SL=1.64633
#
#     Position ID: 3304223234
#     Current TP: 1.3866399999999999, Current SL: 1.6408399999999999
#     Target TP: 1.39213, Target SL: 1.64633
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3304223234 modified successfully.
#     Before: TP=1.3866399999999999, SL=1.6408399999999999
#     After:  TP=1.39213, SL=1.64633
#
#
# === Checking Symbol: USDCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3301255979
#     Current TP: 0.81609, Current SL: 1.0934
#     Target TP: 0.81972, Target SL: 0.821
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Sell position 3301255979. Error: Invalid stops
#
# === Checking Symbol: USDJPY ===
#   Action: Buy
#     Position ID: 3303757544
#     Current TP: 148.954, Current SL: 120.445
#     Target TP: 148.244, Target SL: 120.445
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3303757544 modified successfully.
#     Before: TP=148.954, SL=120.445
#     After:  TP=148.244, SL=120.445
#
#     Position ID: 3304223239
#     Current TP: 148.954, Current SL: 120.445
#     Target TP: 148.244, Target SL: 120.445
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304223239 modified successfully.
#     Before: TP=148.954, SL=120.445
#     After:  TP=148.244, SL=120.445
#
#   Action: Sell
#     Position ID: 3291873635
#     Current TP: 144.65, Current SL: 173.159
#     Target TP: 145.346, Target SL: 173.855
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Sell position 3291873635. Error: Invalid stops
#     Position ID: 3304223246
#     Current TP: 144.65, Current SL: 173.159
#     Target TP: 145.346, Target SL: 173.855
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Sell position 3304223246. Error: Invalid stops
#
# === Checking Symbol: USDMXN ===
#   Action: Buy
#     Position ID: 3293437457
#     Current TP: 19.7217, Current SL: 16.7692
#     Target TP: 19.8119, Target SL: 16.78335
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3293437457 modified successfully.
#     Before: TP=19.7217, SL=16.7692
#     After:  TP=19.8119, SL=16.78335
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: USDZAR ===
#   Action: Buy
#     Position ID: 3293437473
#     Current TP: 18.992, Current SL: 13.57
#     Target TP: 19.0294, Target SL: 13.59
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3293437473 modified successfully.
#     Before: TP=18.992, SL=13.57
#     After:  TP=19.0294, SL=13.59
#
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: V.NYSE ===
#   Action: Buy
#     Position ID: 3306358489
#     Current TP: 366.65, Current SL: 213.81
#     Target TP: 365.87, Target SL: 214.055
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3306358489. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: VNA.XE ===
#   Action: Buy
#     Position ID: 3301984800
#     Current TP: 30.722, Current SL: 0.001
#     Target TP: 30.657, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3301984800. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: VOW3.XE ===
#   Action: Buy
#     Position ID: 3304856583
#     Current TP: 106.475, Current SL: 0.001
#     Target TP: 106.88, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304856583. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: VZ.NYSE ===
#   Action: Buy
#     Position ID: 3301256630
#     Current TP: 44.38, Current SL: 24.67
#     Target TP: 44.35, Target SL: 24.72
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3301256630. Error: Market closed
#     Position ID: 3304133254
#     Current TP: 44.38, Current SL: 24.67
#     Target TP: 44.35, Target SL: 24.72
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304133254. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: WES.ASX ===
#   Action: Buy
#     Position ID: 3305058653
#     Current TP: 81.52, Current SL: 43.95
#     Target TP: 81.58, Target SL: 43.51
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3305058653. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: WFC.NYSE ===
#   Action: Buy
#     Position ID: 3304837439
#     Current TP: 77.07, Current SL: 29.39
#     Target TP: 76.75, Target SL: 29.4
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3304837439. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: WMT.NYSE ===
#   Action: Buy
#     Position ID: 3298325768
#     Current TP: 99.89, Current SL: 65.38
#     Target TP: 99.81, Target SL: 65.447
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3298325768. Error: Market closed
#     Position ID: 3299419095
#     Current TP: 99.89, Current SL: 65.38
#     Target TP: 99.81, Target SL: 65.447
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3299419095. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: XBRUSD ===
#   Action: Buy
#     Position ID: 3304837349
#     Current TP: 66.81, Current SL: 0.01
#     Target TP: 67.08, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304837349 modified successfully.
#     Before: TP=66.81, SL=0.01
#     After:  TP=67.08, SL=0.01
#
#   Action: Sell
#     Position ID: 3306063937
#     Current TP: 62.73, Current SL: 129.53
#     Target TP: 62.48, Target SL: 129.28
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3306063937 modified successfully.
#     Before: TP=62.73, SL=129.53
#     After:  TP=62.48, SL=129.28
#
#
# === Checking Symbol: XNGUSD ===
#   Action: Buy
#     Position ID: 3304493382
#     Current TP: 4.087, Current SL: 0.001
#     Target TP: 4.1, Target SL: 0.001
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304493382 modified successfully.
#     Before: TP=4.087, SL=0.001
#     After:  TP=4.1, SL=0.001
#
#   Action: Sell
#     Position ID: 3306521739
#     Current TP: 3.536, Current SL: 7.62
#     Target TP: 3.524, Target SL: 7.61
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3306521739 modified successfully.
#     Before: TP=3.536, SL=7.62
#     After:  TP=3.524, SL=7.61
#
#
# === Checking Symbol: XOM.NYSE ===
#   Action: Buy
#     Position ID: 3278885254
#     Current TP: 115.25, Current SL: 65.03
#     Target TP: 115.07, Target SL: 64.4337
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3278885254. Error: Market closed
#     Position ID: 3293990121
#     Current TP: 115.25, Current SL: 65.03
#     Target TP: 115.07, Target SL: 64.4337
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3293990121. Error: Market closed
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: XTIUSD ===
#   Action: Buy
#     Position ID: 3304837471
#     Current TP: 63.84, Current SL: 0.01
#     Target TP: 63.97, Target SL: 0.01
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Buy position 3304837471 modified successfully.
#     Before: TP=63.84, SL=0.01
#     After:  TP=63.97, SL=0.01
#
#   Action: Sell
#     Position ID: 3306063871
#     Current TP: 59.55, Current SL: 123.38
#     Target TP: 59.42, Target SL: 123.25
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3306063871 modified successfully.
#     Before: TP=59.55, SL=123.38
#     After:  TP=59.42, SL=123.25
#
#
# === Checking Symbol: ZECUSD ===
#   Action: Buy
#     Position ID: 3303336699
#     Current TP: 45.82, Current SL: 0.01
#     Target TP: 45.87, Target SL: 1
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ⚠️ Failed to modify Buy position 3303336699. Error: Request returned None.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === TP/SL Modification Summary ===
# Total Successful Modifications: 107
# Total Failed Modifications: 149
