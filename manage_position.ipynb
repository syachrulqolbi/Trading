# %%
# === Imports === #
import MetaTrader5 as mt5
import pandas as pd
import numpy as np
import yaml
import os
from google_sheet_api import GoogleSheetsUploader

# === Setup Paths === #
BASE_DIR = os.getcwd()
CONFIG_PATH = os.path.join(BASE_DIR, "config.yaml")
CREDENTIAL_PATH = os.path.join(BASE_DIR, "credential_google_sheets.json")

# === Load Configuration === #
def load_config(path):
    with open(path, "r") as file:
        return yaml.safe_load(file)

config = load_config(CONFIG_PATH)

# === Initialize MT5 Connection === #
if not mt5.initialize():
    print("MT5 initialization failed.")
    quit()

# === Retrieve Account Information === #
account_info = mt5.account_info()
if account_info is None:
    print("Failed to retrieve account information.")
    mt5.shutdown()
    quit()

balance = account_info.balance
equity = account_info.equity + account_info.credit
floating_loss = account_info.profit

print("=== Account Information ===")
print(f"Balance: {balance:.2f} USD")
print(f"Equity: {equity:.2f} USD")
print(f"Floating Loss: {floating_loss:.2f} USD")

# === Load Running Trades from MT5 and Reference Google Sheet === #
fetcher = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")
df = fetcher.get_sheet_as_dataframe("Forex")
positions = mt5.positions_get()
df_positions = pd.DataFrame([pos._asdict() for pos in positions]) if positions else pd.DataFrame()

if df_positions.empty:
    print("No running trades found. Error:", mt5.last_error())
    mt5.shutdown()
    quit()

# === Clean and Rename Trade Columns === #
df_positions = df_positions[["type", "volume", "price_open", "price_current", "sl", "tp", "profit", "symbol"]]
df_positions["type"] = df_positions["type"].replace({0: "Buy", 1: "Sell"})
df_positions.rename(columns={
    "symbol": "Symbol",
    "type": "Action",
    "volume": "Lot",
    "price_open": "Price",
    "price_current": "Price Current",
    "sl": "SL",
    "tp": "TP",
    "profit": "Profit"
}, inplace=True)

# Prepare hedge profit DataFrame early for printing
df_trend = df[[df.columns[0], df.columns[1], df.columns[2], df.columns[19]]].drop_duplicates()
df_trend.columns = ["Symbol", "Type", "Action", "Trend"]

df_temp_profit = df_positions[["Symbol", "Action", "Profit"]]
df_hedge = pd.merge(df_trend, df_temp_profit, on=["Symbol", "Action"], how="left")
hedged_profit = df_hedge.loc[
    (df_hedge["Type"] == "Forex") & (df_hedge["Trend"] == "Sideways"),
    "Profit"
].sum()

print(f"Total hedged amount (Forex, Sideways trend): {hedged_profit} USD")

# === Aggregate Positions by Symbol and Action === #
def aggregate_group(group):
    symbol = group["Symbol"].iloc[0]
    action = group["Action"].iloc[0]
    lot = group["Lot"].sum()
    warnings = []

    df_lot_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[5]].sum()
    if not pd.isna(df_lot_value) and round(df_lot_value, 2) > round(lot, 2):
        warnings.append(f"Lot Mismatch: Expected {round(df_lot_value, 2)}, Found {round(lot, 2)}")

    df_sl_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[7]].sum()
    sl_mode = group["SL"].mode().iloc[0] if not group["SL"].mode().empty else np.nan
    if group["SL"].nunique() > 1 or (df_sl_value != 0 and round(df_sl_value, 2) != round(sl_mode, 2)):
        warnings.append("SL Mismatch")

    df_tp_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[8]].sum()
    tp_mode = group["TP"].mode().iloc[0] if not group["TP"].mode().empty else np.nan
    if group["TP"].nunique() > 1 or round(df_tp_value, 2) != round(tp_mode, 2):
        warnings.append("TP Mismatch")

    warning_message = "; ".join(warnings) if warnings else np.nan

    return pd.Series({
        "Lot": lot,
        "Price": (group["Price"] * group["Lot"]).sum() / group["Lot"].sum(),
        "Price Current": group["Price Current"].mean(),
        "SL": sl_mode,
        "TP": tp_mode,
        "Profit": group["Profit"].sum(),
        "Warning": warning_message
    })

df_positions = (
    df_positions.groupby(["Symbol", "Action"], as_index=False)
    .apply(aggregate_group)
    .reset_index(drop=True)
)

# === Shutdown MT5 === #
mt5.shutdown()

# === Calculations and Merging === #
df_positions["Coeff"] = np.abs(df_positions["Profit"] / (df_positions["Price Current"] - df_positions["Price"])) / (df_positions["Lot"] * 100)
df_positions["Pips"] = np.abs(df_positions["TP"] - df_positions["SL"])

df_type = df[[df.columns[0], df.columns[1]]].drop_duplicates()
df_type.columns = ["Symbol", "Type"]
df_positions = pd.merge(df_positions, df_type, on="Symbol", how="left")
df_positions["Type"].fillna("Unknown", inplace=True)

# === Update Coefficients in Config File === #
df_avg_coeff = df_positions.groupby("Symbol")["Coeff"].mean().reset_index()
differences = {}
for _, row in df_avg_coeff.iterrows():
    symbol = row["Symbol"]
    avg_coeff = round(row["Coeff"], 5)
    if not pd.isna(avg_coeff):
        if symbol in config.get("symbol_coefficients", {}):
            old_coeff = config["symbol_coefficients"].get(symbol, avg_coeff)
            if old_coeff != avg_coeff:
                differences[symbol] = {"Old": old_coeff, "New": avg_coeff}
        config["symbol_coefficients"][symbol] = avg_coeff

with open(CONFIG_PATH, "w") as file:
    yaml.safe_dump(config, file)

print("Changed symbol_coefficients:")
for symbol, change in differences.items():
    print(f"{symbol}: {change['Old']} -> {change['New']}")

# === Add Account Summary === #
df_balance = pd.DataFrame([
    {"Symbol": "Balance", "Price": balance},
    {"Symbol": "Equity", "Price": equity},
    {"Symbol": "Floating Loss", "Price": floating_loss}
])

df_final = pd.concat([df_balance, df_positions], ignore_index=True)

# === Upload to Google Sheets === #
uploader = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")
uploader.upload_dataframe(df_final, "Forex Summary", replace=True)

# === Print Final Output === #
print("Final Merged DataFrame:")
df_final
# Out:
# === Account Information ===
# Balance: 7068.02 USD
# Equity: 7704.78 USD
# Floating Loss: -3065.10 USD

# %%
import time
import MetaTrader5 as mt5
import pandas as pd
import os
from google_sheet_api import GoogleSheetsUploader

# === Setup Paths === #
BASE_DIR = os.getcwd()
CONFIG_PATH = os.path.join(BASE_DIR, "config.yaml")
CREDENTIAL_PATH = os.path.join(BASE_DIR, "credential_google_sheets.json")

# === Initialize MT5 Connection === #
if not mt5.initialize():
    print("MT5 initialization failed.")
    quit()

fetcher = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")

# Load DataFrame from Google Sheets
df = fetcher.get_sheet_as_dataframe("Forex")
df.columns = df.iloc[6]
df = df.iloc[7:-3].reset_index(drop=True)

# Initialize counters for success and failure
success_count = 0
failure_count = 0

# Fetch unique symbols from running trades in MT5
positions = mt5.positions_get()
if positions is None or len(positions) == 0:
    print("No running trades found. Exiting.")
    mt5.shutdown()
    quit()

# Get unique symbols from MT5 positions
symbol_list = sorted(list(set(pos.symbol for pos in positions)))

# Convert positions to DataFrame for easy filtering
df_positions = pd.DataFrame([pos._asdict() for pos in positions])

# Iterate through each unique symbol from MT5 positions
for symbol in symbol_list:
    print(f"\n=== Checking Symbol: {symbol} ===")
    for action in ["Buy", "Sell"]:
        print(f"  Action: {action}")
        action_type = 0 if action == "Buy" else 1
        filtered_positions = df_positions[(df_positions['symbol'] == symbol) & (df_positions['type'] == action_type)]
        
        if filtered_positions.empty:
            print(f"    ⚠️ No {action} positions running. Skipping.")
            continue

        # Filter rows for the current symbol and action from Google Sheets
        df_filtered = df[(df["Symbol"] == symbol) & (df["Action"] == action)]
        
        if df_filtered.empty:
            print(f"    ⚠️ No matching TP/SL settings in Google Sheets.")
            continue
        
        tp_value = round(float(df_filtered['TP'].values[0]), df_filtered['Decimal'].values[0])
        sl_value = round(float(df_filtered['SL'].values[0]), df_filtered['Decimal'].values[0])

        # Iterate over filtered positions for modification
        for _, pos in filtered_positions.iterrows():
            order_id = pos['ticket']
            current_tp = round(pos['tp'], df_filtered['Decimal'].values[0])
            current_sl = round(pos['sl'], df_filtered['Decimal'].values[0])

            # Check for differences and print
            print(f"    Position ID: {order_id}")
            print(f"    Current TP: {current_tp}, Current SL: {current_sl}")
            print(f"    Target TP: {tp_value}, Target SL: {sl_value}")

            if current_tp == tp_value and current_sl == sl_value:
                print(f"    ✅ No changes needed for {action} position {order_id}.")
                continue
            else:
                print(f"    ⚠️ TP/SL difference detected. Attempting to update...")

            # Modify TP/SL using position ID
            request = {
                "action": mt5.TRADE_ACTION_SLTP,
                "position": order_id,
                "sl": sl_value,
                "tp": tp_value
            }

            # Send modification request
            result = mt5.order_send(request)

            # Check if result is None (Error)
            if result is None:
                print(f"    ⚠️ Failed to modify {action} position {order_id}. Error: Request returned None.")
                failure_count += 1
                continue

            # Check if the modification was successful
            if result.retcode == mt5.TRADE_RETCODE_DONE:
                print(f"    ✅ {action} position {order_id} modified successfully.")
                print(f"    Before: TP={current_tp}, SL={current_sl}")
                print(f"    After:  TP={tp_value}, SL={sl_value}\n")
                success_count += 1
            else:
                print(f"    ⚠️ Failed to modify {action} position {order_id}. Error: {result.comment}")
                failure_count += 1

# === Shutdown MT5 Connection === #
mt5.shutdown()

# === Summary Report ===
print("\n=== TP/SL Modification Summary ===")
print(f"Total Successful Modifications: {success_count}")
print(f"Total Failed Modifications: {failure_count}")
# Out:
# ✅ Successfully retrieved data from 'Forex' as a DataFrame.
#
# === Checking Symbol: AAPL.NAS ===
#   Action: Buy
#     Position ID: 3297549570
#     Current TP: 217.47, Current SL: 112.36
#     Target TP: 217.47, Target SL: 112.36
#     ✅ No changes needed for Buy position 3297549570.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AAVEUSD ===
#   Action: Buy
#     Position ID: 3319810775
#     Current TP: 338.66, Current SL: 0.01
#     Target TP: 338.66, Target SL: 0.01
#     ✅ No changes needed for Buy position 3319810775.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ABBV.NYSE ===
#   Action: Buy
#     Position ID: 3298446412
#     Current TP: 200.55, Current SL: 142.89
#     Target TP: 200.55, Target SL: 142.89
#     ✅ No changes needed for Buy position 3298446412.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ABNB.NAS ===
#   Action: Buy
#     Position ID: 3318618882
#     Current TP: 143.89, Current SL: 0.01
#     Target TP: 143.89, Target SL: 0.01
#     ✅ No changes needed for Buy position 3318618882.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ABT.NYSE ===
#   Action: Buy
#     Position ID: 3321249602
#     Current TP: 137.63, Current SL: 91.87
#     Target TP: 137.63, Target SL: 91.87
#     ✅ No changes needed for Buy position 3321249602.
#     Position ID: 3321249782
#     Current TP: 137.63, Current SL: 91.87
#     Target TP: 137.63, Target SL: 91.87
#     ✅ No changes needed for Buy position 3321249782.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ACN.NYSE ===
#   Action: Buy
#     Position ID: 3304837038
#     Current TP: 328.41, Current SL: 246.13
#     Target TP: 328.41, Target SL: 246.13
#     ✅ No changes needed for Buy position 3304837038.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ADAUSD ===
#   Action: Buy
#     Position ID: 3304100487
#     Current TP: 0.8553, Current SL: 0.0001
#     Target TP: 0.8553, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304100487.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ADBE.NAS ===
#   Action: Buy
#     Position ID: 3320065540
#     Current TP: 424.11, Current SL: 242.49
#     Target TP: 424.11, Target SL: 242.49
#     ✅ No changes needed for Buy position 3320065540.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ADS.XE ===
#   Action: Buy
#     Position ID: 3313817895
#     Current TP: 229.647, Current SL: 127.087
#     Target TP: 229.647, Target SL: 127.087
#     ✅ No changes needed for Buy position 3313817895.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AI.EPA ===
#   Action: Buy
#     Position ID: 3306803616
#     Current TP: 188.77, Current SL: 134.19
#     Target TP: 188.77, Target SL: 134.19
#     ✅ No changes needed for Buy position 3306803616.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AIR.EPA ===
#   Action: Buy
#     Position ID: 3316821546
#     Current TP: 175.79, Current SL: 77.83
#     Target TP: 175.79, Target SL: 77.83
#     ✅ No changes needed for Buy position 3316821546.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ALGOUSD ===
#   Action: Buy
#     Position ID: 3304100698
#     Current TP: 0.263, Current SL: 0.0001
#     Target TP: 0.263, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304100698.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AMD.NAS ===
#   Action: Buy
#     Position ID: 3323011318
#     Current TP: 130.04, Current SL: 31.92
#     Target TP: 130.04, Target SL: 31.92
#     ✅ No changes needed for Buy position 3323011318.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AMZN.NAS ===
#   Action: Buy
#     Position ID: 3319432145
#     Current TP: 222.72, Current SL: 88.54
#     Target TP: 222.72, Target SL: 88.54
#     ✅ No changes needed for Buy position 3319432145.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: APTUSD ===
#   Action: Buy
#     Position ID: 3303173396
#     Current TP: 6.4428, Current SL: 0.0001
#     Target TP: 6.4428, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303173396.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ATOMUSD ===
#   Action: Buy
#     Position ID: 3303174194
#     Current TP: 5.57, Current SL: 0.001
#     Target TP: 5.57, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303174194.
#     Position ID: 3304176535
#     Current TP: 5.57, Current SL: 0.001
#     Target TP: 5.57, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304176535.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AUDCAD ===
#   Action: Buy
#     Position ID: 3304834368
#     Current TP: 0.90102, Current SL: 0.78369
#     Target TP: 0.90102, Target SL: 0.78369
#     ✅ No changes needed for Buy position 3304834368.
#     Position ID: 3317231378
#     Current TP: 0.90102, Current SL: 0.78369
#     Target TP: 0.90102, Target SL: 0.78369
#     ✅ No changes needed for Buy position 3317231378.
#     Position ID: 3319432177
#     Current TP: 0.90102, Current SL: 0.78369
#     Target TP: 0.90102, Target SL: 0.78369
#     ✅ No changes needed for Buy position 3319432177.
#   Action: Sell
#     Position ID: 3321451268
#     Current TP: 0.87908, Current SL: 0.99641
#     Target TP: 0.87908, Target SL: 0.99641
#     ✅ No changes needed for Sell position 3321451268.
#     Position ID: 3321705687
#     Current TP: 0.87908, Current SL: 0.99641
#     Target TP: 0.87908, Target SL: 0.99641
#     ✅ No changes needed for Sell position 3321705687.
#
# === Checking Symbol: AUDJPY ===
#   Action: Buy
#     Position ID: 3304837518
#     Current TP: 94.981, Current SL: 76.411
#     Target TP: 94.981, Target SL: 76.411
#     ✅ No changes needed for Buy position 3304837518.
#     Position ID: 3315615609
#     Current TP: 94.981, Current SL: 76.411
#     Target TP: 94.981, Target SL: 76.411
#     ✅ No changes needed for Buy position 3315615609.
#   Action: Sell
#     Position ID: 3310048126
#     Current TP: 91.642, Current SL: 110.212
#     Target TP: 91.642, Target SL: 110.212
#     ✅ No changes needed for Sell position 3310048126.
#     Position ID: 3315615674
#     Current TP: 91.642, Current SL: 110.212
#     Target TP: 91.642, Target SL: 110.212
#     ✅ No changes needed for Sell position 3315615674.
#
# === Checking Symbol: AUDNZD ===
#   Action: Buy
#     Position ID: 3305835701
#     Current TP: 1.09279, Current SL: 0.98513
#     Target TP: 1.09279, Target SL: 0.98513
#     ✅ No changes needed for Buy position 3305835701.
#     Position ID: 3315617121
#     Current TP: 1.09279, Current SL: 0.98513
#     Target TP: 1.09279, Target SL: 0.98513
#     ✅ No changes needed for Buy position 3315617121.
#   Action: Sell
#     Position ID: 3315929848
#     Current TP: 1.07051, Current SL: 1.17817
#     Target TP: 1.07051, Target SL: 1.17817
#     ✅ No changes needed for Sell position 3315929848.
#
# === Checking Symbol: AUDUSD ===
#   Action: Buy
#     Position ID: 3323011278
#     Current TP: 0.65804, Current SL: 0.50566
#     Target TP: 0.65804, Target SL: 0.50566
#     ✅ No changes needed for Buy position 3323011278.
#   Action: Sell
#     Position ID: 3304180166
#     Current TP: 0.63625, Current SL: 0.78863
#     Target TP: 0.63625, Target SL: 0.78863
#     ✅ No changes needed for Sell position 3304180166.
#     Position ID: 3304223991
#     Current TP: 0.63625, Current SL: 0.78863
#     Target TP: 0.63625, Target SL: 0.78863
#     ✅ No changes needed for Sell position 3304223991.
#     Position ID: 3315617525
#     Current TP: 0.63625, Current SL: 0.78863
#     Target TP: 0.63625, Target SL: 0.78863
#     ✅ No changes needed for Sell position 3315617525.
#
# === Checking Symbol: AUS200 ===
#   Action: Buy
#     Position ID: 3319918116
#     Current TP: 8692.6, Current SL: 6114.0
#     Target TP: 8692.6, Target SL: 6114.0
#     ✅ No changes needed for Buy position 3319918116.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AVAXUSD ===
#   Action: Buy
#     Position ID: 3303762188
#     Current TP: 26.8, Current SL: 0.001
#     Target TP: 26.8, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303762188.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AVGO.NAS ===
#   Action: Buy
#     Position ID: 3317232450
#     Current TP: 265.34, Current SL: 155.08
#     Target TP: 265.34, Target SL: 155.08
#     ✅ No changes needed for Buy position 3317232450.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AXP.NYSE ===
#   Action: Buy
#     Position ID: 3318618895
#     Current TP: 306.83, Current SL: 152.15
#     Target TP: 306.83, Target SL: 152.15
#     ✅ No changes needed for Buy position 3318618895.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AXSUSD ===
#   Action: Buy
#     Position ID: 3305014875
#     Current TP: 3.92, Current SL: 0.01
#     Target TP: 3.92, Target SL: 0.01
#     ✅ No changes needed for Buy position 3305014875.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: AZN.LSE ===
#   Action: Buy
#     Position ID: 3321700840
#     Current TP: 111.38, Current SL: 83.17
#     Target TP: 111.38, Target SL: 83.17
#     ✅ No changes needed for Buy position 3321700840.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BA.NYSE ===
#   Action: Buy
#     Position ID: 3319432209
#     Current TP: 221.55, Current SL: 80.97
#     Target TP: 221.55, Target SL: 80.97
#     ✅ No changes needed for Buy position 3319432209.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BABA.NYSE ===
#   Action: Buy
#     Position ID: 3304102868
#     Current TP: 135.37, Current SL: 0.01
#     Target TP: 135.37, Target SL: 0.01
#     ✅ No changes needed for Buy position 3304102868.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BAC.NYSE ===
#   Action: Buy
#     Position ID: 3318618915
#     Current TP: 45.83, Current SL: 18.42
#     Target TP: 45.83, Target SL: 18.42
#     ✅ No changes needed for Buy position 3318618915.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BARC.LSE ===
#   Action: Buy
#     Position ID: 3303762395
#     Current TP: 3.2881, Current SL: 0.0001
#     Target TP: 3.2881, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303762395.
#     Position ID: 3320278229
#     Current TP: 3.2881, Current SL: 0.0001
#     Target TP: 3.2881, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3320278229.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BATS.LSE ===
#   Action: Buy
#     Position ID: 3320966234
#     Current TP: 36.442, Current SL: 19.79
#     Target TP: 36.442, Target SL: 19.79
#     ✅ No changes needed for Buy position 3320966234.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BAYN.FWB ===
#   Action: Buy
#     Position ID: 3320967312
#     Current TP: 27.93, Current SL: 0.01
#     Target TP: 27.93, Target SL: 0.01
#     ✅ No changes needed for Buy position 3320967312.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BBVA.BM ===
#   Action: Buy
#     Position ID: 3308534286
#     Current TP: 13.8461, Current SL: 5.6804
#     Target TP: 13.8461, Target SL: 5.6804
#     ✅ No changes needed for Buy position 3308534286.
#     Position ID: 3315618176
#     Current TP: 13.8461, Current SL: 5.6804
#     Target TP: 13.8461, Target SL: 5.6804
#     ✅ No changes needed for Buy position 3315618176.
#     Position ID: 3319717325
#     Current TP: 13.8461, Current SL: 5.6804
#     Target TP: 13.8461, Target SL: 5.6804
#     ✅ No changes needed for Buy position 3319717325.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BCHUSD ===
#   Action: Buy
#     Position ID: 3323011243
#     Current TP: 487.09, Current SL: 0.01
#     Target TP: 487.09, Target SL: 0.01
#     ✅ No changes needed for Buy position 3323011243.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BEI.XE ===
#   Action: Buy
#     Position ID: 3299405469
#     Current TP: 123.374, Current SL: 93.337
#     Target TP: 123.374, Target SL: 93.337
#     ✅ No changes needed for Buy position 3299405469.
#     Position ID: 3303762634
#     Current TP: 123.374, Current SL: 93.337
#     Target TP: 123.374, Target SL: 93.337
#     ✅ No changes needed for Buy position 3303762634.
#     Position ID: 3316896944
#     Current TP: 123.374, Current SL: 93.337
#     Target TP: 123.374, Target SL: 93.337
#     ✅ No changes needed for Buy position 3316896944.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BHP.ASX ===
#   Action: Buy
#     Position ID: 3305001253
#     Current TP: 39.49, Current SL: 26.41
#     Target TP: 39.49, Target SL: 26.41
#     ✅ No changes needed for Buy position 3305001253.
#     Position ID: 3317318848
#     Current TP: 39.49, Current SL: 26.41
#     Target TP: 39.49, Target SL: 26.41
#     ✅ No changes needed for Buy position 3317318848.
#     Position ID: 3320798644
#     Current TP: 39.49, Current SL: 26.41
#     Target TP: 39.49, Target SL: 26.41
#     ✅ No changes needed for Buy position 3320798644.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BMW.XE ===
#   Action: Buy
#     Position ID: 3305210030
#     Current TP: 81.498, Current SL: 43.503
#     Target TP: 81.498, Target SL: 43.503
#     ✅ No changes needed for Buy position 3305210030.
#     Position ID: 3315618252
#     Current TP: 81.498, Current SL: 43.503
#     Target TP: 81.498, Target SL: 43.503
#     ✅ No changes needed for Buy position 3315618252.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BMY.NYSE ===
#   Action: Buy
#     Position ID: 3319969798
#     Current TP: 50.7, Current SL: 35.02
#     Target TP: 50.7, Target SL: 35.02
#     ✅ No changes needed for Buy position 3319969798.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BNBUSD ===
#   Action: Buy
#     Position ID: 3312740016
#     Current TP: 712.83, Current SL: 0.01
#     Target TP: 712.83, Target SL: 0.01
#     ✅ No changes needed for Buy position 3312740016.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BNP.EPA ===
#   Action: Buy
#     Position ID: 3305269306
#     Current TP: 80.075, Current SL: 35.441
#     Target TP: 80.075, Target SL: 35.441
#     ✅ No changes needed for Buy position 3305269306.
#     Position ID: 3316897274
#     Current TP: 80.075, Current SL: 35.441
#     Target TP: 80.075, Target SL: 35.441
#     ✅ No changes needed for Buy position 3316897274.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: BX.NYSE ===
#   Action: Buy
#     Position ID: 3304110024
#     Current TP: 150.74, Current SL: 75.65
#     Target TP: 150.74, Target SL: 75.65
#     ✅ No changes needed for Buy position 3304110024.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CADCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3295246044
#     Current TP: 0.59027, Current SL: 0.78343
#     Target TP: 0.59027, Target SL: 0.78343
#     ✅ No changes needed for Sell position 3295246044.
#
# === Checking Symbol: CADJPY ===
#   Action: Buy
#     Position ID: 3323073846
#     Current TP: 107.275, Current SL: 88.716
#     Target TP: 107.275, Target SL: 88.716
#     ✅ No changes needed for Buy position 3323073846.
#   Action: Sell
#     Position ID: 3309939192
#     Current TP: 102.924, Current SL: 120.73
#     Target TP: 102.924, Target SL: 121.483
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3309939192 modified successfully.
#     Before: TP=102.924, SL=120.73
#     After:  TP=102.924, SL=121.483
#
#     Position ID: 3315618543
#     Current TP: 102.924, Current SL: 120.73
#     Target TP: 102.924, Target SL: 121.483
#     ⚠️ TP/SL difference detected. Attempting to update...
#     ✅ Sell position 3315618543 modified successfully.
#     Before: TP=102.924, SL=120.73
#     After:  TP=102.924, SL=121.483
#
#
# === Checking Symbol: CAT.NYSE ===
#   Action: Buy
#     Position ID: 3319432218
#     Current TP: 365.2, Current SL: 213.51
#     Target TP: 365.2, Target SL: 213.51
#     ✅ No changes needed for Buy position 3319432218.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CBA.ASX ===
#   Action: Buy
#     Position ID: 3320134628
#     Current TP: 184.6, Current SL: 116.72
#     Target TP: 184.6, Target SL: 116.72
#     ✅ No changes needed for Buy position 3320134628.
#     Position ID: 3320134771
#     Current TP: 184.6, Current SL: 116.72
#     Target TP: 184.6, Target SL: 116.72
#     ✅ No changes needed for Buy position 3320134771.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CMCSA.NAS ===
#   Action: Buy
#     Position ID: 3320064783
#     Current TP: 36.15, Current SL: 23.95
#     Target TP: 36.15, Target SL: 23.95
#     ✅ No changes needed for Buy position 3320064783.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: COP.NYSE ===
#   Action: Buy
#     Position ID: 3322024225
#     Current TP: 97.77, Current SL: 59.21
#     Target TP: 97.77, Target SL: 59.21
#     ✅ No changes needed for Buy position 3322024225.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CRM.NYSE ===
#   Action: Buy
#     Position ID: 3318618966
#     Current TP: 278.45, Current SL: 175.86
#     Target TP: 278.45, Target SL: 175.86
#     ✅ No changes needed for Buy position 3318618966.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CSCO.NAS ===
#   Action: Buy
#     Position ID: 3319432229
#     Current TP: 67.18, Current SL: 29.79
#     Target TP: 67.18, Target SL: 29.79
#     ✅ No changes needed for Buy position 3319432229.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CSL.ASX ===
#   Action: Buy
#     Position ID: 3298768130
#     Current TP: 256.2, Current SL: 188.01
#     Target TP: 256.2, Target SL: 188.01
#     ✅ No changes needed for Buy position 3298768130.
#     Position ID: 3315987384
#     Current TP: 256.2, Current SL: 188.01
#     Target TP: 256.2, Target SL: 188.01
#     ✅ No changes needed for Buy position 3315987384.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: CVS.NYSE ===
#   Action: Buy
#     Position ID: 3322024254
#     Current TP: 68.13, Current SL: 38.4
#     Target TP: 68.13, Target SL: 38.4
#     ✅ No changes needed for Buy position 3322024254.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DASHUSD ===
#   Action: Buy
#     Position ID: 3303173212
#     Current TP: 26.18, Current SL: 0.01
#     Target TP: 26.18, Target SL: 0.01
#     ✅ No changes needed for Buy position 3303173212.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DIS.NYSE ===
#   Action: Buy
#     Position ID: 3323011348
#     Current TP: 121.14, Current SL: 61.21
#     Target TP: 121.14, Target SL: 61.21
#     ✅ No changes needed for Buy position 3323011348.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DKI.TSE ===
#   Action: Buy
#     Position ID: 3297726752
#     Current TP: 17495.84, Current SL: 12450.41
#     Target TP: 17495.84, Target SL: 12450.41
#     ✅ No changes needed for Buy position 3297726752.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DOTUSD ===
#   Action: Buy
#     Position ID: 3303763159
#     Current TP: 5.44, Current SL: 0.001
#     Target TP: 5.44, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303763159.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: DTE.FWB ===
#   Action: Buy
#     Position ID: 3310031540
#     Current TP: 34.21, Current SL: 17.85
#     Target TP: 34.21, Target SL: 17.85
#     ✅ No changes needed for Buy position 3310031540.
#     Position ID: 3315618639
#     Current TP: 34.21, Current SL: 17.85
#     Target TP: 34.21, Target SL: 17.85
#     ✅ No changes needed for Buy position 3315618639.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ENEL.MIL ===
#   Action: Buy
#     Position ID: 3307098448
#     Current TP: 8.1609, Current SL: 4.5936
#     Target TP: 8.1609, Target SL: 4.5936
#     ✅ No changes needed for Buy position 3307098448.
#     Position ID: 3311774405
#     Current TP: 8.1609, Current SL: 4.5936
#     Target TP: 8.1609, Target SL: 4.5936
#     ✅ No changes needed for Buy position 3311774405.
#     Position ID: 3315618747
#     Current TP: 8.1609, Current SL: 4.5936
#     Target TP: 8.1609, Target SL: 4.5936
#     ✅ No changes needed for Buy position 3315618747.
#     Position ID: 3316175295
#     Current TP: 8.1609, Current SL: 4.5936
#     Target TP: 8.1609, Target SL: 4.5936
#     ✅ No changes needed for Buy position 3316175295.
#     Position ID: 3319717263
#     Current TP: 8.1609, Current SL: 4.5936
#     Target TP: 8.1609, Target SL: 4.5936
#     ✅ No changes needed for Buy position 3319717263.
#     Position ID: 3320253440
#     Current TP: 8.1609, Current SL: 4.5936
#     Target TP: 8.1609, Target SL: 4.5936
#     ✅ No changes needed for Buy position 3320253440.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ENI.MIL ===
#   Action: Buy
#     Position ID: 3321700908
#     Current TP: 14.345, Current SL: 8.232
#     Target TP: 14.345, Target SL: 8.232
#     ✅ No changes needed for Buy position 3321700908.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ETCUSD ===
#   Action: Buy
#     Position ID: 3303173265
#     Current TP: 19.688, Current SL: 0.001
#     Target TP: 19.688, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303173265.
#     Position ID: 3317231368
#     Current TP: 19.688, Current SL: 0.001
#     Target TP: 19.688, Target SL: 0.001
#     ✅ No changes needed for Buy position 3317231368.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: EURAUD ===
#   Action: Buy
#     Position ID: 3321493532
#     Current TP: 1.7888, Current SL: 1.47379
#     Target TP: 1.7888, Target SL: 1.47379
#     ✅ No changes needed for Buy position 3321493532.
#   Action: Sell
#     Position ID: 3304856822
#     Current TP: 1.73619, Current SL: 2.0512
#     Target TP: 1.73619, Target SL: 2.0512
#     ✅ No changes needed for Sell position 3304856822.
#     Position ID: 3315618921
#     Current TP: 1.73619, Current SL: 2.0512
#     Target TP: 1.73619, Target SL: 2.0512
#     ✅ No changes needed for Sell position 3315618921.
#
# === Checking Symbol: EURCAD ===
#   Action: Buy
#     Position ID: 3321364280
#     Current TP: 1.58044, Current SL: 1.31713
#     Target TP: 1.58044, Target SL: 1.31713
#     ✅ No changes needed for Buy position 3321364280.
#   Action: Sell
#     Position ID: 3303757395
#     Current TP: 1.54474, Current SL: 1.80805
#     Target TP: 1.54474, Target SL: 1.80805
#     ✅ No changes needed for Sell position 3303757395.
#     Position ID: 3304223178
#     Current TP: 1.54474, Current SL: 1.80805
#     Target TP: 1.54474, Target SL: 1.80805
#     ✅ No changes needed for Sell position 3304223178.
#
# === Checking Symbol: EURCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3299527080
#     Current TP: 0.92792, Current SL: 1.13439
#     Target TP: 0.92792, Target SL: 1.13439
#     ✅ No changes needed for Sell position 3299527080.
#
# === Checking Symbol: EURGBP ===
#   Action: Buy
#     Position ID: 3321075138
#     Current TP: 0.85612, Current SL: 0.75598
#     Target TP: 0.85612, Target SL: 0.75598
#     ✅ No changes needed for Buy position 3321075138.
#   Action: Sell
#     Position ID: 3310842489
#     Current TP: 0.83712, Current SL: 0.93726
#     Target TP: 0.83712, Target SL: 0.93726
#     ✅ No changes needed for Sell position 3310842489.
#     Position ID: 3310842707
#     Current TP: 0.83712, Current SL: 0.93726
#     Target TP: 0.83712, Target SL: 0.93726
#     ✅ No changes needed for Sell position 3310842707.
#     Position ID: 3315619003
#     Current TP: 0.83712, Current SL: 0.93726
#     Target TP: 0.83712, Target SL: 0.93726
#     ✅ No changes needed for Sell position 3315619003.
#
# === Checking Symbol: EURJPY ===
#   Action: Buy
#     Position ID: 3322538991
#     Current TP: 167.727, Current SL: 134.866
#     Target TP: 167.727, Target SL: 134.866
#     ✅ No changes needed for Buy position 3322538991.
#   Action: Sell
#     Position ID: 3310842266
#     Current TP: 161.212, Current SL: 194.073
#     Target TP: 161.212, Target SL: 194.073
#     ✅ No changes needed for Sell position 3310842266.
#     Position ID: 3315619090
#     Current TP: 161.212, Current SL: 194.073
#     Target TP: 161.212, Target SL: 194.073
#     ✅ No changes needed for Sell position 3315619090.
#
# === Checking Symbol: EURMXN ===
#   Action: Buy
#     Position ID: 3293419757
#     Current TP: 22.3898, Current SL: 18.3764
#     Target TP: 22.3898, Target SL: 18.3764
#     ✅ No changes needed for Buy position 3293419757.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: EURNZD ===
#   Action: Buy
#     Position ID: 3321493562
#     Current TP: 1.92461, Current SL: 1.5858
#     Target TP: 1.92461, Target SL: 1.5858
#     ✅ No changes needed for Buy position 3321493562.
#   Action: Sell
#     Position ID: 3304459498
#     Current TP: 1.87539, Current SL: 2.2142
#     Target TP: 1.87539, Target SL: 2.2142
#     ✅ No changes needed for Sell position 3304459498.
#
# === Checking Symbol: EURUSD ===
#   Action: Buy
#     Position ID: 3321115338
#     Current TP: 1.16475, Current SL: 0.91508
#     Target TP: 1.16475, Target SL: 0.91508
#     ✅ No changes needed for Buy position 3321115338.
#   Action: Sell
#     Position ID: 3303757469
#     Current TP: 1.12109, Current SL: 1.37076
#     Target TP: 1.12109, Target SL: 1.37076
#     ✅ No changes needed for Sell position 3303757469.
#     Position ID: 3315619295
#     Current TP: 1.12109, Current SL: 1.37076
#     Target TP: 1.12109, Target SL: 1.37076
#     ✅ No changes needed for Sell position 3315619295.
#
# === Checking Symbol: EURZAR ===
#   Action: Buy
#     Position ID: 3297344129
#     Current TP: 21.24942, Current SL: 16.4322
#     Target TP: 21.24942, Target SL: 16.4322
#     ✅ No changes needed for Buy position 3297344129.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: FETUSD ===
#   Action: Buy
#     Position ID: 3310566104
#     Current TP: 0.9983, Current SL: 0.0001
#     Target TP: 0.9983, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3310566104.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: FILUSD ===
#   Action: Buy
#     Position ID: 3302580433
#     Current TP: 3.288, Current SL: 0.001
#     Target TP: 3.288, Target SL: 0.001
#     ✅ No changes needed for Buy position 3302580433.
#     Position ID: 3303239649
#     Current TP: 3.288, Current SL: 0.001
#     Target TP: 3.288, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303239649.
#     Position ID: 3303770477
#     Current TP: 3.288, Current SL: 0.001
#     Target TP: 3.288, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303770477.
#     Position ID: 3304121459
#     Current TP: 3.288, Current SL: 0.001
#     Target TP: 3.288, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304121459.
#     Position ID: 3304219700
#     Current TP: 3.288, Current SL: 0.001
#     Target TP: 3.288, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304219700.
#     Position ID: 3304239787
#     Current TP: 3.288, Current SL: 0.001
#     Target TP: 3.288, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304239787.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: GBPAUD ===
#   Action: Buy
#     Position ID: 3320821197
#     Current TP: 2.10062, Current SL: 1.68905
#     Target TP: 2.10062, Target SL: 1.68905
#     ✅ No changes needed for Buy position 3320821197.
#   Action: Sell
#     Position ID: 3299102816
#     Current TP: 2.04994, Current SL: 2.46151
#     Target TP: 2.04994, Target SL: 2.46151
#     ✅ No changes needed for Sell position 3299102816.
#     Position ID: 3320064995
#     Current TP: 2.04994, Current SL: 2.46151
#     Target TP: 2.04994, Target SL: 2.46151
#     ✅ No changes needed for Sell position 3320064995.
#
# === Checking Symbol: GBPCAD ===
#   Action: Buy
#     Position ID: 3307940973
#     Current TP: 1.86732, Current SL: 1.52398
#     Target TP: 1.86732, Target SL: 1.52398
#     ✅ No changes needed for Buy position 3307940973.
#     Position ID: 3317322191
#     Current TP: 1.86732, Current SL: 1.52398
#     Target TP: 1.86732, Target SL: 1.52398
#     ✅ No changes needed for Buy position 3317322191.
#   Action: Sell
#     Position ID: 3297345453
#     Current TP: 1.83906, Current SL: 2.1824
#     Target TP: 1.83906, Target SL: 2.1824
#     ✅ No changes needed for Sell position 3297345453.
#     Position ID: 3317322217
#     Current TP: 1.83906, Current SL: 2.1824
#     Target TP: 1.83906, Target SL: 2.1824
#     ✅ No changes needed for Sell position 3317322217.
#
# === Checking Symbol: GBPCHF ===
#   Action: Buy
#     ⚠️ No Buy positions running. Skipping.
#   Action: Sell
#     Position ID: 3298014406
#     Current TP: 1.09067, Current SL: 1.40847
#     Target TP: 1.09067, Target SL: 1.40847
#     ✅ No changes needed for Sell position 3298014406.
#
# === Checking Symbol: GBPJPY ===
#   Action: Buy
#     Position ID: 3304869137
#     Current TP: 197.191, Current SL: 144.426
#     Target TP: 197.191, Target SL: 144.426
#     ✅ No changes needed for Buy position 3304869137.
#   Action: Sell
#     Position ID: 3299912193
#     Current TP: 189.589, Current SL: 242.354
#     Target TP: 189.589, Target SL: 242.354
#     ✅ No changes needed for Sell position 3299912193.
#
# === Checking Symbol: GBPMXN ===
#   Action: Buy
#     Position ID: 3285596224
#     Current TP: 26.9703, Current SL: 21.5239
#     Target TP: 26.9703, Target SL: 21.5239
#     ✅ No changes needed for Buy position 3285596224.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: GBPNZD ===
#   Action: Buy
#     Position ID: 3310088345
#     Current TP: 2.26329, Current SL: 1.83132
#     Target TP: 2.26329, Target SL: 1.83132
#     ✅ No changes needed for Buy position 3310088345.
#     Position ID: 3320065557
#     Current TP: 2.26329, Current SL: 1.83132
#     Target TP: 2.26329, Target SL: 1.83132
#     ✅ No changes needed for Buy position 3320065557.
#   Action: Sell
#     Position ID: 3298767397
#     Current TP: 2.22102, Current SL: 2.65299
#     Target TP: 2.22102, Target SL: 2.65299
#     ✅ No changes needed for Sell position 3298767397.
#     Position ID: 3320065560
#     Current TP: 2.22102, Current SL: 2.65299
#     Target TP: 2.22102, Target SL: 2.65299
#     ✅ No changes needed for Sell position 3320065560.
#
# === Checking Symbol: GBPUSD ===
#   Action: Buy
#     Position ID: 3317742597
#     Current TP: 1.36646, Current SL: 1.0453
#     Target TP: 1.36646, Target SL: 1.0453
#     ✅ No changes needed for Buy position 3317742597.
#   Action: Sell
#     Position ID: 3303757685
#     Current TP: 1.31158, Current SL: 1.63274
#     Target TP: 1.31158, Target SL: 1.63274
#     ✅ No changes needed for Sell position 3303757685.
#
# === Checking Symbol: GBPZAR ===
#   Action: Buy
#     Position ID: 3297347553
#     Current TP: 25.01671, Current SL: 19.28434
#     Target TP: 25.01671, Target SL: 19.28434
#     ✅ No changes needed for Buy position 3297347553.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: GOOGL.NAS ===
#   Action: Buy
#     Position ID: 3319918090
#     Current TP: 182.03, Current SL: 120.0
#     Target TP: 182.03, Target SL: 120.0
#     ✅ No changes needed for Buy position 3319918090.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HD.NYSE ===
#   Action: Buy
#     Position ID: 3316577328
#     Current TP: 378.1, Current SL: 247.17
#     Target TP: 378.1, Target SL: 247.17
#     ✅ No changes needed for Buy position 3316577328.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HEIA.EAS ===
#   Action: Buy
#     Position ID: 3316897345
#     Current TP: 81.963, Current SL: 58.28
#     Target TP: 81.963, Target SL: 58.28
#     ✅ No changes needed for Buy position 3316897345.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HIT.TSE ===
#   Action: Buy
#     Position ID: 3319470514
#     Current TP: 4215.62, Current SL: 1843.81
#     Target TP: 4215.62, Target SL: 1843.81
#     ✅ No changes needed for Buy position 3319470514.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HMC.NYSE ===
#   Action: Buy
#     Position ID: 3295995003
#     Current TP: 30.75, Current SL: 0.01
#     Target TP: 30.75, Target SL: 0.01
#     ✅ No changes needed for Buy position 3295995003.
#     Position ID: 3319918275
#     Current TP: 30.75, Current SL: 0.01
#     Target TP: 30.75, Target SL: 0.01
#     ✅ No changes needed for Buy position 3319918275.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HON.NAS ===
#   Action: Buy
#     Position ID: 3318618984
#     Current TP: 231.92, Current SL: 123.08
#     Target TP: 231.92, Target SL: 123.08
#     ✅ No changes needed for Buy position 3318618984.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: HSBA.LSE ===
#   Action: Buy
#     Position ID: 3303764157
#     Current TP: 8.9675, Current SL: 0.0001
#     Target TP: 8.9675, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303764157.
#     Position ID: 3319961401
#     Current TP: 8.9675, Current SL: 0.0001
#     Target TP: 8.9675, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3319961401.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: IBM.NYSE ===
#   Action: Buy
#     Position ID: 3323011262
#     Current TP: 286.02, Current SL: 163.61
#     Target TP: 286.02, Target SL: 163.61
#     ✅ No changes needed for Buy position 3323011262.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: INTC.NAS ===
#   Action: Buy
#     Position ID: 3304188828
#     Current TP: 22.87, Current SL: 0.01
#     Target TP: 22.87, Target SL: 0.01
#     ✅ No changes needed for Buy position 3304188828.
#     Position ID: 3320065031
#     Current TP: 22.87, Current SL: 0.01
#     Target TP: 22.87, Target SL: 0.01
#     ✅ No changes needed for Buy position 3320065031.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: IOTAUSD ===
#   Action: Buy
#     Position ID: 3303174051
#     Current TP: 0.2667, Current SL: 0.0001
#     Target TP: 0.2667, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303174051.
#     Position ID: 3304127077
#     Current TP: 0.2667, Current SL: 0.0001
#     Target TP: 0.2667, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304127077.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ISP.MIL ===
#   Action: Buy
#     Position ID: 3302854899
#     Current TP: 5.0454, Current SL: 1.9226
#     Target TP: 5.0454, Target SL: 1.9226
#     ✅ No changes needed for Buy position 3302854899.
#     Position ID: 3304492379
#     Current TP: 5.0454, Current SL: 1.9226
#     Target TP: 5.0454, Target SL: 1.9226
#     ✅ No changes needed for Buy position 3304492379.
#     Position ID: 3315619847
#     Current TP: 5.0454, Current SL: 1.9226
#     Target TP: 5.0454, Target SL: 1.9226
#     ✅ No changes needed for Buy position 3315619847.
#     Position ID: 3316175322
#     Current TP: 5.0454, Current SL: 1.9226
#     Target TP: 5.0454, Target SL: 1.9226
#     ✅ No changes needed for Buy position 3316175322.
#     Position ID: 3319884108
#     Current TP: 5.0454, Current SL: 1.9226
#     Target TP: 5.0454, Target SL: 1.9226
#     ✅ No changes needed for Buy position 3319884108.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: ITX.BM ===
#   Action: Buy
#     Position ID: 3294683715
#     Current TP: 49.94, Current SL: 35.471
#     Target TP: 49.94, Target SL: 35.471
#     ✅ No changes needed for Buy position 3294683715.
#     Position ID: 3315620022
#     Current TP: 49.94, Current SL: 35.471
#     Target TP: 49.94, Target SL: 35.471
#     ✅ No changes needed for Buy position 3315620022.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: JAR.SGX ===
#   Action: Buy
#     Position ID: 3279704752
#     Current TP: 26.44, Current SL: 0.01
#     Target TP: 26.44, Target SL: 0.01
#     ✅ No changes needed for Buy position 3279704752.
#     Position ID: 3293425477
#     Current TP: 26.44, Current SL: 0.01
#     Target TP: 26.44, Target SL: 0.01
#     ✅ No changes needed for Buy position 3293425477.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: JD.NAS ===
#   Action: Buy
#     Position ID: 3304860748
#     Current TP: 38.37, Current SL: 0.01
#     Target TP: 38.37, Target SL: 0.01
#     ✅ No changes needed for Buy position 3304860748.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: JNJ.NYSE ===
#   Action: Buy
#     Position ID: 3278886088
#     Current TP: 159.07, Current SL: 122.19
#     Target TP: 159.07, Target SL: 122.19
#     ✅ No changes needed for Buy position 3278886088.
#     Position ID: 3293954893
#     Current TP: 159.07, Current SL: 122.19
#     Target TP: 159.07, Target SL: 122.19
#     ✅ No changes needed for Buy position 3293954893.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: JPM.NYSE ===
#   Action: Buy
#     Position ID: 3323011364
#     Current TP: 275.51, Current SL: 137.69
#     Target TP: 275.51, Target SL: 137.69
#     ✅ No changes needed for Buy position 3323011364.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: JPN225 ===
#   Action: Buy
#     Position ID: 3319516386
#     Current TP: 38855.0, Current SL: 24695.0
#     Target TP: 38855.0, Target SL: 24695.0
#     ✅ No changes needed for Buy position 3319516386.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: KEE.TSE ===
#   Action: Buy
#     Position ID: 3316607179
#     Current TP: 61369.31, Current SL: 44686.34
#     Target TP: 61369.31, Target SL: 44686.34
#     ✅ No changes needed for Buy position 3316607179.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: KO.NYSE ===
#   Action: Buy
#     Position ID: 3296715805
#     Current TP: 72.99, Current SL: 50.1
#     Target TP: 72.99, Target SL: 50.1
#     ✅ No changes needed for Buy position 3296715805.
#     Position ID: 3319961474
#     Current TP: 72.99, Current SL: 50.1
#     Target TP: 72.99, Target SL: 50.1
#     ✅ No changes needed for Buy position 3319961474.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LI.NAS ===
#   Action: Buy
#     Position ID: 3319432279
#     Current TP: 31.23, Current SL: 0.01
#     Target TP: 31.23, Target SL: 0.01
#     ✅ No changes needed for Buy position 3319432279.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LIN.NYSE ===
#   Action: Buy
#     Position ID: 3316577295
#     Current TP: 476.73, Current SL: 315.0
#     Target TP: 476.73, Target SL: 315.0
#     ✅ No changes needed for Buy position 3316577295.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LINKUSD ===
#   Action: Buy
#     Position ID: 3303764332
#     Current TP: 18.096, Current SL: 0.001
#     Target TP: 18.096, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303764332.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LLY.NYSE ===
#   Action: Buy
#     Position ID: 3320628183
#     Current TP: 826.0, Current SL: 621.31
#     Target TP: 826.0, Target SL: 621.31
#     ✅ No changes needed for Buy position 3320628183.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LMT.NYSE ===
#   Action: Buy
#     Position ID: 3317232550
#     Current TP: 491.12, Current SL: 340.72
#     Target TP: 491.12, Target SL: 340.72
#     ✅ No changes needed for Buy position 3317232550.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LRCUSD ===
#   Action: Buy
#     Position ID: 3299514904
#     Current TP: 0.1267, Current SL: 0.0001
#     Target TP: 0.1267, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3299514904.
#     Position ID: 3304127358
#     Current TP: 0.1267, Current SL: 0.0001
#     Target TP: 0.1267, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304127358.
#     Position ID: 3306729027
#     Current TP: 0.1267, Current SL: 0.0001
#     Target TP: 0.1267, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3306729027.
#     Position ID: 3319884211
#     Current TP: 0.1267, Current SL: 0.0001
#     Target TP: 0.1267, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3319884211.
#     Position ID: 3320065579
#     Current TP: 0.1267, Current SL: 0.0001
#     Target TP: 0.1267, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3320065579.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LSEG.LSE ===
#   Action: Buy
#     Position ID: 3312480645
#     Current TP: 119.48, Current SL: 64.56
#     Target TP: 119.48, Target SL: 64.56
#     ✅ No changes needed for Buy position 3312480645.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: LTCUSD ===
#   Action: Buy
#     Position ID: 3303003157
#     Current TP: 108.21, Current SL: 0.01
#     Target TP: 108.21, Target SL: 0.01
#     ✅ No changes needed for Buy position 3303003157.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MANAUSD ===
#   Action: Buy
#     Position ID: 3303174266
#     Current TP: 0.3927, Current SL: 0.0001
#     Target TP: 0.3927, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303174266.
#     Position ID: 3303239684
#     Current TP: 0.3927, Current SL: 0.0001
#     Target TP: 0.3927, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303239684.
#     Position ID: 3304128204
#     Current TP: 0.3927, Current SL: 0.0001
#     Target TP: 0.3927, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304128204.
#     Position ID: 3304176884
#     Current TP: 0.3927, Current SL: 0.0001
#     Target TP: 0.3927, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304176884.
#     Position ID: 3319961545
#     Current TP: 0.3927, Current SL: 0.0001
#     Target TP: 0.3927, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3319961545.
#     Position ID: 3320197906
#     Current TP: 0.3927, Current SL: 0.0001
#     Target TP: 0.3927, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3320197906.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MBG.XE ===
#   Action: Buy
#     Position ID: 3294703468
#     Current TP: 55.75, Current SL: 29.15
#     Target TP: 55.75, Target SL: 29.15
#     ✅ No changes needed for Buy position 3294703468.
#     Position ID: 3299026423
#     Current TP: 55.75, Current SL: 29.15
#     Target TP: 55.75, Target SL: 29.15
#     ✅ No changes needed for Buy position 3299026423.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MC.EPA ===
#   Action: Buy
#     Position ID: 3317455215
#     Current TP: 488.79, Current SL: 389.89
#     Target TP: 488.79, Target SL: 389.89
#     ✅ No changes needed for Buy position 3317455215.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MCD.NYSE ===
#   Action: Buy
#     Position ID: 3308743172
#     Current TP: 324.71, Current SL: 209.3
#     Target TP: 324.71, Target SL: 209.3
#     ✅ No changes needed for Buy position 3308743172.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MDLZ.NAS ===
#   Action: Buy
#     Position ID: 3296717234
#     Current TP: 68.92, Current SL: 51.51
#     Target TP: 68.92, Target SL: 51.51
#     ✅ No changes needed for Buy position 3296717234.
#     Position ID: 3317232565
#     Current TP: 68.92, Current SL: 51.51
#     Target TP: 68.92, Target SL: 51.51
#     ✅ No changes needed for Buy position 3317232565.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MMM.NYSE ===
#   Action: Buy
#     Position ID: 3308743325
#     Current TP: 156.02, Current SL: 98.35
#     Target TP: 156.02, Target SL: 98.35
#     ✅ No changes needed for Buy position 3308743325.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MRK.XE ===
#   Action: Buy
#     Position ID: 3304493136
#     Current TP: 128.3834, Current SL: 104.7919
#     Target TP: 128.3834, Target SL: 104.7919
#     ✅ No changes needed for Buy position 3304493136.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MS.NYSE ===
#   Action: Buy
#     Position ID: 3306521810
#     Current TP: 135.27, Current SL: 53.05
#     Target TP: 135.27, Target SL: 53.05
#     ✅ No changes needed for Buy position 3306521810.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: MUR.TSE ===
#   Action: Buy
#     Position ID: 3320821304
#     Current TP: 2205.22, Current SL: 1707.43
#     Target TP: 2205.22, Target SL: 1707.43
#     ✅ No changes needed for Buy position 3320821304.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NAB.ASX ===
#   Action: Buy
#     Position ID: 3320134592
#     Current TP: 39.81, Current SL: 24.53
#     Target TP: 39.81, Target SL: 24.53
#     ✅ No changes needed for Buy position 3320134592.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NEARUSD ===
#   Action: Buy
#     Position ID: 3303173156
#     Current TP: 3.535, Current SL: 0.001
#     Target TP: 3.535, Target SL: 0.001
#     ✅ No changes needed for Buy position 3303173156.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NEE.NYSE ===
#   Action: Buy
#     Position ID: 3322032364
#     Current TP: 75.42, Current SL: 55.71
#     Target TP: 75.42, Target SL: 55.71
#     ✅ No changes needed for Buy position 3322032364.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NESTE.OMXH ===
#   Action: Buy
#     Position ID: 3319810870
#     Current TP: 10.86, Current SL: 0.01
#     Target TP: 10.86, Target SL: 0.01
#     ✅ No changes needed for Buy position 3319810870.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NID.TSE ===
#   Action: Buy
#     Position ID: 3305794022
#     Current TP: 2919.03, Current SL: 0.01
#     Target TP: 2919.03, Target SL: 0.01
#     ✅ No changes needed for Buy position 3305794022.
#     Position ID: 3308239278
#     Current TP: 2919.03, Current SL: 0.01
#     Target TP: 2919.03, Target SL: 0.01
#     ✅ No changes needed for Buy position 3308239278.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NKE.NYSE ===
#   Action: Buy
#     Position ID: 3320628288
#     Current TP: 64.27, Current SL: 0.01
#     Target TP: 64.27, Target SL: 0.01
#     ✅ No changes needed for Buy position 3320628288.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NOKIA.OMXH ===
#   Action: Buy
#     Position ID: 3276134396
#     Current TP: 4.7607, Current SL: 0.0001
#     Target TP: 4.7607, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3276134396.
#     Position ID: 3292135089
#     Current TP: 4.7607, Current SL: 0.0001
#     Target TP: 4.7607, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3292135089.
#     Position ID: 3293980710
#     Current TP: 4.7607, Current SL: 0.0001
#     Target TP: 4.7607, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3293980710.
#     Position ID: 3299027603
#     Current TP: 4.7607, Current SL: 0.0001
#     Target TP: 4.7607, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3299027603.
#     Position ID: 3304492678
#     Current TP: 4.7607, Current SL: 0.0001
#     Target TP: 4.7607, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304492678.
#     Position ID: 3304547359
#     Current TP: 4.7607, Current SL: 0.0001
#     Target TP: 4.7607, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3304547359.
#     Position ID: 3312684738
#     Current TP: 4.7607, Current SL: 0.0001
#     Target TP: 4.7607, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3312684738.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NVDA.NAS ===
#   Action: Buy
#     Position ID: 3323011380
#     Current TP: 149.39, Current SL: 40.93
#     Target TP: 149.39, Target SL: 40.93
#     ✅ No changes needed for Buy position 3323011380.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: NZDCAD ===
#   Action: Buy
#     Position ID: 3304830506
#     Current TP: 0.83079, Current SL: 0.69914
#     Target TP: 0.83079, Target SL: 0.69914
# ...
#     Position ID: 3320628409
#     Current TP: 24.98, Current SL: 0.01
#     Target TP: 24.98, Target SL: 0.01
#     ✅ No changes needed for Buy position 3320628409.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: PG.NYSE ===
#   Action: Buy
#     Position ID: 3314887529
#     Current TP: 170.48, Current SL: 120.56
#     Target TP: 170.48, Target SL: 120.56
#     ✅ No changes needed for Buy position 3314887529.
#     Position ID: 3315884752
#     Current TP: 170.48, Current SL: 120.56
#     Target TP: 170.48, Target SL: 120.56
#     ✅ No changes needed for Buy position 3315884752.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: PYPL.NAS ===
#   Action: Buy
#     Position ID: 3320056979
#     Current TP: 75.61, Current SL: 0.01
#     Target TP: 75.61, Target SL: 0.01
#     ✅ No changes needed for Buy position 3320056979.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: QCOM.NAS ===
#   Action: Buy
#     Position ID: 3320628943
#     Current TP: 164.07, Current SL: 103.2
#     Target TP: 164.07, Target SL: 103.2
#     ✅ No changes needed for Buy position 3320628943.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: RACE.MIL ===
#   Action: Buy
#     Position ID: 3314563915
#     Current TP: 429.84, Current SL: 327.75
#     Target TP: 429.84, Target SL: 327.75
#     ✅ No changes needed for Buy position 3314563915.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: RTX.NYSE ===
#   Action: Buy
#     Position ID: 3322024283
#     Current TP: 147.49, Current SL: 79.46
#     Target TP: 147.49, Target SL: 79.46
#     ✅ No changes needed for Buy position 3322024283.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SAN.BM ===
#   Action: Buy
#     Position ID: 3308590585
#     Current TP: 7.2214, Current SL: 0.0001
#     Target TP: 7.2214, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3308590585.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SBUX.NAS ===
#   Action: Buy
#     Position ID: 3320629057
#     Current TP: 95.83, Current SL: 56.99
#     Target TP: 95.83, Target SL: 56.99
#     ✅ No changes needed for Buy position 3320629057.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SHEL.LSE ===
#   Action: Buy
#     Position ID: 3321700948
#     Current TP: 26.92, Current SL: 0.01
#     Target TP: 26.92, Target SL: 0.01
#     ✅ No changes needed for Buy position 3321700948.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SHOP.NYSE ===
#   Action: Buy
#     Position ID: 3320629167
#     Current TP: 117.83, Current SL: 0.01
#     Target TP: 117.83, Target SL: 0.01
#     ✅ No changes needed for Buy position 3320629167.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SIE.XE ===
#   Action: Buy
#     Position ID: 3320253302
#     Current TP: 224.331, Current SL: 101.982
#     Target TP: 224.331, Target SL: 101.982
#     ✅ No changes needed for Buy position 3320253302.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SOLUSD ===
#   Action: Buy
#     Position ID: 3320065668
#     Current TP: 172.37, Current SL: 0.01
#     Target TP: 172.37, Target SL: 0.01
#     ✅ No changes needed for Buy position 3320065668.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SONY.NYSE ===
#   Action: Buy
#     Position ID: 3312684869
#     Current TP: 27.03, Current SL: 11.03
#     Target TP: 27.03, Target SL: 11.03
#     ✅ No changes needed for Buy position 3312684869.
#     Position ID: 3315708507
#     Current TP: 27.03, Current SL: 11.03
#     Target TP: 27.03, Target SL: 11.03
#     ✅ No changes needed for Buy position 3315708507.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: STLA.MIL ===
#   Action: Buy
#     Position ID: 3304836943
#     Current TP: 9.986, Current SL: 0.001
#     Target TP: 9.986, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304836943.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SUIUSD ===
#   Action: Buy
#     Position ID: 3303764586
#     Current TP: 4.3359, Current SL: 0.0001
#     Target TP: 4.3359, Target SL: 0.0001
#     ✅ No changes needed for Buy position 3303764586.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: SVN.TSE ===
#   Action: Buy
#     Position ID: 3303526044
#     Current TP: 2324.74, Current SL: 1645.6
#     Target TP: 2324.74, Target SL: 1645.6
#     ✅ No changes needed for Buy position 3303526044.
#     Position ID: 3304239917
#     Current TP: 2324.74, Current SL: 1645.6
#     Target TP: 2324.74, Target SL: 1645.6
#     ✅ No changes needed for Buy position 3304239917.
#     Position ID: 3315928706
#     Current TP: 2324.74, Current SL: 1645.6
#     Target TP: 2324.74, Target SL: 1645.6
#     ✅ No changes needed for Buy position 3315928706.
#     Position ID: 3315929534
#     Current TP: 2324.74, Current SL: 1645.6
#     Target TP: 2324.74, Target SL: 1645.6
#     ✅ No changes needed for Buy position 3315929534.
#     Position ID: 3319470619
#     Current TP: 2324.74, Current SL: 1645.6
#     Target TP: 2324.74, Target SL: 1645.6
#     ✅ No changes needed for Buy position 3319470619.
#     Position ID: 3320109024
#     Current TP: 2324.74, Current SL: 1645.6
#     Target TP: 2324.74, Target SL: 1645.6
#     ✅ No changes needed for Buy position 3320109024.
#     Position ID: 3320134742
#     Current TP: 2324.74, Current SL: 1645.6
#     Target TP: 2324.74, Target SL: 1645.6
#     ✅ No changes needed for Buy position 3320134742.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: T.NYSE ===
#   Action: Buy
#     Position ID: 3319974697
#     Current TP: 28.72, Current SL: 17.62
#     Target TP: 28.72, Target SL: 17.62
#     ✅ No changes needed for Buy position 3319974697.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TCEHY.OTC ===
#   Action: Buy
#     Position ID: 3305638500
#     Current TP: 67.659, Current SL: 34.518
#     Target TP: 67.659, Target SL: 34.518
#     ✅ No changes needed for Buy position 3305638500.
#     Position ID: 3306359369
#     Current TP: 67.659, Current SL: 34.518
#     Target TP: 67.659, Target SL: 34.518
#     ✅ No changes needed for Buy position 3306359369.
#     Position ID: 3320065686
#     Current TP: 67.659, Current SL: 34.518
#     Target TP: 67.659, Target SL: 34.518
#     ✅ No changes needed for Buy position 3320065686.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TKY.TSE ===
#   Action: Buy
#     Position ID: 3320821330
#     Current TP: 25184.72, Current SL: 13922.56
#     Target TP: 25184.72, Target SL: 13922.56
#     ✅ No changes needed for Buy position 3320821330.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TM.TSE ===
#   Action: Buy
#     Position ID: 3304242075
#     Current TP: 2914.98, Current SL: 1829.34
#     Target TP: 2914.98, Target SL: 1829.34
#     ✅ No changes needed for Buy position 3304242075.
#     Position ID: 3304380529
#     Current TP: 2914.98, Current SL: 1829.34
#     Target TP: 2914.98, Target SL: 1829.34
#     ✅ No changes needed for Buy position 3304380529.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TMH.TSE ===
#   Action: Buy
#     Position ID: 3316644483
#     Current TP: 6517.54, Current SL: 0.01
#     Target TP: 6517.54, Target SL: 0.01
#     ✅ No changes needed for Buy position 3316644483.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TMO.NYSE ===
#   Action: Buy
#     Position ID: 3295995689
#     Current TP: 435.52, Current SL: 342.65
#     Target TP: 435.52, Target SL: 342.65
#     ✅ No changes needed for Buy position 3295995689.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TMUS.NAS ===
#   Action: Buy
#     Position ID: 3316577325
#     Current TP: 247.77, Current SL: 116.68
#     Target TP: 247.77, Target SL: 116.68
#     ✅ No changes needed for Buy position 3316577325.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TTE.EPA ===
#   Action: Buy
#     Position ID: 3321700977
#     Current TP: 56.58, Current SL: 37.9
#     Target TP: 56.58, Target SL: 37.9
#     ✅ No changes needed for Buy position 3321700977.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: TXN.NAS ===
#   Action: Buy
#     Position ID: 3319432312
#     Current TP: 203.67, Current SL: 102.06
#     Target TP: 203.67, Target SL: 102.06
#     ✅ No changes needed for Buy position 3319432312.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UCG.MIL ===
#   Action: Buy
#     Position ID: 3309225864
#     Current TP: 59.353, Current SL: 0.001
#     Target TP: 59.353, Target SL: 0.001
#     ✅ No changes needed for Buy position 3309225864.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UNIUSD ===
#   Action: Buy
#     Position ID: 3320108856
#     Current TP: 9.082, Current SL: 0.001
#     Target TP: 9.082, Target SL: 0.001
#     ✅ No changes needed for Buy position 3320108856.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UNP.NYSE ===
#   Action: Buy
#     Position ID: 3307217889
#     Current TP: 234.63, Current SL: 152.57
#     Target TP: 234.63, Target SL: 152.57
#     ✅ No changes needed for Buy position 3307217889.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: UPS.NYSE ===
#   Action: Buy
#     Position ID: 3320629352
#     Current TP: 102.92, Current SL: 89.1
#     Target TP: 102.92, Target SL: 89.1
#     ✅ No changes needed for Buy position 3320629352.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: USDCAD ===
#   Action: Buy
#     Position ID: 3307143399
#     Current TP: 1.39434, Current SL: 1.22043
#     Target TP: 1.39434, Target SL: 1.22043
#     ✅ No changes needed for Buy position 3307143399.
#     Position ID: 3315621219
#     Current TP: 1.39434, Current SL: 1.22043
#     Target TP: 1.39434, Target SL: 1.22043
#     ✅ No changes needed for Buy position 3315621219.
#   Action: Sell
#     Position ID: 3323011224
#     Current TP: 1.35037, Current SL: 1.52428
#     Target TP: 1.35037, Target SL: 1.52428
#     ✅ No changes needed for Sell position 3323011224.
#
# === Checking Symbol: USDJPY ===
#   Action: Buy
#     Position ID: 3303757544
#     Current TP: 147.094, Current SL: 129.482
#     Target TP: 147.094, Target SL: 129.482
#     ✅ No changes needed for Buy position 3303757544.
#     Position ID: 3304223239
#     Current TP: 147.094, Current SL: 129.482
#     Target TP: 147.094, Target SL: 129.482
#     ✅ No changes needed for Buy position 3304223239.
#     Position ID: 3315621326
#     Current TP: 147.094, Current SL: 129.482
#     Target TP: 147.094, Target SL: 129.482
#     ✅ No changes needed for Buy position 3315621326.
#   Action: Sell
#     Position ID: 3310841966
#     Current TP: 141.926, Current SL: 159.538
#     Target TP: 141.926, Target SL: 159.538
#     ✅ No changes needed for Sell position 3310841966.
#     Position ID: 3315621376
#     Current TP: 141.926, Current SL: 159.538
#     Target TP: 141.926, Target SL: 159.538
#     ✅ No changes needed for Sell position 3315621376.
#
# === Checking Symbol: USDMXN ===
#   Action: Buy
#     Position ID: 3293437457
#     Current TP: 19.7216, Current SL: 17.6596
#     Target TP: 19.7216, Target SL: 17.6596
#     ✅ No changes needed for Buy position 3293437457.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: USDZAR ===
#   Action: Buy
#     Position ID: 3293437473
#     Current TP: 18.99187, Current SL: 14.80714
#     Target TP: 18.99187, Target SL: 14.80714
#     ✅ No changes needed for Buy position 3293437473.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: V.NYSE ===
#   Action: Buy
#     Position ID: 3320629501
#     Current TP: 379.02, Current SL: 250.82
#     Target TP: 379.02, Target SL: 250.82
#     ✅ No changes needed for Buy position 3320629501.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: VNA.XE ===
#   Action: Buy
#     Position ID: 3301984800
#     Current TP: 30.358, Current SL: 0.001
#     Target TP: 30.358, Target SL: 0.001
#     ✅ No changes needed for Buy position 3301984800.
#     Position ID: 3316897484
#     Current TP: 30.358, Current SL: 0.001
#     Target TP: 30.358, Target SL: 0.001
#     ✅ No changes needed for Buy position 3316897484.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: VOW3.XE ===
#   Action: Buy
#     Position ID: 3304856583
#     Current TP: 106.474, Current SL: 0.001
#     Target TP: 106.474, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304856583.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: VZ.NYSE ===
#   Action: Buy
#     Position ID: 3308743558
#     Current TP: 44.88, Current SL: 29.42
#     Target TP: 44.88, Target SL: 29.42
#     ✅ No changes needed for Buy position 3308743558.
#     Position ID: 3315708894
#     Current TP: 44.88, Current SL: 29.42
#     Target TP: 44.88, Target SL: 29.42
#     ✅ No changes needed for Buy position 3315708894.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: WES.ASX ===
#   Action: Buy
#     Position ID: 3317303003
#     Current TP: 86.17, Current SL: 53.85
#     Target TP: 86.17, Target SL: 53.85
#     ✅ No changes needed for Buy position 3317303003.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: WFC.NYSE ===
#   Action: Buy
#     Position ID: 3317232595
#     Current TP: 76.91, Current SL: 41.45
#     Target TP: 76.91, Target SL: 41.45
#     ✅ No changes needed for Buy position 3317232595.
#     Position ID: 3317232600
#     Current TP: 76.91, Current SL: 41.45
#     Target TP: 76.91, Target SL: 41.45
#     ✅ No changes needed for Buy position 3317232600.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: WMT.NYSE ===
#   Action: Buy
#     Position ID: 3316577341
#     Current TP: 101.16, Current SL: 73.45
#     Target TP: 101.16, Target SL: 73.45
#     ✅ No changes needed for Buy position 3316577341.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: XBRUSD ===
#   Action: Buy
#     Position ID: 3321706399
#     Current TP: 74.73, Current SL: 0.01
#     Target TP: 74.73, Target SL: 0.01
#     ✅ No changes needed for Buy position 3321706399.
#   Action: Sell
#     Position ID: 3314887507
#     Current TP: 61.54, Current SL: 136.26
#     Target TP: 61.54, Target SL: 136.26
#     ✅ No changes needed for Sell position 3314887507.
#
# === Checking Symbol: XNGUSD ===
#   Action: Buy
#     Position ID: 3304493382
#     Current TP: 4.087, Current SL: 0.001
#     Target TP: 4.087, Target SL: 0.001
#     ✅ No changes needed for Buy position 3304493382.
#   Action: Sell
#     Position ID: 3308412938
#     Current TP: 3.347, Current SL: 7.433
#     Target TP: 3.347, Target SL: 7.433
#     ✅ No changes needed for Sell position 3308412938.
#
# === Checking Symbol: XOM.NYSE ===
#   Action: Buy
#     Position ID: 3278885254
#     Current TP: 115.25, Current SL: 77.83
#     Target TP: 115.25, Target SL: 77.83
#     ✅ No changes needed for Buy position 3278885254.
#     Position ID: 3293990121
#     Current TP: 115.25, Current SL: 77.83
#     Target TP: 115.25, Target SL: 77.83
#     ✅ No changes needed for Buy position 3293990121.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === Checking Symbol: XTIUSD ===
#   Action: Buy
#     Position ID: 3322329790
#     Current TP: 73.81, Current SL: 0.01
#     Target TP: 73.81, Target SL: 0.01
#     ✅ No changes needed for Buy position 3322329790.
#   Action: Sell
#     Position ID: 3314887519
#     Current TP: 59.06, Current SL: 132.86
#     Target TP: 59.06, Target SL: 132.86
#     ✅ No changes needed for Sell position 3314887519.
#
# === Checking Symbol: ZECUSD ===
#   Action: Buy
#     Position ID: 3311554264
#     Current TP: 57.25, Current SL: 0.01
#     Target TP: 57.25, Target SL: 0.01
#     ✅ No changes needed for Buy position 3311554264.
#   Action: Sell
#     ⚠️ No Sell positions running. Skipping.
#
# === TP/SL Modification Summary ===
# Total Successful Modifications: 2
# Total Failed Modifications: 0
