# %%
# === Imports === #
import MetaTrader5 as mt5
import pandas as pd
import numpy as np
import yaml
import os
from google_sheet_api import GoogleSheetsUploader

# === Setup Paths === #
BASE_DIR = os.getcwd()
CONFIG_PATH = os.path.join(BASE_DIR, "config.yaml")
CREDENTIAL_PATH = os.path.join(BASE_DIR, "credential_google_sheets.json")

# === Load Configuration === #
def load_config(path):
    """Load configuration from YAML file."""
    with open(path, "r") as file:
        return yaml.safe_load(file)

config = load_config(CONFIG_PATH)

# === Initialize MT5 Connection === #
if not mt5.initialize():
    print("MT5 initialization failed.")
    quit()

# === Retrieve Account Information === #
account_info = mt5.account_info()
if account_info is None:
    print("Failed to retrieve account information.")
    mt5.shutdown()
    quit()

# === Extract Balance, Equity, and Floating Loss === #
balance = account_info.balance
equity = account_info.equity
floating_loss = account_info.profit

# === Display Results === #
print("=== Account Information ===")
print(f"Balance: {balance:.2f} USD")
print(f"Equity: {equity:.2f} USD")
print(f"Floating Loss: {floating_loss:.2f} USD")

# === Fetch and Process Running Trades === #
fetcher = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")
df = fetcher.get_sheet_as_dataframe("Forex")
positions = mt5.positions_get()
df_positions = pd.DataFrame([pos._asdict() for pos in positions]) if positions else pd.DataFrame()

if df_positions.empty:
    print("No running trades found. Error:", mt5.last_error())
else:
    # Filter and rename columns
    df_positions = df_positions[["type", "volume", "price_open", "price_current", "sl", "tp", "profit", "symbol"]]
    df_positions["type"] = df_positions["type"].replace({0: "Buy", 1: "Sell"})
    df_positions.rename(columns={
        "symbol": "Symbol",
        "type": "Action",
        "volume": "Lot",
        "price_open": "Price",
        "price_current": "Price Current",
        "sl": "SL",
        "tp": "TP",
        "profit": "Profit"
    }, inplace=True)

    # Aggregate by Symbol and Action
    def aggregate_group(group):
        symbol = group["Symbol"].iloc[0]
        action = group["Action"].iloc[0]
        lot = group["Lot"].sum()
        warnings = []

        # === Lot mismatch check === #
        df_lot_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[5]].sum()
        if not pd.isna(df_lot_value) and round(df_lot_value, 2) > round(lot, 2):
            warnings.append(f"Lot Mismatch: Expected {round(df_lot_value, 2)}, Found {round(lot, 2)}")

        # === SL/TP mismatch check === #
        df_sl_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[7]].sum()
        sl_mode = group["SL"].mode().iloc[0] if not group["SL"].mode().empty else np.nan
        if group["SL"].nunique() > 1 or (df_sl_value != 0 and round(df_sl_value, 2) != round(sl_mode, 2)):
            warnings.append("SL Mismatch")

        df_tp_value = df.loc[(df.iloc[:, 0] == symbol) & (df.iloc[:, 2] == action), df.columns[8]].sum()
        tp_mode = group["TP"].mode().iloc[0] if not group["TP"].mode().empty else np.nan
        if group["TP"].nunique() > 1 or round(df_tp_value, 2) != round(tp_mode, 2):
            warnings.append("TP Mismatch")

        # Combine warnings
        warning_message = "; ".join(warnings) if warnings else np.nan

        return pd.Series({
            "Lot": lot,
            "Price": (group["Price"] * group["Lot"]).sum() / group["Lot"].sum(),
            "Price Current": group["Price Current"].mean(),
            "SL": group["SL"].mode().iloc[0] if not group["SL"].empty else np.nan,
            "TP": group["TP"].mode().iloc[0] if not group["TP"].empty else np.nan,
            "Profit": group["Profit"].sum(),
            "Warning": warning_message
        })

    df_positions = (
        df_positions.groupby(["Symbol", "Action"], as_index=False)
        .apply(lambda group: aggregate_group(group))
        .reset_index(drop=True)
    )

# === Shutdown MT5 Connection === #
mt5.shutdown()

# === Calculate Coefficients === #
df_positions["Coeff"] = np.abs(df_positions["Profit"] / (df_positions["Price Current"] - df_positions["Price"])) / (df_positions["Lot"] * 100)
df_positions["Pips"] = np.abs(df_positions["TP"] - df_positions["SL"])

# Merging the Type column based on Symbol
df_type = df[[df.columns[0], df.columns[1]]].drop_duplicates()
df_type.columns = ["Symbol", "Type"]
df_positions = pd.merge(df_positions, df_type, on="Symbol", how="left")

# Handling missing types (optional)
df_positions['Type'].fillna("Unknown", inplace=True)

df_positions

# === Update Coefficients in Config (Exclude NaN) === #
df_avg_coeff = df_positions.groupby("Symbol")["Coeff"].mean().reset_index()
differences = {}

for _, row in df_avg_coeff.iterrows():
    symbol = row["Symbol"]
    avg_coeff = round(row["Coeff"], 5)
    
    # Only update if coefficient is not NaN
    if not pd.isna(avg_coeff):
        if symbol in config.get("symbol_coefficients", {}):
            old_coeff = config["symbol_coefficients"].get(symbol, avg_coeff)
            if old_coeff != avg_coeff:
                differences[symbol] = {"Old": old_coeff, "New": avg_coeff}
        
        # Add or update the coefficient
        config["symbol_coefficients"][symbol] = avg_coeff

# === Save Updated Configuration === #
with open(CONFIG_PATH, "w") as file:
    yaml.safe_dump(config, file)

# === Display Changed Coefficients === #
print("Changed symbol_coefficients:")
for symbol, change in differences.items():
    print(f"{symbol}: {change['Old']} -> {change['New']}")

# Creating new rows for Balance, Equity, and Floating Loss
df_balance = pd.DataFrame([
    {"Symbol": "Balance", "Price": balance},
    {"Symbol": "Equity", "Price": equity},
    {"Symbol": "Floating Loss", "Price": floating_loss}
])

# Inserting the new rows at the top of the DataFrame
df_final = pd.concat([df_balance, df_positions], ignore_index=True)

# === Uploade Updated Dataframe === #
uploader = GoogleSheetsUploader(CREDENTIAL_PATH, "Financial Report - Indonesia")
uploader.upload_dataframe(df_final, "Forex Summary", replace=True)

# === Display Final Merged DataFrame === #
print("Final Merged DataFrame:")
df_final

# %%
import time

# === Initialize MT5 Connection === #
if not mt5.initialize():
    print("MT5 initialization failed.")
    quit()
    
# Load DataFrame from Google Sheets
df = fetcher.get_sheet_as_dataframe("Forex")
df.columns = df.iloc[5]
df = df.iloc[6:-3].reset_index(drop=True)

# Initialize counters for success and failure
success_count = 0
failure_count = 0

# Iterate through each unique symbol and action
symbol_list = df["Symbol"].unique()
for symbol in symbol_list:
#for symbol in ["ADAUSD"]:
    for action in ["Buy", "Sell"]:
        # Filter rows for the current symbol and action
        df_filtered = df[(df["Symbol"] == symbol) & (df["Action"] == action)]
        
        if not df_filtered.empty:
            print(f"Symbol: {symbol}")
            print(f"Action: {action}")

            tp_value = round(df_filtered['TP'].values[0], 5)
            sl_value = round(df_filtered['SL'].values[0], 5)

            # === Fetch Open Positions for the Specified Symbol ===
            positions = mt5.positions_get(symbol=symbol)
            if positions is None or len(positions) == 0:
                print(f"No open positions found for {symbol}.")
                continue

            # === Modify TP/SL for All Trades based on Action ===
            for pos in positions:
                action_type = "Buy" if pos.type == 0 else "Sell"
                
                # Ensure it only modifies the correct action type (Buy or Sell)
                if action_type == action:
                    order_id = pos.ticket
                    current_tp = pos.tp
                    current_sl = pos.sl

                    # Only modify if the new TP/SL values differ from current
                    if current_tp == tp_value and current_sl == sl_value:
                        print(f"✅ No changes for {action_type} position {order_id}. TP/SL already set.")
                        continue

                    # Modify TP/SL using position ID
                    request = {
                        "action": mt5.TRADE_ACTION_SLTP,
                        "position": order_id,
                        "sl": sl_value,
                        "tp": tp_value
                    }

                    # Send modification request
                    result = mt5.order_send(request)
                    time.sleep(1)  # Delay of 2 seconds between each request

                    # Check if result is None (Error)
                    if result is None:
                        print(f"⚠️ Failed to modify {action_type} position {order_id}. Error: Request returned None.")
                        failure_count += 1
                        continue

                    # Check if the modification was successful
                    if result.retcode == mt5.TRADE_RETCODE_DONE:
                        print(f"{action_type} position {order_id} modified successfully.")
                        print(f"Before: TP={current_tp}, SL={current_sl}")
                        print(f"After:  TP={tp_value}, SL={sl_value}\n")
                        success_count += 1
                    else:
                        print(f"⚠️ Failed to modify {action_type} position {order_id}. Error: {result.comment}")
                        failure_count += 1
                else:
                    print(f"⚠️ Skipping {action_type} position {pos.ticket} - does not match action {action}.")

# === Shutdown MT5 Connection === #
mt5.shutdown()

# === Summary Report ===
print("\n=== TP/SL Modification Summary ===")
print(f"Total Successful Modifications: {success_count}")
print(f"Total Failed Modifications: {failure_count}")
# Out:
# ✅ Successfully retrieved data from 'Forex' as a DataFrame.
# Symbol: AAPL.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3297549570. Error: Market closed
# Symbol: AAVEUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3302602638. Error: Request returned None.
# Symbol: ABBV.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3298446412. Error: Market closed
# Symbol: ABNB.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304860529. Error: Request returned None.
# Symbol: ABT.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3302221724. Error: Market closed
# Symbol: ACN.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304837038. Error: Market closed
# Symbol: ADAUSD
# Action: Buy
# ✅ No changes for Buy position 3304100487. TP/SL already set.
# Symbol: ADBE.NAS
# Action: Buy
# No open positions found for ADBE.NAS.
# Symbol: ADS.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3305209594. Error: No changes
# Symbol: AI.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3297913700. Error: No changes
# Symbol: AIR.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3305210944. Error: No changes
# Symbol: ALGOUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304100698. Error: Request returned None.
# Symbol: ALV.XE
# Action: Buy
# No open positions found for ALV.XE.
# Symbol: AMD.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304858347. Error: Request returned None.
# Symbol: AMZN.NAS
# Action: Buy
# No open positions found for AMZN.NAS.
# Symbol: APTUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303173396. Error: Request returned None.
# Symbol: ASML.EAS
# Action: Buy
# No open positions found for ASML.EAS.
# Symbol: ATOMUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303174194. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3304176535. Error: Request returned None.
# Symbol: AUDCAD
# Action: Buy
# ⚠️ Skipping Sell position 3301252618 - does not match action Buy.
# ⚠️ Skipping Sell position 3304223072 - does not match action Buy.
# ⚠️ Skipping Sell position 3304229587 - does not match action Buy.
# ✅ No changes for Buy position 3304834368. TP/SL already set.
# Symbol: AUDCAD
# Action: Sell
# Sell position 3301252618 modified successfully.
# Before: TP=0.88671, SL=1.04804
# After:  TP=0.88671, SL=1.04729
#
# Sell position 3304223072 modified successfully.
# Before: TP=0.88671, SL=1.04804
# After:  TP=0.88671, SL=1.04729
#
# Sell position 3304229587 modified successfully.
# Before: TP=0.88671, SL=1.04804
# After:  TP=0.88671, SL=1.04729
#
# ⚠️ Skipping Buy position 3304834368 - does not match action Sell.
# Symbol: AUDCHF
# Action: Sell
# ✅ No changes for Sell position 3296721794. TP/SL already set.
# Symbol: AUDJPY
# Action: Buy
# ⚠️ Skipping Sell position 3295995295 - does not match action Buy.
# ⚠️ Skipping Sell position 3304223099 - does not match action Buy.
# ⚠️ Failed to modify Buy position 3304837518. Error: No changes
# Symbol: AUDJPY
# Action: Sell
# Sell position 3295995295 modified successfully.
# Before: TP=92.105, SL=121.115
# After:  TP=92.10526, SL=120.87026
#
# Sell position 3304223099 modified successfully.
# Before: TP=92.105, SL=121.115
# After:  TP=92.10526, SL=120.87026
#
# ⚠️ Skipping Buy position 3304837518 - does not match action Sell.
# Symbol: AUDNZD
# Action: Buy
# ⚠️ Skipping Sell position 3285918930 - does not match action Buy.
# ✅ No changes for Buy position 3302556793. TP/SL already set.
# ✅ No changes for Buy position 3304223122. TP/SL already set.
# ⚠️ Skipping Sell position 3304223126 - does not match action Buy.
# Symbol: AUDNZD
# Action: Sell
# Sell position 3285918930 modified successfully.
# Before: TP=1.08119, SL=1.2233100000000001
# After:  TP=1.08119, SL=1.22278
#
# ⚠️ Skipping Buy position 3302556793 - does not match action Sell.
# ⚠️ Skipping Buy position 3304223122 - does not match action Sell.
# Sell position 3304223126 modified successfully.
# Before: TP=1.08119, SL=1.2233100000000001
# After:  TP=1.08119, SL=1.22278
#
# Symbol: AUDUSD
# Action: Buy
# ⚠️ Skipping Sell position 3304180166 - does not match action Buy.
# ⚠️ Skipping Sell position 3304223991 - does not match action Buy.
# ✅ No changes for Buy position 3304888719. TP/SL already set.
# Symbol: AUDUSD
# Action: Sell
# Sell position 3304180166 modified successfully.
# Before: TP=0.63238, SL=0.83147
# After:  TP=0.63238, SL=0.83113
#
# Sell position 3304223991 modified successfully.
# Before: TP=0.63238, SL=0.83147
# After:  TP=0.63238, SL=0.83113
#
# ⚠️ Skipping Buy position 3304888719 - does not match action Sell.
# Symbol: AUS200
# Action: Buy
# No open positions found for AUS200.
# Symbol: AVAXUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303762188. Error: Request returned None.
# Symbol: AVGO.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304947624. Error: Market closed
# Symbol: AXP.NYSE
# Action: Buy
# No open positions found for AXP.NYSE.
# Symbol: AXSUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3305014875. Error: Request returned None.
# Symbol: AZN.LSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3299847401. Error: No changes
# Symbol: BA.NYSE
# Action: Buy
# No open positions found for BA.NYSE.
# Symbol: BABA.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304102868. Error: Request returned None.
# Symbol: BAC.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304888731. Error: Market closed
# Symbol: BARC.LSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303762395. Error: Request returned None.
# Symbol: BATS.LSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3299872790. Error: No changes
# Symbol: BAYN.FWB
# Action: Buy
# ⚠️ Failed to modify Buy position 3305209875. Error: Request returned None.
# Symbol: BBVA.BM
# Action: Buy
# ⚠️ Failed to modify Buy position 3304865845. Error: No changes
# Symbol: BCHUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3301497543. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3303230992. Error: Request returned None.
# Symbol: BEI.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3299405469. Error: No changes
# ⚠️ Failed to modify Buy position 3303762634. Error: No changes
# Symbol: BHP.ASX
# Action: Buy
# ⚠️ Failed to modify Buy position 3305001253. Error: Market closed
# Symbol: BKNG.NAS
# Action: Buy
# No open positions found for BKNG.NAS.
# Symbol: BLK.NYSE
# Action: Buy
# No open positions found for BLK.NYSE.
# Symbol: BMW.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3305210030. Error: No changes
# Symbol: BMY.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3300219853. Error: Market closed
# ⚠️ Failed to modify Buy position 3304109863. Error: Market closed
# Symbol: BNBUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303003080. Error: Request returned None.
# Symbol: BNP.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3303762824. Error: No changes
# Symbol: BTCUSD
# Action: Buy
# No open positions found for BTCUSD.
# Symbol: BX.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304110024. Error: Market closed
# Symbol: CABK.BM
# Action: Buy
# No open positions found for CABK.BM.
# Symbol: CADCHF
# Action: Sell
# ✅ No changes for Sell position 3295246044. TP/SL already set.
# Symbol: CADJPY
# Action: Buy
# ⚠️ Skipping Sell position 3291088065 - does not match action Buy.
# ⚠️ Failed to modify Buy position 3303757604. Error: No changes
# ⚠️ Failed to modify Buy position 3304223147. Error: No changes
# ⚠️ Skipping Sell position 3304223149 - does not match action Buy.
# Symbol: CADJPY
# Action: Sell
# Sell position 3291088065 modified successfully.
# Before: TP=103.23, SL=129.527
# After:  TP=103.22984, SL=129.30684
#
# ⚠️ Skipping Buy position 3303757604 - does not match action Sell.
# ⚠️ Skipping Buy position 3304223147 - does not match action Sell.
# Sell position 3304223149 modified successfully.
# Before: TP=103.23, SL=129.527
# After:  TP=103.22984, SL=129.30684
#
# Symbol: CAT.NYSE
# Action: Buy
# No open positions found for CAT.NYSE.
# Symbol: CBA.ASX
# Action: Buy
# ⚠️ Failed to modify Buy position 3303445304. Error: Market closed
# Symbol: CHFJPY
# Action: Buy
# ⚠️ Failed to modify Buy position 3298014085. Error: No changes
# Symbol: CMCSA.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304114376. Error: Market closed
# Symbol: COP.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3280209232. Error: No changes
# ⚠️ Failed to modify Buy position 3293935589. Error: No changes
# ⚠️ Failed to modify Buy position 3293935927. Error: No changes
# Symbol: COST.NAS
# Action: Buy
# No open positions found for COST.NAS.
# Symbol: CRM.NYSE
# Action: Buy
# No open positions found for CRM.NYSE.
# Symbol: CSCO.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304114538. Error: Market closed
# Symbol: CSL.ASX
# Action: Buy
# ⚠️ Failed to modify Buy position 3298768130. Error: Market closed
# Symbol: CVS.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3298338209. Error: Market closed
# Symbol: CVX.NYSE
# Action: Buy
# No open positions found for CVX.NYSE.
# Symbol: DAII.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3300540962. Error: Market closed
# ⚠️ Failed to modify Buy position 3303520468. Error: Market closed
# ⚠️ Failed to modify Buy position 3303520689. Error: Market closed
# ⚠️ Failed to modify Buy position 3304239778. Error: Market closed
# ⚠️ Failed to modify Buy position 3304268865. Error: Market closed
# ⚠️ Failed to modify Buy position 3304269062. Error: Market closed
# Symbol: DASHUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303173212. Error: Request returned None.
# Symbol: DHR.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304176735. Error: Market closed
# Symbol: DIS.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304837280. Error: Market closed
# Symbol: DKI.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3297726752. Error: Market closed
# Symbol: DOGEUSD
# Action: Buy
# No open positions found for DOGEUSD.
# Symbol: DOTUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303763159. Error: Request returned None.
# Symbol: DTE.FWB
# Action: Buy
# No open positions found for DTE.FWB.
# Symbol: DTG.FWB
# Action: Buy
# No open positions found for DTG.FWB.
# Symbol: ENEL.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3280812140. Error: No changes
# ⚠️ Failed to modify Buy position 3293645774. Error: No changes
# ⚠️ Failed to modify Buy position 3303763669. Error: No changes
# ⚠️ Failed to modify Buy position 3304492228. Error: No changes
# Symbol: ENI.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3303763971. Error: No changes
# Symbol: ESP35
# Action: Buy
# No open positions found for ESP35.
# Symbol: ETCUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303173265. Error: Request returned None.
# Symbol: ETHUSD
# Action: Buy
# No open positions found for ETHUSD.
# Symbol: EURAUD
# Action: Buy
# ✅ No changes for Buy position 3293418441. TP/SL already set.
# ⚠️ Skipping Sell position 3304856822 - does not match action Buy.
# Symbol: EURAUD
# Action: Sell
# ⚠️ Skipping Buy position 3293418441 - does not match action Sell.
# Sell position 3304856822 modified successfully.
# Before: TP=1.71953, SL=2.13579
# After:  TP=1.71953, SL=2.12817
#
# Symbol: EURCAD
# Action: Buy
# ✅ No changes for Buy position 3293418743. TP/SL already set.
# ⚠️ Skipping Sell position 3303757395 - does not match action Buy.
# ✅ No changes for Buy position 3304223165. TP/SL already set.
# ⚠️ Skipping Sell position 3304223178 - does not match action Buy.
# Symbol: EURCAD
# Action: Sell
# ⚠️ Skipping Buy position 3293418743 - does not match action Sell.
# Sell position 3303757395 modified successfully.
# Before: TP=1.54474, SL=1.8743400000000001
# After:  TP=1.54474, SL=1.8731
#
# ⚠️ Skipping Buy position 3304223165 - does not match action Sell.
# Sell position 3304223178 modified successfully.
# Before: TP=1.54474, SL=1.8743400000000001
# After:  TP=1.54474, SL=1.8731
#
# Symbol: EURCHF
# Action: Sell
# ✅ No changes for Sell position 3299527080. TP/SL already set.
# Symbol: EURGBP
# Action: Buy
# ✅ No changes for Buy position 3293418914. TP/SL already set.
# ⚠️ Skipping Sell position 3303756772 - does not match action Buy.
# ✅ No changes for Buy position 3304223185. TP/SL already set.
# ⚠️ Skipping Sell position 3304223191 - does not match action Buy.
# Symbol: EURGBP
# Action: Sell
# ⚠️ Skipping Buy position 3293418914 - does not match action Sell.
# Sell position 3303756772 modified successfully.
# Before: TP=0.8393, SL=0.96203
# After:  TP=0.8393, SL=0.96175
#
# ⚠️ Skipping Buy position 3304223185 - does not match action Sell.
# Sell position 3304223191 modified successfully.
# Before: TP=0.8393, SL=0.96203
# After:  TP=0.8393, SL=0.96175
#
# Symbol: EURJPY
# Action: Buy
# ⚠️ Skipping Sell position 3293419124 - does not match action Buy.
# ⚠️ Failed to modify Buy position 3304179775. Error: No changes
# Symbol: EURJPY
# Action: Sell
# Sell position 3293419124 modified successfully.
# Before: TP=161.477, SL=203.274
# After:  TP=161.47672, SL=202.99072
#
# ⚠️ Skipping Buy position 3304179775 - does not match action Sell.
# Symbol: EURMXN
# Action: Buy
# ⚠️ Failed to modify Buy position 3293419757. Error: No changes
# Symbol: EURNZD
# Action: Buy
# ⚠️ Failed to modify Buy position 3295753416. Error: No changes
# ⚠️ Failed to modify Buy position 3304243214. Error: No changes
# ⚠️ Skipping Sell position 3304459498 - does not match action Buy.
# Symbol: EURNZD
# Action: Sell
# ⚠️ Skipping Buy position 3295753416 - does not match action Sell.
# ⚠️ Skipping Buy position 3304243214 - does not match action Sell.
# Sell position 3304459498 modified successfully.
# Before: TP=1.87539, SL=2.29914
# After:  TP=1.87539, SL=2.30664
#
# Symbol: EURUSD
# Action: Buy
# ✅ No changes for Buy position 3297343009. TP/SL already set.
# ⚠️ Skipping Sell position 3303757469 - does not match action Buy.
# Symbol: EURUSD
# Action: Sell
# ⚠️ Skipping Buy position 3297343009 - does not match action Sell.
# Sell position 3303757469 modified successfully.
# Before: TP=1.10565, SL=1.4047
# After:  TP=1.10565, SL=1.40427
#
# Symbol: EURZAR
# Action: Buy
# ✅ No changes for Buy position 3297344129. TP/SL already set.
# Symbol: EUSTX50
# Action: Buy
# No open positions found for EUSTX50.
# Symbol: FETUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303216662. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3303226695. Error: Request returned None.
# Symbol: FILUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3302580433. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3303239649. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3303770477. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3304121459. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3304219700. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3304239787. Error: Request returned None.
# Symbol: FRA40
# Action: Buy
# No open positions found for FRA40.
# Symbol: GBPAUD
# Action: Buy
# ✅ No changes for Buy position 3297344455. TP/SL already set.
# ⚠️ Skipping Sell position 3299102816 - does not match action Buy.
# Symbol: GBPAUD
# Action: Sell
# ⚠️ Skipping Buy position 3297344455 - does not match action Sell.
# Sell position 3299102816 modified successfully.
# Before: TP=2.03971, SL=2.5872
# After:  TP=2.03971, SL=2.58737
#
# Symbol: GBPCAD
# Action: Buy
# ⚠️ Skipping Sell position 3297345453 - does not match action Buy.
# ✅ No changes for Buy position 3304835107. TP/SL already set.
# Symbol: GBPCAD
# Action: Sell
# Sell position 3297345453 modified successfully.
# Before: TP=1.8334899999999998, SL=2.2792
# After:  TP=1.83349, SL=2.27962
#
# ⚠️ Skipping Buy position 3304835107 - does not match action Sell.
# Symbol: GBPCHF
# Action: Sell
# ⚠️ Failed to modify Sell position 3298014406. Error: No changes
# Symbol: GBPJPY
# Action: Buy
# ⚠️ Skipping Sell position 3299912193 - does not match action Buy.
# ⚠️ Failed to modify Buy position 3304869137. Error: No changes
# Symbol: GBPJPY
# Action: Sell
# Sell position 3299912193 modified successfully.
# Before: TP=189.588, SL=262.285
# After:  TP=189.58789, SL=262.00789
#
# ⚠️ Skipping Buy position 3304869137 - does not match action Sell.
# Symbol: GBPMXN
# Action: Buy
# ⚠️ Failed to modify Buy position 3285596224. Error: No changes
# Symbol: GBPNZD
# Action: Buy
# ✅ No changes for Buy position 3297346528. TP/SL already set.
# ⚠️ Skipping Sell position 3298767397 - does not match action Buy.
# Symbol: GBPNZD
# Action: Sell
# ⚠️ Skipping Buy position 3297346528 - does not match action Sell.
# Sell position 3298767397 modified successfully.
# Before: TP=2.22017, SL=2.79052
# After:  TP=2.22017, SL=2.79077
#
# Symbol: GBPUSD
# Action: Buy
# ✅ No changes for Buy position 3295254715. TP/SL already set.
# ⚠️ Skipping Sell position 3303757685 - does not match action Buy.
# Symbol: GBPUSD
# Action: Sell
# ⚠️ Skipping Buy position 3295254715 - does not match action Sell.
# Sell position 3303757685 modified successfully.
# Before: TP=1.3115700000000001, SL=1.7128999999999999
# After:  TP=1.31157, SL=1.71288
#
# Symbol: GBPZAR
# Action: Buy
# ✅ No changes for Buy position 3297347553. TP/SL already set.
# Symbol: GE.NYSE
# Action: Buy
# No open positions found for GE.NYSE.
# Symbol: GER40
# Action: Buy
# No open positions found for GER40.
# Symbol: GOOGL.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3293910256. Error: Market closed
# Symbol: GS.NYSE
# Action: Buy
# No open positions found for GS.NYSE.
# Symbol: HD.NYSE
# Action: Buy
# No open positions found for HD.NYSE.
# Symbol: HEIA.EAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3300760802. Error: No changes
# Symbol: HIT.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303449468. Error: Market closed
# Symbol: HMC.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3295995003. Error: Request returned None.
# Symbol: HON.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304835900. Error: Market closed
# Symbol: HSBA.LSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303764157. Error: Request returned None.
# Symbol: IBM.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304841557. Error: Market closed
# Symbol: INTC.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304188828. Error: Request returned None.
# Symbol: INTU.NAS
# Action: Buy
# No open positions found for INTU.NAS.
# Symbol: IOTAUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303174051. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3304127077. Error: Request returned None.
# Symbol: ISP.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3302854899. Error: No changes
# ⚠️ Failed to modify Buy position 3304492379. Error: No changes
# Symbol: ISRG.NAS
# Action: Buy
# No open positions found for ISRG.NAS.
# Symbol: ITX.BM
# Action: Buy
# ⚠️ Failed to modify Buy position 3294683715. Error: No changes
# Symbol: JAR.SGX
# Action: Buy
# ⚠️ Failed to modify Buy position 3279704752. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3293425477. Error: Request returned None.
# Symbol: JD.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304860748. Error: Request returned None.
# Symbol: JNJ.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3278886088. Error: Market closed
# ⚠️ Failed to modify Buy position 3293954893. Error: Market closed
# Symbol: JPM.NYSE
# Action: Buy
# No open positions found for JPM.NYSE.
# Symbol: JPN225
# Action: Buy
# No open positions found for JPN225.
# Symbol: KEE.TSE
# Action: Buy
# No open positions found for KEE.TSE.
# Symbol: KO.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3296715805. Error: Market closed
# Symbol: LI.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304127280. Error: Request returned None.
# Symbol: LIN.NYSE
# Action: Buy
# No open positions found for LIN.NYSE.
# Symbol: LINKUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303764332. Error: Request returned None.
# Symbol: LLY.NYSE
# Action: Buy
# No open positions found for LLY.NYSE.
# Symbol: LMT.NYSE
# Action: Buy
# No open positions found for LMT.NYSE.
# Symbol: LRCUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3299514904. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3304127358. Error: Request returned None.
# Symbol: LSEG.LSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3292134139. Error: No changes
# Symbol: LTCUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303003157. Error: Request returned None.
# Symbol: MA.NYSE
# Action: Buy
# No open positions found for MA.NYSE.
# Symbol: MANAUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303174266. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3303239684. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3304128204. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3304176884. Error: Request returned None.
# Symbol: MBG.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3294703468. Error: No changes
# ⚠️ Failed to modify Buy position 3299026423. Error: No changes
# Symbol: MC.EPA
# Action: Buy
# No open positions found for MC.EPA.
# Symbol: MCD.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3299420804. Error: No changes
# Symbol: MDLZ.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3296717234. Error: Market closed
# Symbol: META.NAS
# Action: Buy
# No open positions found for META.NAS.
# Symbol: MMM.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304835768. Error: Market closed
# Symbol: MRK.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304188852. Error: Market closed
# Symbol: MRK.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304493136. Error: No changes
# Symbol: MS.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304879336. Error: No changes
# Symbol: MSFT.NAS
# Action: Buy
# No open positions found for MSFT.NAS.
# Symbol: MUR.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304239834. Error: Market closed
# Symbol: NAB.ASX
# Action: Buy
# ⚠️ Failed to modify Buy position 3297726296. Error: Market closed
# Symbol: NAS100
# Action: Buy
# No open positions found for NAS100.
# Symbol: NEARUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303173156. Error: Request returned None.
# Symbol: NEE.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304947636. Error: Market closed
# Symbol: NESTE.OMXH
# Action: Buy
# ⚠️ Failed to modify Buy position 3304492589. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3304492996. Error: Request returned None.
# Symbol: NFLX.NAS
# Action: Buy
# No open positions found for NFLX.NAS.
# Symbol: NID.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304239872. Error: Request returned None.
# Symbol: NKE.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304131530. Error: Request returned None.
# Symbol: NOKIA.OMXH
# Action: Buy
# ⚠️ Failed to modify Buy position 3276134396. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3292135089. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3293980710. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3299027603. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3304492678. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3304547359. Error: Request returned None.
# Symbol: NOW.NYSE
# Action: Buy
# No open positions found for NOW.NYSE.
# Symbol: NVDA.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304835289. Error: No changes
# Symbol: NZDCAD
# Action: Buy
# ⚠️ Skipping Sell position 3296002462 - does not match action Buy.
# ⚠️ Skipping Sell position 3304223209 - does not match action Buy.
# ⚠️ Skipping Sell position 3304229647 - does not match action Buy.
# ✅ No changes for Buy position 3304830506. TP/SL already set.
# ✅ No changes for Buy position 3304830658. TP/SL already set.
# Symbol: NZDCAD
# Action: Sell
# Sell position 3296002462 modified successfully.
# Before: TP=0.81533, SL=0.99149
# After:  TP=0.81533, SL=0.99086
#
# Sell position 3304223209 modified successfully.
# Before: TP=0.81533, SL=0.99149
# After:  TP=0.81533, SL=0.99086
#
# Sell position 3304229647 modified successfully.
# Before: TP=0.81533, SL=0.99149
# After:  TP=0.81533, SL=0.99086
#
# ⚠️ Skipping Buy position 3304830506 - does not match action Sell.
# ⚠️ Skipping Buy position 3304830658 - does not match action Sell.
# Symbol: NZDCHF
# Action: Sell
# ✅ No changes for Sell position 3295245784. TP/SL already set.
# Symbol: NZDJPY
# Action: Buy
# ⚠️ Skipping Sell position 3295754442 - does not match action Buy.
# ⚠️ Skipping Sell position 3304223214 - does not match action Buy.
# ⚠️ Failed to modify Buy position 3304856177. Error: No changes
# Symbol: NZDJPY
# Action: Sell
# Sell position 3295754442 modified successfully.
# Before: TP=85.194, SL=112.011
# After:  TP=85.19376, SL=111.78576
#
# Sell position 3304223214 modified successfully.
# Before: TP=85.194, SL=112.011
# After:  TP=85.19376, SL=111.78576
#
# ⚠️ Skipping Buy position 3304856177 - does not match action Sell.
# Symbol: NZDUSD
# Action: Buy
# ✅ No changes for Buy position 3293432046. TP/SL already set.
# ⚠️ Skipping Sell position 3303841489 - does not match action Buy.
# ✅ No changes for Buy position 3304223217. TP/SL already set.
# ⚠️ Skipping Sell position 3304223221 - does not match action Buy.
# Symbol: NZDUSD
# Action: Sell
# ⚠️ Skipping Buy position 3293432046 - does not match action Sell.
# Sell position 3303841489 modified successfully.
# Before: TP=0.58316, SL=0.75945
# After:  TP=0.58316, SL=0.75988
#
# ⚠️ Skipping Buy position 3304223217 - does not match action Sell.
# Sell position 3304223221 modified successfully.
# Before: TP=0.58316, SL=0.75945
# After:  TP=0.58316, SL=0.75988
#
# Symbol: OL.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303449890. Error: Market closed
# Symbol: OR.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3298299601. Error: No changes
# Symbol: ORCL.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304836662. Error: Market closed
# Symbol: PEP.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3296714573. Error: Market closed
# ⚠️ Failed to modify Buy position 3299414757. Error: Market closed
# Symbol: PFE.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3295995788. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3299416106. Error: Request returned None.
# Symbol: PG.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3292398776. Error: Market closed
# ⚠️ Failed to modify Buy position 3293983199. Error: Market closed
# Symbol: PM.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304843607. Error: Market closed
# Symbol: PYPL.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304132258. Error: Request returned None.
# Symbol: QCOM.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304132378. Error: Market closed
# Symbol: RACE.MIL
# Action: Buy
# No open positions found for RACE.MIL.
# Symbol: RMS.EPA
# Action: Buy
# No open positions found for RMS.EPA.
# Symbol: RTX.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3298446626. Error: Market closed
# Symbol: SAN.BM
# Action: Buy
# ⚠️ Failed to modify Buy position 3303764473. Error: Request returned None.
# ⚠️ Failed to modify Buy position 3304492796. Error: Request returned None.
# Symbol: SAP.NYSE
# Action: Buy
# No open positions found for SAP.NYSE.
# Symbol: SBUX.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3280209688. Error: Market closed
# ⚠️ Failed to modify Buy position 3293985232. Error: Market closed
# Symbol: SHEL.LSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303764511. Error: Request returned None.
# Symbol: SHOP.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304835412. Error: Request returned None.
# Symbol: SIE.XE
# Action: Buy
# No open positions found for SIE.XE.
# Symbol: SOLUSD
# Action: Buy
# No open positions found for SOLUSD.
# Symbol: SONY.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3295995076. Error: Market closed
# ⚠️ Failed to modify Buy position 3299416560. Error: Market closed
# Symbol: SPX500
# Action: Buy
# No open positions found for SPX500.
# Symbol: STLA.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3304836943. Error: Request returned None.
# Symbol: SUIUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303764586. Error: Request returned None.
# Symbol: SVN.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303526044. Error: Market closed
# ⚠️ Failed to modify Buy position 3304239917. Error: Market closed
# Symbol: T.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3301254934. Error: Market closed
# ⚠️ Failed to modify Buy position 3304132650. Error: Market closed
# Symbol: TCEHY.OTC
# Action: Buy
# ⚠️ Failed to modify Buy position 3302788591. Error: Market closed
# ⚠️ Failed to modify Buy position 3304177250. Error: Market closed
# Symbol: TKY.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3305001170. Error: Market closed
# Symbol: TM.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304242075. Error: Market closed
# ⚠️ Failed to modify Buy position 3304380529. Error: Market closed
# Symbol: TMH.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303450840. Error: Request returned None.
# Symbol: TMO.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3295995689. Error: Market closed
# Symbol: TMUS.NAS
# Action: Buy
# No open positions found for TMUS.NAS.
# Symbol: TRXUSD
# Action: Buy
# No open positions found for TRXUSD.
# Symbol: TSLA.NAS
# Action: Buy
# No open positions found for TSLA.NAS.
# Symbol: TTE.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3278875237. Error: No changes
# ⚠️ Failed to modify Buy position 3292135946. Error: No changes
# ⚠️ Failed to modify Buy position 3293652739. Error: No changes
# ⚠️ Failed to modify Buy position 3293653283. Error: No changes
# ⚠️ Failed to modify Buy position 3293653462. Error: No changes
# Symbol: TXN.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304132717. Error: Market closed
# Symbol: UCG.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3303764669. Error: Request returned None.
# Symbol: UK100
# Action: Buy
# No open positions found for UK100.
# Symbol: UNH.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3295249135. Error: Market closed
# Symbol: UNIUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303173729. Error: Request returned None.
# Symbol: UNP.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304132846. Error: Market closed
# Symbol: UPS.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304133027. Error: Market closed
# Symbol: US30
# Action: Buy
# No open positions found for US30.
# Symbol: USDCAD
# Action: Buy
# ⚠️ Skipping Sell position 3293436465 - does not match action Buy.
# ⚠️ Failed to modify Buy position 3303844515. Error: No changes
# ⚠️ Failed to modify Buy position 3304223227. Error: No changes
# ⚠️ Skipping Sell position 3304223234 - does not match action Buy.
# Symbol: USDCAD
# Action: Sell
# Sell position 3293436465 modified successfully.
# Before: TP=1.3866399999999999, SL=1.64089
# After:  TP=1.38664, SL=1.64004
#
# ⚠️ Skipping Buy position 3303844515 - does not match action Sell.
# ⚠️ Skipping Buy position 3304223227 - does not match action Sell.
# Sell position 3304223234 modified successfully.
# Before: TP=1.3866399999999999, SL=1.64089
# After:  TP=1.38664, SL=1.64004
#
# Symbol: USDCHF
# Action: Sell
# ✅ No changes for Sell position 3301255979. TP/SL already set.
# Symbol: USDJPY
# Action: Buy
# ⚠️ Skipping Sell position 3291873635 - does not match action Buy.
# ⚠️ Failed to modify Buy position 3303757544. Error: No changes
# ⚠️ Failed to modify Buy position 3304223239. Error: No changes
# ⚠️ Skipping Sell position 3304223246 - does not match action Buy.
# Symbol: USDJPY
# Action: Sell
# Sell position 3291873635 modified successfully.
# Before: TP=144.65, SL=173.311
# After:  TP=144.64989, SL=172.96589
#
# ⚠️ Skipping Buy position 3303757544 - does not match action Sell.
# ⚠️ Skipping Buy position 3304223239 - does not match action Sell.
# Sell position 3304223246 modified successfully.
# Before: TP=144.65, SL=173.311
# After:  TP=144.64989, SL=172.96589
#
# Symbol: USDMXN
# Action: Buy
# ⚠️ Failed to modify Buy position 3293437457. Error: No changes
# Symbol: USDZAR
# Action: Buy
# ✅ No changes for Buy position 3293437473. TP/SL already set.
# Symbol: V.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304836805. Error: Market closed
# Symbol: VNA.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3301984800. Error: Request returned None.
# Symbol: VOW3.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304856583. Error: Request returned None.
# Symbol: VZ.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3301256630. Error: Market closed
# ⚠️ Failed to modify Buy position 3304133254. Error: Market closed
# Symbol: WES.ASX
# Action: Buy
# ⚠️ Failed to modify Buy position 3305058653. Error: Market closed
# Symbol: WFC.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304837439. Error: Market closed
# Symbol: WMT.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3298325768. Error: Market closed
# ⚠️ Failed to modify Buy position 3299419095. Error: Market closed
# Symbol: XAGUSD
# Action: Buy
# No open positions found for XAGUSD.
# Symbol: XAUUSD
# Action: Buy
# No open positions found for XAUUSD.
# Symbol: XBRUSD
# Action: Buy
# ⚠️ Skipping Sell position 3304242913 - does not match action Buy.
# ⚠️ Failed to modify Buy position 3304837349. Error: Request returned None.
# Symbol: XBRUSD
# Action: Sell
# ⚠️ Failed to modify Sell position 3304242913. Error: No changes
# ⚠️ Skipping Buy position 3304837349 - does not match action Sell.
# Symbol: XNGUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304493382. Error: Request returned None.
# ⚠️ Skipping Sell position 3304493461 - does not match action Buy.
# Symbol: XNGUSD
# Action: Sell
# ⚠️ Skipping Buy position 3304493382 - does not match action Sell.
# ⚠️ Failed to modify Sell position 3304493461. Error: No changes
# Symbol: XOM.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3278885254. Error: Market closed
# ⚠️ Failed to modify Buy position 3293990121. Error: Market closed
# Symbol: XRPUSD
# Action: Buy
# No open positions found for XRPUSD.
# Symbol: XTIUSD
# Action: Buy
# ⚠️ Skipping Sell position 3304223537 - does not match action Buy.
# ⚠️ Failed to modify Buy position 3304837471. Error: Request returned None.
# Symbol: XTIUSD
# Action: Sell
# ⚠️ Failed to modify Sell position 3304223537. Error: No changes
# ⚠️ Skipping Buy position 3304837471 - does not match action Sell.
# Symbol: ZECUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303336699. Error: Request returned None.
#
# === TP/SL Modification Summary ===
# Total Successful Modifications: 35
# Total Failed Modifications: 200

# %%
import time
import MetaTrader5 as mt5
import pandas as pd

# === Initialize MT5 Connection === #
if not mt5.initialize():
    print("MT5 initialization failed.")
    quit()

# Load DataFrame from Google Sheets
df = fetcher.get_sheet_as_dataframe("Forex")
df.columns = df.iloc[5]
df = df.iloc[6:-3].reset_index(drop=True)

# Initialize counters for success and failure
success_count = 0
failure_count = 0

# Fetch unique symbols from running trades in MT5
positions = mt5.positions_get()
if positions is None or len(positions) == 0:
    print("No running trades found. Exiting.")
    mt5.shutdown()
    quit()

# Get unique symbols from MT5 positions
symbol_list = sorted(list(set(pos.symbol for pos in positions)))

# Convert positions to DataFrame for easy filtering
df_positions = pd.DataFrame([pos._asdict() for pos in positions])

# Iterate through each unique symbol from MT5 positions
for symbol in symbol_list:
    for action in ["Buy", "Sell"]:
        # Filter positions for the current symbol and action
        action_type = 0 if action == "Buy" else 1
        filtered_positions = df_positions[(df_positions['symbol'] == symbol) & (df_positions['type'] == action_type)]
        
        if filtered_positions.empty:
            print(f"Symbol: {symbol}\nAction: {action}\n⚠️ No {action} positions running. Skipping.")
            continue

        # Filter rows for the current symbol and action from Google Sheets
        df_filtered = df[(df["Symbol"] == symbol) & (df["Action"] == action)]
        
        if df_filtered.empty:
            print(f"Symbol: {symbol}\nAction: {action}\n⚠️ No matching TP/SL settings in Google Sheets.")
            continue
        
        tp_value = round(df_filtered['TP'].values[0], 5)
        sl_value = round(df_filtered['SL'].values[0], 5)

        # Iterate over filtered positions for modification
        for _, pos in filtered_positions.iterrows():
            order_id = pos['ticket']
            current_tp = pos['tp']
            current_sl = pos['sl']

            # Only modify if the new TP/SL values differ from current
            if current_tp == tp_value and current_sl == sl_value:
                print(f"Symbol: {symbol}\nAction: {action}\n✅ No changes for {action} position {order_id}. TP/SL already set.")
                continue

            # Modify TP/SL using position ID
            request = {
                "action": mt5.TRADE_ACTION_SLTP,
                "position": order_id,
                "sl": sl_value,
                "tp": tp_value
            }

            # Send modification request
            result = mt5.order_send(request)
            #time.sleep(0.5)  # Delay of 0.5 second between each request

            # Check if result is None (Error)
            if result is None:
                print(f"Symbol: {symbol}\nAction: {action}\n⚠️ Failed to modify {action} position {order_id}. Error: Request returned None.")
                failure_count += 1
                continue

            # Check if the modification was successful
            if result.retcode == mt5.TRADE_RETCODE_DONE:
                print(f"Symbol: {symbol}\nAction: {action}\n✅ {action} position {order_id} modified successfully.")
                print(f"Before: TP={current_tp}, SL={current_sl}")
                print(f"After:  TP={tp_value}, SL={sl_value}\n")
                success_count += 1
            else:
                print(f"Symbol: {symbol}\nAction: {action}\n⚠️ Failed to modify {action} position {order_id}. Error: {result.comment}")
                failure_count += 1

# === Shutdown MT5 Connection === #
mt5.shutdown()

# === Summary Report ===
print("\n=== TP/SL Modification Summary ===")
print(f"Total Successful Modifications: {success_count}")
print(f"Total Failed Modifications: {failure_count}")
# Out:
# ✅ Successfully retrieved data from 'Forex' as a DataFrame.
# Symbol: AAPL.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3297549570. Error: AutoTrading disabled by client
# Symbol: AAPL.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: AAVEUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3302602638. Error: Request returned None.
# Symbol: AAVEUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ABBV.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3298446412. Error: AutoTrading disabled by client
# Symbol: ABBV.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ABNB.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304860529. Error: Request returned None.
# Symbol: ABNB.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ABT.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3302221724. Error: AutoTrading disabled by client
# Symbol: ABT.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ACN.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304837038. Error: AutoTrading disabled by client
# Symbol: ACN.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ADAUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304100487. Error: Request returned None.
# Symbol: ADAUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ADS.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3305209594. Error: AutoTrading disabled by client
# Symbol: ADS.XE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: AI.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3297913700. Error: AutoTrading disabled by client
# Symbol: AI.EPA
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: AIR.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3305210944. Error: AutoTrading disabled by client
# Symbol: AIR.EPA
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ALGOUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304100698. Error: Request returned None.
# Symbol: ALGOUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: AMD.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304858347. Error: Request returned None.
# Symbol: AMD.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: APTUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303173396. Error: Request returned None.
# Symbol: APTUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ATOMUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303174194. Error: Request returned None.
# Symbol: ATOMUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304176535. Error: Request returned None.
# Symbol: ATOMUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: AUDCAD
# Action: Buy
# ✅ No changes for Buy position 3304834368. TP/SL already set.
# Symbol: AUDCAD
# Action: Sell
# ✅ No changes for Sell position 3301252618. TP/SL already set.
# Symbol: AUDCAD
# Action: Sell
# ✅ No changes for Sell position 3304223072. TP/SL already set.
# Symbol: AUDCAD
# Action: Sell
# ✅ No changes for Sell position 3304229587. TP/SL already set.
# Symbol: AUDCHF
# Action: Buy
# ⚠️ No Buy positions running. Skipping.
# Symbol: AUDCHF
# Action: Sell
# ✅ No changes for Sell position 3296721794. TP/SL already set.
# Symbol: AUDJPY
# Action: Buy
# ⚠️ Failed to modify Buy position 3304837518. Error: AutoTrading disabled by client
# Symbol: AUDJPY
# Action: Sell
# ⚠️ Failed to modify Sell position 3295995295. Error: AutoTrading disabled by client
# Symbol: AUDJPY
# Action: Sell
# ⚠️ Failed to modify Sell position 3304223099. Error: AutoTrading disabled by client
# Symbol: AUDNZD
# Action: Buy
# ✅ No changes for Buy position 3302556793. TP/SL already set.
# Symbol: AUDNZD
# Action: Buy
# ✅ No changes for Buy position 3304223122. TP/SL already set.
# Symbol: AUDNZD
# Action: Sell
# ✅ No changes for Sell position 3285918930. TP/SL already set.
# Symbol: AUDNZD
# Action: Sell
# ✅ No changes for Sell position 3304223126. TP/SL already set.
# Symbol: AUDUSD
# Action: Buy
# ✅ No changes for Buy position 3304888719. TP/SL already set.
# Symbol: AUDUSD
# Action: Sell
# ✅ No changes for Sell position 3304180166. TP/SL already set.
# Symbol: AUDUSD
# Action: Sell
# ✅ No changes for Sell position 3304223991. TP/SL already set.
# Symbol: AVAXUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303762188. Error: Request returned None.
# Symbol: AVAXUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: AVGO.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304947624. Error: AutoTrading disabled by client
# Symbol: AVGO.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: AXSUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3305014875. Error: Request returned None.
# Symbol: AXSUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: AZN.LSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3299847401. Error: AutoTrading disabled by client
# Symbol: AZN.LSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BABA.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304102868. Error: Request returned None.
# Symbol: BABA.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BAC.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304888731. Error: AutoTrading disabled by client
# Symbol: BAC.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BARC.LSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303762395. Error: Request returned None.
# Symbol: BARC.LSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BATS.LSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3299872790. Error: AutoTrading disabled by client
# Symbol: BATS.LSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BAYN.FWB
# Action: Buy
# ⚠️ Failed to modify Buy position 3305209875. Error: Request returned None.
# Symbol: BAYN.FWB
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BBVA.BM
# Action: Buy
# ⚠️ Failed to modify Buy position 3304865845. Error: AutoTrading disabled by client
# Symbol: BBVA.BM
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BCHUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3301497543. Error: Request returned None.
# Symbol: BCHUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303230992. Error: Request returned None.
# Symbol: BCHUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BEI.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3299405469. Error: AutoTrading disabled by client
# Symbol: BEI.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303762634. Error: AutoTrading disabled by client
# Symbol: BEI.XE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BHP.ASX
# Action: Buy
# ⚠️ Failed to modify Buy position 3305001253. Error: AutoTrading disabled by client
# Symbol: BHP.ASX
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BMW.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3305210030. Error: AutoTrading disabled by client
# Symbol: BMW.XE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BMY.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3300219853. Error: AutoTrading disabled by client
# Symbol: BMY.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304109863. Error: AutoTrading disabled by client
# Symbol: BMY.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BNBUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303003080. Error: Request returned None.
# Symbol: BNBUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BNP.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3305269306. Error: AutoTrading disabled by client
# Symbol: BNP.EPA
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: BX.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304110024. Error: AutoTrading disabled by client
# Symbol: BX.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: CADCHF
# Action: Buy
# ⚠️ No Buy positions running. Skipping.
# Symbol: CADCHF
# Action: Sell
# ✅ No changes for Sell position 3295246044. TP/SL already set.
# Symbol: CADJPY
# Action: Buy
# ⚠️ Failed to modify Buy position 3303757604. Error: AutoTrading disabled by client
# Symbol: CADJPY
# Action: Buy
# ⚠️ Failed to modify Buy position 3304223147. Error: AutoTrading disabled by client
# Symbol: CADJPY
# Action: Sell
# ⚠️ Failed to modify Sell position 3291088065. Error: AutoTrading disabled by client
# Symbol: CADJPY
# Action: Sell
# ⚠️ Failed to modify Sell position 3304223149. Error: AutoTrading disabled by client
# Symbol: CBA.ASX
# Action: Buy
# ⚠️ Failed to modify Buy position 3303445304. Error: AutoTrading disabled by client
# Symbol: CBA.ASX
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: CHFJPY
# Action: Buy
# ⚠️ Failed to modify Buy position 3298014085. Error: AutoTrading disabled by client
# Symbol: CHFJPY
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: CMCSA.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304114376. Error: AutoTrading disabled by client
# Symbol: CMCSA.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: COP.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3280209232. Error: AutoTrading disabled by client
# Symbol: COP.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3293935589. Error: AutoTrading disabled by client
# Symbol: COP.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3293935927. Error: AutoTrading disabled by client
# Symbol: COP.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: CSCO.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304114538. Error: AutoTrading disabled by client
# Symbol: CSCO.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: CSL.ASX
# Action: Buy
# ⚠️ Failed to modify Buy position 3298768130. Error: AutoTrading disabled by client
# Symbol: CSL.ASX
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: CVS.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3298338209. Error: AutoTrading disabled by client
# Symbol: CVS.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: DAII.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3300540962. Error: AutoTrading disabled by client
# Symbol: DAII.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303520468. Error: AutoTrading disabled by client
# Symbol: DAII.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303520689. Error: AutoTrading disabled by client
# Symbol: DAII.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304239778. Error: AutoTrading disabled by client
# Symbol: DAII.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304268865. Error: AutoTrading disabled by client
# Symbol: DAII.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304269062. Error: AutoTrading disabled by client
# Symbol: DAII.TSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: DASHUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303173212. Error: Request returned None.
# Symbol: DASHUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: DHR.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304176735. Error: AutoTrading disabled by client
# Symbol: DHR.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: DIS.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304837280. Error: AutoTrading disabled by client
# Symbol: DIS.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: DKI.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3297726752. Error: AutoTrading disabled by client
# Symbol: DKI.TSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: DOTUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303763159. Error: Request returned None.
# Symbol: DOTUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ENEL.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3280812140. Error: AutoTrading disabled by client
# Symbol: ENEL.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3293645774. Error: AutoTrading disabled by client
# Symbol: ENEL.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3303763669. Error: AutoTrading disabled by client
# Symbol: ENEL.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3304492228. Error: AutoTrading disabled by client
# Symbol: ENEL.MIL
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ENI.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3303763971. Error: AutoTrading disabled by client
# Symbol: ENI.MIL
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ETCUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303173265. Error: Request returned None.
# Symbol: ETCUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: EURAUD
# Action: Buy
# ✅ No changes for Buy position 3293418441. TP/SL already set.
# Symbol: EURAUD
# Action: Sell
# ✅ No changes for Sell position 3304856822. TP/SL already set.
# Symbol: EURCAD
# Action: Buy
# ✅ No changes for Buy position 3293418743. TP/SL already set.
# Symbol: EURCAD
# Action: Buy
# ✅ No changes for Buy position 3304223165. TP/SL already set.
# Symbol: EURCAD
# Action: Sell
# ✅ No changes for Sell position 3303757395. TP/SL already set.
# Symbol: EURCAD
# Action: Sell
# ✅ No changes for Sell position 3304223178. TP/SL already set.
# Symbol: EURCHF
# Action: Buy
# ⚠️ No Buy positions running. Skipping.
# Symbol: EURCHF
# Action: Sell
# ✅ No changes for Sell position 3299527080. TP/SL already set.
# Symbol: EURGBP
# Action: Buy
# ✅ No changes for Buy position 3293418914. TP/SL already set.
# Symbol: EURGBP
# Action: Buy
# ✅ No changes for Buy position 3304223185. TP/SL already set.
# Symbol: EURGBP
# Action: Sell
# ✅ No changes for Sell position 3303756772. TP/SL already set.
# Symbol: EURGBP
# Action: Sell
# ✅ No changes for Sell position 3304223191. TP/SL already set.
# Symbol: EURJPY
# Action: Buy
# ⚠️ Failed to modify Buy position 3304179775. Error: AutoTrading disabled by client
# Symbol: EURJPY
# Action: Sell
# ⚠️ Failed to modify Sell position 3293419124. Error: AutoTrading disabled by client
# Symbol: EURMXN
# Action: Buy
# ⚠️ Failed to modify Buy position 3293419757. Error: AutoTrading disabled by client
# Symbol: EURMXN
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: EURNZD
# Action: Buy
# ⚠️ Failed to modify Buy position 3295753416. Error: AutoTrading disabled by client
# Symbol: EURNZD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304243214. Error: AutoTrading disabled by client
# Symbol: EURNZD
# Action: Sell
# ✅ No changes for Sell position 3304459498. TP/SL already set.
# Symbol: EURUSD
# Action: Buy
# ✅ No changes for Buy position 3297343009. TP/SL already set.
# Symbol: EURUSD
# Action: Sell
# ✅ No changes for Sell position 3303757469. TP/SL already set.
# Symbol: EURZAR
# Action: Buy
# ✅ No changes for Buy position 3297344129. TP/SL already set.
# Symbol: EURZAR
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: FETUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303216662. Error: Request returned None.
# Symbol: FETUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303226695. Error: Request returned None.
# Symbol: FETUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: FILUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3302580433. Error: Request returned None.
# Symbol: FILUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303239649. Error: Request returned None.
# Symbol: FILUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303770477. Error: Request returned None.
# Symbol: FILUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304121459. Error: Request returned None.
# Symbol: FILUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304219700. Error: Request returned None.
# Symbol: FILUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304239787. Error: Request returned None.
# Symbol: FILUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: GBPAUD
# Action: Buy
# ✅ No changes for Buy position 3297344455. TP/SL already set.
# Symbol: GBPAUD
# Action: Sell
# ✅ No changes for Sell position 3299102816. TP/SL already set.
# Symbol: GBPCAD
# Action: Buy
# ✅ No changes for Buy position 3304835107. TP/SL already set.
# Symbol: GBPCAD
# Action: Sell
# ⚠️ Failed to modify Sell position 3297345453. Error: AutoTrading disabled by client
# Symbol: GBPCHF
# Action: Buy
# ⚠️ No Buy positions running. Skipping.
# Symbol: GBPCHF
# Action: Sell
# ⚠️ Failed to modify Sell position 3298014406. Error: AutoTrading disabled by client
# Symbol: GBPJPY
# Action: Buy
# ⚠️ Failed to modify Buy position 3304869137. Error: AutoTrading disabled by client
# Symbol: GBPJPY
# Action: Sell
# ⚠️ Failed to modify Sell position 3299912193. Error: AutoTrading disabled by client
# Symbol: GBPMXN
# Action: Buy
# ⚠️ Failed to modify Buy position 3285596224. Error: AutoTrading disabled by client
# Symbol: GBPMXN
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: GBPNZD
# Action: Buy
# ✅ No changes for Buy position 3297346528. TP/SL already set.
# Symbol: GBPNZD
# Action: Sell
# ✅ No changes for Sell position 3298767397. TP/SL already set.
# Symbol: GBPUSD
# Action: Buy
# ✅ No changes for Buy position 3295254715. TP/SL already set.
# Symbol: GBPUSD
# Action: Sell
# ⚠️ Failed to modify Sell position 3303757685. Error: AutoTrading disabled by client
# Symbol: GBPZAR
# Action: Buy
# ✅ No changes for Buy position 3297347553. TP/SL already set.
# Symbol: GBPZAR
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: GOOGL.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3293910256. Error: AutoTrading disabled by client
# Symbol: GOOGL.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: HEIA.EAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3300760802. Error: AutoTrading disabled by client
# Symbol: HEIA.EAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: HIT.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303449468. Error: AutoTrading disabled by client
# Symbol: HIT.TSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: HMC.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3295995003. Error: Request returned None.
# Symbol: HMC.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: HON.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304835900. Error: AutoTrading disabled by client
# Symbol: HON.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: HSBA.LSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303764157. Error: Request returned None.
# Symbol: HSBA.LSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: IBM.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304841557. Error: AutoTrading disabled by client
# Symbol: IBM.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: INTC.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304188828. Error: Request returned None.
# Symbol: INTC.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: IOTAUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303174051. Error: Request returned None.
# Symbol: IOTAUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304127077. Error: Request returned None.
# Symbol: IOTAUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ISP.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3302854899. Error: AutoTrading disabled by client
# Symbol: ISP.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3304492379. Error: AutoTrading disabled by client
# Symbol: ISP.MIL
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ITX.BM
# Action: Buy
# ⚠️ Failed to modify Buy position 3294683715. Error: AutoTrading disabled by client
# Symbol: ITX.BM
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: JAR.SGX
# Action: Buy
# ⚠️ Failed to modify Buy position 3279704752. Error: Request returned None.
# Symbol: JAR.SGX
# Action: Buy
# ⚠️ Failed to modify Buy position 3293425477. Error: Request returned None.
# Symbol: JAR.SGX
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: JD.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304860748. Error: Request returned None.
# Symbol: JD.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: JNJ.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3278886088. Error: AutoTrading disabled by client
# Symbol: JNJ.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3293954893. Error: AutoTrading disabled by client
# Symbol: JNJ.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: KO.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3296715805. Error: AutoTrading disabled by client
# Symbol: KO.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: LI.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304127280. Error: Request returned None.
# Symbol: LI.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: LINKUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303764332. Error: Request returned None.
# Symbol: LINKUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: LRCUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3299514904. Error: Request returned None.
# Symbol: LRCUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304127358. Error: Request returned None.
# Symbol: LRCUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: LSEG.LSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3292134139. Error: AutoTrading disabled by client
# Symbol: LSEG.LSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: LTCUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303003157. Error: Request returned None.
# Symbol: LTCUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: MANAUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303174266. Error: Request returned None.
# Symbol: MANAUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303239684. Error: Request returned None.
# Symbol: MANAUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304128204. Error: Request returned None.
# Symbol: MANAUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304176884. Error: Request returned None.
# Symbol: MANAUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: MBG.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3294703468. Error: AutoTrading disabled by client
# Symbol: MBG.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3299026423. Error: AutoTrading disabled by client
# Symbol: MBG.XE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: MCD.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3299420804. Error: AutoTrading disabled by client
# Symbol: MCD.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: MDLZ.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3296717234. Error: AutoTrading disabled by client
# Symbol: MDLZ.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: MMM.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304835768. Error: AutoTrading disabled by client
# Symbol: MMM.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: MRK.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304188852. Error: AutoTrading disabled by client
# Symbol: MRK.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: MRK.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304493136. Error: AutoTrading disabled by client
# Symbol: MRK.XE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: MS.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304879336. Error: AutoTrading disabled by client
# Symbol: MS.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: MUR.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304239834. Error: AutoTrading disabled by client
# Symbol: MUR.TSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: NAB.ASX
# Action: Buy
# ⚠️ Failed to modify Buy position 3297726296. Error: AutoTrading disabled by client
# Symbol: NAB.ASX
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: NEARUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303173156. Error: Request returned None.
# Symbol: NEARUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: NEE.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304947636. Error: AutoTrading disabled by client
# Symbol: NEE.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: NESTE.OMXH
# Action: Buy
# ⚠️ Failed to modify Buy position 3304492589. Error: Request returned None.
# Symbol: NESTE.OMXH
# Action: Buy
# ⚠️ Failed to modify Buy position 3304492996. Error: Request returned None.
# Symbol: NESTE.OMXH
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: NID.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304239872. Error: Request returned None.
# Symbol: NID.TSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: NKE.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304131530. Error: Request returned None.
# Symbol: NKE.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: NOKIA.OMXH
# Action: Buy
# ⚠️ Failed to modify Buy position 3276134396. Error: Request returned None.
# Symbol: NOKIA.OMXH
# Action: Buy
# ⚠️ Failed to modify Buy position 3292135089. Error: Request returned None.
# Symbol: NOKIA.OMXH
# Action: Buy
# ⚠️ Failed to modify Buy position 3293980710. Error: Request returned None.
# Symbol: NOKIA.OMXH
# Action: Buy
# ⚠️ Failed to modify Buy position 3299027603. Error: Request returned None.
# Symbol: NOKIA.OMXH
# Action: Buy
# ⚠️ Failed to modify Buy position 3304492678. Error: Request returned None.
# Symbol: NOKIA.OMXH
# Action: Buy
# ⚠️ Failed to modify Buy position 3304547359. Error: Request returned None.
# Symbol: NOKIA.OMXH
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: NVDA.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304835289. Error: AutoTrading disabled by client
# Symbol: NVDA.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: NZDCAD
# Action: Buy
# ✅ No changes for Buy position 3304830506. TP/SL already set.
# Symbol: NZDCAD
# Action: Buy
# ✅ No changes for Buy position 3304830658. TP/SL already set.
# Symbol: NZDCAD
# Action: Sell
# ✅ No changes for Sell position 3296002462. TP/SL already set.
# Symbol: NZDCAD
# Action: Sell
# ✅ No changes for Sell position 3304223209. TP/SL already set.
# Symbol: NZDCAD
# Action: Sell
# ✅ No changes for Sell position 3304229647. TP/SL already set.
# Symbol: NZDCHF
# Action: Buy
# ⚠️ No Buy positions running. Skipping.
# Symbol: NZDCHF
# Action: Sell
# ✅ No changes for Sell position 3295245784. TP/SL already set.
# Symbol: NZDJPY
# Action: Buy
# ⚠️ Failed to modify Buy position 3304856177. Error: AutoTrading disabled by client
# Symbol: NZDJPY
# Action: Sell
# ⚠️ Failed to modify Sell position 3295754442. Error: AutoTrading disabled by client
# Symbol: NZDJPY
# Action: Sell
# ⚠️ Failed to modify Sell position 3304223214. Error: AutoTrading disabled by client
# Symbol: NZDUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3305270505. Error: AutoTrading disabled by client
# Symbol: NZDUSD
# Action: Sell
# ⚠️ Failed to modify Sell position 3303841489. Error: AutoTrading disabled by client
# Symbol: NZDUSD
# Action: Sell
# ⚠️ Failed to modify Sell position 3304223221. Error: AutoTrading disabled by client
# Symbol: OL.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303449890. Error: AutoTrading disabled by client
# Symbol: OL.TSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: OR.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3298299601. Error: AutoTrading disabled by client
# Symbol: OR.EPA
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: ORCL.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304836662. Error: AutoTrading disabled by client
# Symbol: ORCL.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: PEP.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3296714573. Error: AutoTrading disabled by client
# Symbol: PEP.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3299414757. Error: AutoTrading disabled by client
# Symbol: PEP.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: PFE.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3295995788. Error: Request returned None.
# Symbol: PFE.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3299416106. Error: Request returned None.
# Symbol: PFE.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: PG.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3292398776. Error: AutoTrading disabled by client
# Symbol: PG.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3293983199. Error: AutoTrading disabled by client
# Symbol: PG.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: PM.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304843607. Error: AutoTrading disabled by client
# Symbol: PM.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: PYPL.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304132258. Error: Request returned None.
# Symbol: PYPL.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: QCOM.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304132378. Error: AutoTrading disabled by client
# Symbol: QCOM.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: RTX.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3298446626. Error: AutoTrading disabled by client
# Symbol: RTX.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: SAN.BM
# Action: Buy
# ⚠️ Failed to modify Buy position 3303764473. Error: Request returned None.
# Symbol: SAN.BM
# Action: Buy
# ⚠️ Failed to modify Buy position 3304492796. Error: Request returned None.
# Symbol: SAN.BM
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: SBUX.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3280209688. Error: AutoTrading disabled by client
# Symbol: SBUX.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3293985232. Error: AutoTrading disabled by client
# Symbol: SBUX.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: SHEL.LSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303764511. Error: Request returned None.
# Symbol: SHEL.LSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: SHOP.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304835412. Error: Request returned None.
# Symbol: SHOP.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: SONY.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3295995076. Error: AutoTrading disabled by client
# Symbol: SONY.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3299416560. Error: AutoTrading disabled by client
# Symbol: SONY.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: STLA.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3304836943. Error: Request returned None.
# Symbol: STLA.MIL
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: SUIUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303764586. Error: Request returned None.
# Symbol: SUIUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: SVN.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303526044. Error: AutoTrading disabled by client
# Symbol: SVN.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304239917. Error: AutoTrading disabled by client
# Symbol: SVN.TSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: T.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3301254934. Error: AutoTrading disabled by client
# Symbol: T.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304132650. Error: AutoTrading disabled by client
# Symbol: T.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: TCEHY.OTC
# Action: Buy
# ⚠️ Failed to modify Buy position 3302788591. Error: AutoTrading disabled by client
# Symbol: TCEHY.OTC
# Action: Buy
# ⚠️ Failed to modify Buy position 3304177250. Error: AutoTrading disabled by client
# Symbol: TCEHY.OTC
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: TKY.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3305001170. Error: AutoTrading disabled by client
# Symbol: TKY.TSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: TM.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304242075. Error: AutoTrading disabled by client
# Symbol: TM.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304380529. Error: AutoTrading disabled by client
# Symbol: TM.TSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: TMH.TSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3303450840. Error: Request returned None.
# Symbol: TMH.TSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: TMO.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3295995689. Error: AutoTrading disabled by client
# Symbol: TMO.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: TTE.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3278875237. Error: AutoTrading disabled by client
# Symbol: TTE.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3292135946. Error: AutoTrading disabled by client
# Symbol: TTE.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3293652739. Error: AutoTrading disabled by client
# Symbol: TTE.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3293653283. Error: AutoTrading disabled by client
# Symbol: TTE.EPA
# Action: Buy
# ⚠️ Failed to modify Buy position 3293653462. Error: AutoTrading disabled by client
# Symbol: TTE.EPA
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: TXN.NAS
# Action: Buy
# ⚠️ Failed to modify Buy position 3304132717. Error: AutoTrading disabled by client
# Symbol: TXN.NAS
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: UCG.MIL
# Action: Buy
# ⚠️ Failed to modify Buy position 3303764669. Error: Request returned None.
# Symbol: UCG.MIL
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: UNH.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3295249135. Error: AutoTrading disabled by client
# Symbol: UNH.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: UNIUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303173729. Error: Request returned None.
# Symbol: UNIUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: UNP.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304132846. Error: AutoTrading disabled by client
# Symbol: UNP.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: UPS.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304133027. Error: AutoTrading disabled by client
# Symbol: UPS.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: USDCAD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303844515. Error: AutoTrading disabled by client
# Symbol: USDCAD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304223227. Error: AutoTrading disabled by client
# Symbol: USDCAD
# Action: Sell
# ⚠️ Failed to modify Sell position 3293436465. Error: AutoTrading disabled by client
# Symbol: USDCAD
# Action: Sell
# ⚠️ Failed to modify Sell position 3304223234. Error: AutoTrading disabled by client
# Symbol: USDCHF
# Action: Buy
# ⚠️ No Buy positions running. Skipping.
# Symbol: USDCHF
# Action: Sell
# ✅ No changes for Sell position 3301255979. TP/SL already set.
# Symbol: USDJPY
# Action: Buy
# ⚠️ Failed to modify Buy position 3303757544. Error: AutoTrading disabled by client
# Symbol: USDJPY
# Action: Buy
# ⚠️ Failed to modify Buy position 3304223239. Error: AutoTrading disabled by client
# Symbol: USDJPY
# Action: Sell
# ⚠️ Failed to modify Sell position 3291873635. Error: AutoTrading disabled by client
# Symbol: USDJPY
# Action: Sell
# ⚠️ Failed to modify Sell position 3304223246. Error: AutoTrading disabled by client
# Symbol: USDMXN
# Action: Buy
# ⚠️ Failed to modify Buy position 3293437457. Error: AutoTrading disabled by client
# Symbol: USDMXN
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: USDZAR
# Action: Buy
# ✅ No changes for Buy position 3293437473. TP/SL already set.
# Symbol: USDZAR
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: V.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304836805. Error: AutoTrading disabled by client
# Symbol: V.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: VNA.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3301984800. Error: Request returned None.
# Symbol: VNA.XE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: VOW3.XE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304856583. Error: Request returned None.
# Symbol: VOW3.XE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: VZ.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3301256630. Error: AutoTrading disabled by client
# Symbol: VZ.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304133254. Error: AutoTrading disabled by client
# Symbol: VZ.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: WES.ASX
# Action: Buy
# ⚠️ Failed to modify Buy position 3305058653. Error: AutoTrading disabled by client
# Symbol: WES.ASX
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: WFC.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3304837439. Error: AutoTrading disabled by client
# Symbol: WFC.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: WMT.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3298325768. Error: AutoTrading disabled by client
# Symbol: WMT.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3299419095. Error: AutoTrading disabled by client
# Symbol: WMT.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: XBRUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304837349. Error: Request returned None.
# Symbol: XBRUSD
# Action: Sell
# ⚠️ Failed to modify Sell position 3304242913. Error: AutoTrading disabled by client
# Symbol: XNGUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304493382. Error: Request returned None.
# Symbol: XNGUSD
# Action: Sell
# ⚠️ Failed to modify Sell position 3304493461. Error: AutoTrading disabled by client
# Symbol: XOM.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3278885254. Error: AutoTrading disabled by client
# Symbol: XOM.NYSE
# Action: Buy
# ⚠️ Failed to modify Buy position 3293990121. Error: AutoTrading disabled by client
# Symbol: XOM.NYSE
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
# Symbol: XTIUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3304837471. Error: Request returned None.
# Symbol: XTIUSD
# Action: Sell
# ⚠️ Failed to modify Sell position 3304223537. Error: AutoTrading disabled by client
# Symbol: ZECUSD
# Action: Buy
# ⚠️ Failed to modify Buy position 3303336699. Error: Request returned None.
# Symbol: ZECUSD
# Action: Sell
# ⚠️ No Sell positions running. Skipping.
#
# === TP/SL Modification Summary ===
# Total Successful Modifications: 0
# Total Failed Modifications: 218

# %%
import MetaTrader5 as mt5
import pandas as pd

# === Initialize MT5 Connection === #
if not mt5.initialize():
    print("MT5 initialization failed.")
    quit()

# === Fetch Open Positions === #
positions = mt5.positions_get()
if positions is None or len(positions) == 0:
    print("No running trades found. Exiting.")
    mt5.shutdown()
    quit()

# === Retrieve Unique Symbols from Positions === #
symbols = sorted(list(set(pos.symbol for pos in positions)))

# === Create DataFrame for Symbols and Decimals === #
symbol_decimals = []

for symbol in symbols:
    symbol_info = mt5.symbol_info(symbol)
    if symbol_info:
        symbol_decimals.append({
            "Symbol": symbol,
            "Decimals": symbol_info.digits
        })

# === Convert to DataFrame and Display === #
df_decimals = pd.DataFrame(symbol_decimals)
print(df_decimals)

# === Shutdown MT5 Connection === #
mt5.shutdown()
# Out:
#         Symbol  Decimals
# 0     AAPL.NAS         2
# 1      AAVEUSD         2
# 2    ABBV.NYSE         2
# 3     ABNB.NAS         2
# 4     ABT.NYSE         2
# ..         ...       ...
# 158     XBRUSD         2
# 159     XNGUSD         3
# 160   XOM.NYSE         2
# 161     XTIUSD         2
# 162     ZECUSD         2
#
# [163 rows x 2 columns]
# True

# %%
df_decimals.loc[(df_decimals["Symbol"] == "AUDCAD")]
# Out:
#     Symbol  Decimals
# 69  AUDCAD         5
